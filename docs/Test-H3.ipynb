# %% [markdown]
# # Uber H3 Demo
# H3 is hierarchical spatial index solution that applies recursive decomposition based on hexagonal cells.
#
# https://nbviewer.org/github/ozdemirht/py_redis_1/blob/master/docs/Test-H3.ipynb

# %% [markdown]
# ## Setup
# Need to install h3 and folium first

# %%
# %pip install h3
# %pip install folium
# %pip install geopandas
# %pip install tabulate
# Out:
# Requirement already satisfied: h3 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (4.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: folium in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from folium) (2.3.3)
# Requirement already satisfied: requests in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from requests->folium) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from requests->folium) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: geopandas in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.24 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from geopandas) (2.3.3)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from geopandas) (2.3.3)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.8.3)
# Requirement already satisfied: six>=1.5 in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tabulate in c:\users\timuc\onedrive\training\github-root\genai-ibm\py_redis_1\.venv\lib\site-packages (0.9.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Helper Functions
# This section will walk reader thorough the helper functions.

# %% [markdown]
# Let's first import packages this notebook will need.

# %%
import h3
import folium
from shapely.geometry import MultiPolygon, Polygon
from IPython.display import display
import pandas as pd

# %% [markdown]
# Let's display the H3 Cell id of a location at different hexagon resolutions.

# %%
# Let's explore H3Cell
df = pd.DataFrame(columns=["Lat", "Lon", "Hexagon Resolution", "H3 Address", "H3 Cell First Part", "H3 Cell Second Part"])
43.0375919,
test_lat = 37.3615593
test_lon = -122.0553238
test_lat = 43.0375919
test_lon = -76.135058
test_hexagon_resolutions = [7,8,9,10,11,12,13,14,15]
for i in test_hexagon_resolutions:
    hexagon_resolution=i
    h3_address = h3.latlng_to_cell(test_lat,test_lon, hexagon_resolution) # lat, lng, hex resolution
    print(f"H3 address ({test_lat},{test_lon},{hexagon_resolution:02d}): {h3_address} -> {h3_address[:3]} {h3_address[3:]}")
    new_row = {"Lat":test_lat, "Lon":test_lon, "Hexagon Resolution": hexagon_resolution, "H3 Address": h3_address, "H3 Cell First Part": h3_address[:3], "H3 Cell Second Part": h3_address[3:] }
    df.loc[len(df)]=new_row
# Out:
# H3 address (43.0375919,-76.135058,07): 872b8a2e3ffffff -> 872 b8a2e3ffffff
# H3 address (43.0375919,-76.135058,08): 882b8a2e3dfffff -> 882 b8a2e3dfffff
# H3 address (43.0375919,-76.135058,09): 892b8a2e3cfffff -> 892 b8a2e3cfffff
# H3 address (43.0375919,-76.135058,10): 8a2b8a2e3cd7fff -> 8a2 b8a2e3cd7fff
# H3 address (43.0375919,-76.135058,11): 8b2b8a2e3cd0fff -> 8b2 b8a2e3cd0fff
# H3 address (43.0375919,-76.135058,12): 8c2b8a2e3cd0bff -> 8c2 b8a2e3cd0bff
# H3 address (43.0375919,-76.135058,13): 8d2b8a2e3cd0bbf -> 8d2 b8a2e3cd0bbf
# H3 address (43.0375919,-76.135058,14): 8e2b8a2e3cd0baf -> 8e2 b8a2e3cd0baf
# H3 address (43.0375919,-76.135058,15): 8f2b8a2e3cd0bac -> 8f2 b8a2e3cd0bac

# %% [markdown]
# When the H3 Cell id of the same location at different resolution is displayed, it is easier to recognize the hierarchical spatial index encoding. For instance, the second character correlates with the resolution. In the last 12 characters, it is easier to observe that the prefix emerges as the resolution is increased.

# %%
from tabulate import tabulate
print(tabulate(df, headers = 'keys', tablefmt = 'psql'))
# Out:
# +----+---------+----------+----------------------+-----------------+----------------------+-----------------------+
# |    |     Lat |      Lon |   Hexagon Resolution | H3 Address      | H3 Cell First Part   | H3 Cell Second Part   |
# |----+---------+----------+----------------------+-----------------+----------------------+-----------------------|
# |  0 | 43.0376 | -76.1351 |                    7 | 872b8a2e3ffffff | 872                  | b8a2e3ffffff          |
# |  1 | 43.0376 | -76.1351 |                    8 | 882b8a2e3dfffff | 882                  | b8a2e3dfffff          |
# |  2 | 43.0376 | -76.1351 |                    9 | 892b8a2e3cfffff | 892                  | b8a2e3cfffff          |
# |  3 | 43.0376 | -76.1351 |                   10 | 8a2b8a2e3cd7fff | 8a2                  | b8a2e3cd7fff          |
# |  4 | 43.0376 | -76.1351 |                   11 | 8b2b8a2e3cd0fff | 8b2                  | b8a2e3cd0fff          |
# |  5 | 43.0376 | -76.1351 |                   12 | 8c2b8a2e3cd0bff | 8c2                  | b8a2e3cd0bff          |
# |  6 | 43.0376 | -76.1351 |                   13 | 8d2b8a2e3cd0bbf | 8d2                  | b8a2e3cd0bbf          |
# |  7 | 43.0376 | -76.1351 |                   14 | 8e2b8a2e3cd0baf | 8e2                  | b8a2e3cd0baf          |
# |  8 | 43.0376 | -76.1351 |                   15 | 8f2b8a2e3cd0bac | 8f2                  | b8a2e3cd0bac          |
# +----+---------+----------+----------------------+-----------------+----------------------+-----------------------+

# %%
# Extract the vertices from MultiPolygon structure, assuming 1 polygon
def get_outline_coordinates(mpoly: MultiPolygon):
    outline_coordinates = []
    for polygon in mpoly['coordinates']:
        if polygon:
            for vertices in polygon:
                if vertices:
                    for coord in vertices:
                        outline_coordinates.append([coord[0],coord[1]]) ## needs further investigation why it needs to be switched
    return outline_coordinates

# %%
# Defines line segments from list of vertices
# assumption: vertices are in order
def get_polyLines(coordinates):
    returnlines = []
    i=1;
    while i < len(coordinates):
        returnlines.append([coordinates[i-1],coordinates[i]])
        i=i+1
    return returnlines

# %%
# Switching
def reverseLatLonLinesOfPolygon(vertices):
    result = []
    [result.append([v[1], v[0]]) for v in vertices]
    return result

# %% [markdown]
# Method visualize_polygon() renders polygon a map (folium.Map). <br>
# The returned map can be rendered by calling display(m)

# %%
###
def visualize_polygon(polyline, color):
    """
        Visualize a polygon by using folium
    :param polyline:
    :param color:
    :return:
    """
    polyline.append(polyline[0])
    lat = [p[0] for p in polyline]
    lng = [p[1] for p in polyline]
    m = folium.Map(location=[sum(lat)/len(lat), sum(lng)/len(lng)], zoom_start=13, tiles='Cartodb Positron')
    my_PolyLine=folium.PolyLine(locations=polyline,weight=8,color=color)
    m.add_child(my_PolyLine)
    return m

# %% [markdown]
# Method visualize_hexagons() renders hexagons on a map (folium.Map)

# %%
###
def visualize_hexagons(hexagons, color="cyan", folium_map=None,zoom_start=13):
    """
    Visualize Hexagons by using folium tool

    :param hexagons: is a list of hexcluster. Each hexcluster is a list of hexagons. eg. [[hex1, hex2], [hex3, hex4]]
    :param color:
    :param folium_map:
    """
    polylines = []
    lat = []
    lng = []
    for hex in hexagons:
        #polygons = h3.h3_set_to_multi_polygon([hex], geo_json=False)
        polygons = h3.cells_to_geo([hex], tight=False)
        # flatten polygons into loops.
        #outlines = [loop for polygon in polygons for loop in polygon]
        outlines = get_outline_coordinates(polygons)
        #polyline = [outline + [outline[0]] for outline in outlines][0]
        polyline = get_polyLines(outlines)
        #polyline = h3.LatLngPoly(outlines)
        polyline = outlines
        lat.extend(map(lambda v:v[0],polyline))
        lng.extend(map(lambda v:v[1],polyline))
        polylines.append(polyline)

    #for polyline in polylines:
    #    print(polyline)
    location=[sum(lng)/len(lng),sum(lat)/len(lat)]
    print(f"Center :{location}")

    if folium_map is None:
        #m = folium.Map(location=[sum(lng)/len(lng), sum(lat)/len(lat)], tiles='Cartodb Positron', zoom_start=13)
        m = folium.Map(location=[sum(lng)/len(lng), sum(lat)/len(lat)], tiles='OpenStreetMap', zoom_start=zoom_start)
    else:
        m = folium_map

    for polyline in polylines:
        #my_PolyLine=folium.PolyLine(locations=polyline,weight=8,color=color)
        my_PolyLine=folium.PolyLine(locations=reverseLatLonLinesOfPolygon(polyline),weight=8,color=color)
        m.add_child(my_PolyLine)
        for v in polyline:
            r=5
            circle = folium.CircleMarker(
                location=[v[1], v[0]],
                radius=r,
                color="cornflowerblue",
                stroke=False,
                fill=True,
                fill_opacity=0.6,
                opacity=1,
                popup="{} pixels".format(r),
                tooltip="{},{}".format(v[1], v[0]),
            )
            m.add_child(circle)

    return m

# %% [markdown]
# ## H3 Cell Visualization on a Map
# - It will translate location at resolution 9 to H3 Cell address
# - Then finds the vertices of H3 Cell
# - Displays the boundary of H3 Cell on a Map

# %%
hexagon_resolution=9
h3_address = h3.latlng_to_cell(test_lat,test_lon, hexagon_resolution)
print(f"h3.latlng_to_cell ({test_lat},{test_lon},{hexagon_resolution:02d}): {h3_address} ")
# Out:
# h3.latlng_to_cell (43.0375919,-76.135058,09): 892b8a2e3cfffff

# %% [markdown]
# As we have seen before H3 Cell did consist of two parts: first 3 encodes and the remaining encodes the hierarchy.
# <br> Let's find out the boundary of 89283470d93ffff

# %%
# Boundary of H3 Cell
h3_cell_boundary = h3.cell_to_boundary(h3_address)
for i in range(len(h3_cell_boundary)):
    print(f"v[{i+1}]={h3_cell_boundary[i]}")
# Out:
# v[1]=(43.03906983955765, -76.13379936708955)
# v[2]=(43.03806660158603, -76.13596540836582)
# v[3]=(43.0362591407131, -76.13580815975423)
# v[4]=(43.035454908732, -76.13348504597)
# v[5]=(43.036458071661094, -76.13131907499339)
# v[6]=(43.03826554161082, -76.13147614749984)

# %% [markdown]
# Because this H3 Cell is hexagon, it has 6 vertices. <br> Let's display H3 Cell information on a map.

# %%
m = visualize_hexagons([h3_address],color="red")
display(m)
# Out:
# Center :[43.03714745364597, -76.13331032552375]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2bb24a6529a1477eca396ce7dab7bd59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2bb24a6529a1477eca396ce7dab7bd59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2bb24a6529a1477eca396ce7dab7bd59 = L.map(
#                 &quot;map_2bb24a6529a1477eca396ce7dab7bd59&quot;,
#                 {
#                     center: [43.03714745364597, -76.13331032552375],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_398d726441c33e28af89b1951ac0f98f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_398d726441c33e28af89b1951ac0f98f.addTo(map_2bb24a6529a1477eca396ce7dab7bd59);
#
#
#             var poly_line_dc51eebe34e446db6c697c0423f9d2ab = L.polyline(
#                 [[43.036458071661094, -76.13131907499339], [43.03826554161082, -76.13147614749984], [43.03906983955765, -76.13379936708955], [43.03806660158603, -76.13596540836582], [43.0362591407131, -76.13580815975423], [43.035454908732, -76.13348504597], [43.036458071661094, -76.13131907499339]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8}
#             ).addTo(map_2bb24a6529a1477eca396ce7dab7bd59);
#
#
#             var circle_marker_0e81bcc41c12598182e72c87e0a1702d = L.circleMarker(
#                 [43.036458071661094, -76.13131907499339],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cornflowerblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cornflowerblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 5, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_2bb24a6529a1477eca396ce7dab7bd59);
#
#
#         var popup_da1c163f6c9f7324f6fbbd9beffbe964 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dea1bfd3765676713fcec7e4e02455f = $(`&lt;div id=&quot;html_7dea1bfd3765676713fcec7e4e02455f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5 pixels&lt;/div&gt;`)[0];
#                 popup_da1c163f6c9f7324f6fbbd9beffbe964.setContent(html_7dea1bfd3765676713fcec7e4e02455f);
#
#
#
#         circle_marker_0e81bcc41c12598182e72c87e0a1702d.bindPopup(popup_da1c163f6c9f7324f6fbbd9beffbe964)
#         ;
#
#
#
#
#             circle_marker_0e81bcc41c12598182e72c87e0a1702d.bindTooltip(
#                 `&lt;div&gt;
#                      43.036458071661094,-76.13131907499339
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_03233185110034a826cdf2bb4abeb827 = L.circleMarker(
#                 [43.03826554161082, -76.13147614749984],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cornflowerblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cornflowerblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 5, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_2bb24a6529a1477eca396ce7dab7bd59);
#
#
#         var popup_92c3d3cba5161b888694eedf60d23c3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_285f8a443e004ac34b72a4edb7b3fe53 = $(`&lt;div id=&quot;html_285f8a443e004ac34b72a4edb7b3fe53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5 pixels&lt;/div&gt;`)[0];
#                 popup_92c3d3cba5161b888694eedf60d23c3c.setContent(html_285f8a443e004ac34b72a4edb7b3fe53);
#
#
#
#         circle_marker_03233185110034a826cdf2bb4abeb827.bindPopup(popup_92c3d3cba5161b888694eedf60d23c3c)
#         ;
#
#
#
#
#             circle_marker_03233185110034a826c

# %% [markdown]
# If the notebook did not show the image, here is the screenshot.
# ![](m1.png)

# %% [markdown]
# Let's also visualize the parent H3 Cell

# %%
parents = h3.cell_to_parent(h3_address)
print(f"parent-of({h3_address})={parents}")
# Out:
# parent-of(892b8a2e3cfffff)=882b8a2e3dfffff

# %%
childrens =  h3.cell_to_children(parents)
childrens = [h for h in childrens if h!=h3_address]

m = visualize_hexagons(childrens,color="cyan",folium_map=m)

#display(m)
# Out:
# Center :[43.040675316391244, -76.13120273448256]

# %%
m = visualize_hexagons([parents],color="blue",folium_map=m)
display(m)
# Out:
# Center :[43.03990126436152, -76.13258401494035]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2bb24a6529a1477eca396ce7dab7bd59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2bb24a6529a1477eca396ce7dab7bd59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2bb24a6529a1477eca396ce7dab7bd59 = L.map(
#                 &quot;map_2bb24a6529a1477eca396ce7dab7bd59&quot;,
#                 {
#                     center: [43.03714745364597, -76.13331032552375],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_398d726441c33e28af89b1951ac0f98f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_398d726441c33e28af89b1951ac0f98f.addTo(map_2bb24a6529a1477eca396ce7dab7bd59);
#
#
#             var poly_line_dc51eebe34e446db6c697c0423f9d2ab = L.polyline(
#                 [[43.036458071661094, -76.13131907499339], [43.03826554161082, -76.13147614749984], [43.03906983955765, -76.13379936708955], [43.03806660158603, -76.13596540836582], [43.0362591407131, -76.13580815975423], [43.035454908732, -76.13348504597], [43.036458071661094, -76.13131907499339]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8}
#             ).addTo(map_2bb24a6529a1477eca396ce7dab7bd59);
#
#
#             var circle_marker_0e81bcc41c12598182e72c87e0a1702d = L.circleMarker(
#                 [43.036458071661094, -76.13131907499339],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cornflowerblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cornflowerblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 5, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_2bb24a6529a1477eca396ce7dab7bd59);
#
#
#         var popup_da1c163f6c9f7324f6fbbd9beffbe964 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dea1bfd3765676713fcec7e4e02455f = $(`&lt;div id=&quot;html_7dea1bfd3765676713fcec7e4e02455f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5 pixels&lt;/div&gt;`)[0];
#                 popup_da1c163f6c9f7324f6fbbd9beffbe964.setContent(html_7dea1bfd3765676713fcec7e4e02455f);
#
#
#
#         circle_marker_0e81bcc41c12598182e72c87e0a1702d.bindPopup(popup_da1c163f6c9f7324f6fbbd9beffbe964)
#         ;
#
#
#
#
#             circle_marker_0e81bcc41c12598182e72c87e0a1702d.bindTooltip(
#                 `&lt;div&gt;
#                      43.036458071661094,-76.13131907499339
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_03233185110034a826cdf2bb4abeb827 = L.circleMarker(
#                 [43.03826554161082, -76.13147614749984],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cornflowerblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cornflowerblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 5, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_2bb24a6529a1477eca396ce7dab7bd59);
#
#
#         var popup_92c3d3cba5161b888694eedf60d23c3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_285f8a443e004ac34b72a4edb7b3fe53 = $(`&lt;div id=&quot;html_285f8a443e004ac34b72a4edb7b3fe53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5 pixels&lt;/div&gt;`)[0];
#                 popup_92c3d3cba5161b888694eedf60d23c3c.setContent(html_285f8a443e004ac34b72a4edb7b3fe53);
#
#
#
#         circle_marker_03233185110034a826cdf2bb4abeb827.bindPopup(popup_92c3d3cba5161b888694eedf60d23c3c)
#         ;
#
#
#
#
#             circle_marker_03233185110034a826c

# %% [markdown]
# If the notebook does not show the image, here is the screenshot.
# ![](./m2.png)

# %% [markdown]
# ## How to utilize H3 Cells and hierarchical decomposition to implement NNQ?
# There are two parameters drive such decision.
#  1. Search radius, given in NNQ.
#  1. H3 Cell Resolution used when the index structure is built.
#
# For given NNQ and resolution of H3 Cell Index, system needs to figure out which H3 Cells are contained in the circle defined by NNQ.
# <br>Then restaurants in the selected H3 Cells are sorted based on L2 distance formula before returning a query result.

# %%
neighbors = h3.grid_ring(h3_address)
neighbors
# Out:
# ['892b8a2e3c3ffff',
#  '892b8a2e3cbffff',
#  '892b8a2e353ffff',
#  '892b8a2e357ffff',
#  '892b8a2e31bffff',
#  '892b8a2e3c7ffff']

# %%
m = visualize_hexagons(neighbors,color="green")
m = visualize_hexagons([h3_address],color="red",folium_map=m)
m = visualize_hexagons([parents],color="blue",folium_map=m,zoom_start=18)
display(m)
# Out:
# Center :[43.03739617632877, -76.13354654462405]
# Center :[43.03714745364597, -76.13331032552375]
# Center :[43.03990126436152, -76.13258401494035]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_271a98c859e9ce3f623a3c3659fb191f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_271a98c859e9ce3f623a3c3659fb191f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_271a98c859e9ce3f623a3c3659fb191f = L.map(
#                 &quot;map_271a98c859e9ce3f623a3c3659fb191f&quot;,
#                 {
#                     center: [43.03739617632877, -76.13354654462405],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ffd098c87a658e56097a3229cb321498 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ffd098c87a658e56097a3229cb321498.addTo(map_271a98c859e9ce3f623a3c3659fb191f);
#
#
#             var poly_line_73fc85b0c4b73fc34944ca03219f0110 = L.polyline(
#                 [[43.03926869649308, -76.12931000122254], [43.04107622436191, -76.12946700421372], [43.04188058828088, -76.13179032961176], [43.04087735835588, -76.1339565462088], [43.03906983955765, -76.13379936708955], [43.03826554161082, -76.13147614749984], [43.03926869649308, -76.12931000122254]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8}
#             ).addTo(map_271a98c859e9ce3f623a3c3659fb191f);
#
#
#             var circle_marker_de3fcfab12766c42cd627df68e3413f4 = L.circleMarker(
#                 [43.03926869649308, -76.12931000122254],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cornflowerblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cornflowerblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 5, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_271a98c859e9ce3f623a3c3659fb191f);
#
#
#         var popup_f76b0acc927c7fc33eea4f47e629e5a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15675690b7224b71d8d4d5c96cc02fa4 = $(`&lt;div id=&quot;html_15675690b7224b71d8d4d5c96cc02fa4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5 pixels&lt;/div&gt;`)[0];
#                 popup_f76b0acc927c7fc33eea4f47e629e5a4.setContent(html_15675690b7224b71d8d4d5c96cc02fa4);
#
#
#
#         circle_marker_de3fcfab12766c42cd627df68e3413f4.bindPopup(popup_f76b0acc927c7fc33eea4f47e629e5a4)
#         ;
#
#
#
#
#             circle_marker_de3fcfab12766c42cd627df68e3413f4.bindTooltip(
#                 `&lt;div&gt;
#                      43.03926869649308,-76.12931000122254
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_402e002671b502b15b78e78c37ce2759 = L.circleMarker(
#                 [43.04107622436191, -76.12946700421372],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cornflowerblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cornflowerblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 5, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_271a98c859e9ce3f623a3c3659fb191f);
#
#
#         var popup_dca4b9e59b0788fe7f7c21b86169b35a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59ca127941e0a75afa3deb8b961101c6 = $(`&lt;div id=&quot;html_59ca127941e0a75afa3deb8b961101c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5 pixels&lt;/div&gt;`)[0];
#                 popup_dca4b9e59b0788fe7f7c21b86169b35a.setContent(html_59ca127941e0a75afa3deb8b961101c6);
#
#
#
#         circle_marker_402e002671b502b15b78e78c37ce2759.bindPopup(popup_dca4b9e59b0788fe7f7c21b86169b35a)
#         ;
#
#
#
#
#             circle_marker_402e002671b502

# %% [markdown]
# If the notebook does not show the image, here is the screenshot.
# ![](./m4.png)

# %% [markdown]
# The hexagon in red (h3_address) is the H3 Cell that contains query point.
# <br> The hexagon in blue is parent H3 Cell of h3_address in the hierarchical decomposition.
# <br> The hexagons in green are H3 Cells surrounding h3_address, hence called ring. Based on the given radius and resolution used, it can decide which H3 Cells to leverage for fast NNQ.

# %% [markdown]
# ## Summary
# The objective of this exploration is to demonstrate part of H3 Cell and spatial indexing. Hopefully it helps to understand how it works.
