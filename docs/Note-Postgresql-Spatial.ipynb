# %% [markdown]
# ## PostgreSQL and PostGIS for Nearest Neighbour Query / Proximity Search

# %% [markdown]
# Objective is to leverage PostGIS for NNQ.

# %%
# %pip install --user psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\timuc\appdata\roaming\python\python313\site-packages (2.9.11)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# To enable PostGIS extension, run the following command on database
#
# CREATE EXTENSION postgis;

# %%
import psycopg2
from psycopg2 import Error
import pandas as pd

# %% [markdown]
# Parsing configuration parameters.

# %%
def getConfigOrDefault(config_filename, config,label,default=None):
    if config.get(label) is not None:
        return config.get(label)
    if default is not None:
        return default
    print(f"{config_filename} file does not have {label} parameter!")
    return None

# %%
from dotenv import dotenv_values
config_filename = './postgresql.cfg'
config = dotenv_values(config_filename)

USER_NAME = getConfigOrDefault(config_filename, config, 'POSTGRES_UNAME')
USER_PWD  = getConfigOrDefault(config_filename, config, 'POSTGRES_UPWD')
POSTGRES_HOST = getConfigOrDefault(config_filename, config, 'POSTGRES_HOST', 'localhost')
POSTGRES_PORT = getConfigOrDefault(config_filename, config, 'POSTGRES_PORT', '5432')
POSTGRES_DB = getConfigOrDefault(config_filename, config, 'POSTGRES_DBNAME', 'test')

if USER_PWD is None or USER_PWD is None:
    print(f"{config_filename} file does not have parameters: POSTGRES_UNAME and/or POSTGRES_UPWD!")

# %%
try:
    # Connect to an existing database
    connection = psycopg2.connect(user=USER_NAME,
                                  password=USER_PWD,
                                  host=POSTGRES_HOST,
                                  port=POSTGRES_PORT,
                                  database=POSTGRES_DB)

    # Create a cursor to perform database operations
    cursor = connection.cursor()
    # Print PostgreSQL details
    print("PostgreSQL server information")
    print(connection.get_dsn_parameters(), "\n")
    # Executing a SQL query
    cursor.execute("SELECT version();")
    # Fetch result
    record = cursor.fetchone()
    print("You are connected to - ", record, "\n")

    #Closing the connection
    connection.close()

except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if (connection):
       cursor.close()
       connection.close()
       print("PostgreSQL connection is closed")
# Out:
# PostgreSQL server information
# {'user': 'test_user', 'channel_binding': 'prefer', 'dbname': 'postgres', 'host': '127.0.0.1', 'port': '5432', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'sslcertmode': 'allow', 'sslsni': '1', 'ssl_min_protocol_version': 'TLSv1.2', 'gssencmode': 'disable', 'krbsrvname': 'postgres', 'gssdelegation': '0', 'target_session_attrs': 'any', 'load_balance_hosts': 'disable'}
#
# You are connected to -  ('PostgreSQL 17.5 on x86_64-windows, compiled by msvc-19.44.35209, 64-bit',)
#
# PostgreSQL connection is closed

# %% [markdown]
# ## Helpers

# %%
def execute_sqL_with_fetchnone(sql_stmt):
    """ Executes SQL statement with fetchnone
        Not worried about performance
    """
    print(f"Executing SQL statement with fetchnone-{sql_stmt}")
    try:
        # Connect to an existing database
        connection = psycopg2.connect(user=USER_NAME,
                                  password=USER_PWD,
                                  host=POSTGRES_HOST,
                                  port=POSTGRES_PORT,
                                  database=POSTGRES_DB)

        # Create a cursor to perform database operations
        cursor = connection.cursor()
        # Executing given SQL query
        cursor.execute(sql_stmt)
        connection.commit()
        cursor.close()
        connection.close()

    except (Exception, Error) as error:
        print(f"Error : {error}")
    finally:
        if (connection):
            cursor.close()
            connection.close()
            print(f"Connection to PostgreSQL({POSTGRES_HOST}:{POSTGRES_PORT}) is closed")

# %%
def execute_sqL_with_fetchone(sql_stmt):
    """ Executes SQL statement with fetchone
        Not worried about performance
    """
    response = None
    print(f"Executing SQL statement with fetchone-{sql_stmt}")
    try:
        # Connect to an existing database
        connection = psycopg2.connect(user=USER_NAME,
                                  password=USER_PWD,
                                  host=POSTGRES_HOST,
                                  port=POSTGRES_PORT,
                                  database=POSTGRES_DB)

        # Create a cursor to perform database operations
        cursor = connection.cursor()
        # Executing given SQL query
        cursor.execute(sql_stmt)
        # Fetch result so that it can return
        response = cursor.fetchone()

        connection.commit()
        cursor.close()
        connection.close()

    except (Exception, Error) as error:
        print(f"Error : {error}")
    finally:
        if (connection):
            cursor.close()
            connection.close()
            print(f"Connection to PostgreSQL({POSTGRES_HOST}:{POSTGRES_PORT}) is closed")
    return response

# %%
def execute_sqL_with_fetchall(sql_stmt):
    """ Executes SQL statement with fetchone
        Not worried about performance
    """
    response = None
    try:
        # Connect to an existing database
        connection = psycopg2.connect(user=USER_NAME,
                                  password=USER_PWD,
                                  host=POSTGRES_HOST,
                                  port=POSTGRES_PORT,
                                  database=POSTGRES_DB)

        # Create a cursor to perform database operations
        cursor = connection.cursor()
        # Executing given SQL query
        cursor.execute(sql_stmt)
        # Fetch result so that it can return
        response = cursor.fetchall()

        connection.commit()
        cursor.close()
        connection.close()

    except (Exception, Error) as error:
        print(f"Error : {error}")
    finally:
        if (connection):
            cursor.close()
            connection.close()
            print(f"Connection to PostgreSQL({POSTGRES_HOST}:{POSTGRES_PORT}) is closed")
    return response

# %% [markdown]
# This notebook utilize following helper queries

# %%
# Queries
SQL_DROP_TABLE = f"DROP TABLE IF EXISTS test.restaurants;"
SQL_CREATE_TABLE = f"""
    CREATE TABLE IF NOT EXISTS test.restaurants (
    id SERIAL PRIMARY KEY,
    name VARCHAR(255),
    cuisine VARCHAR(64),
    longitude FLOAT,
    latitude FLOAT,
    location GEOMETRY(Point, 4326)
    )
    """
SQL_VALIDATE_COLUMNS="""
     select column_name
        , data_type
        , udt_catalog
        , udt_schema
        , udt_name
        , character_maximum_length
        , column_default
        , is_nullable
    from INFORMATION_SCHEMA.COLUMNS
    where table_name = 'restaurants';
    """

# %%
# Drops the restaurants table
reply = execute_sqL_with_fetchnone(SQL_DROP_TABLE)
reply
# Out:
# Executing SQL statement with fetchnone-DROP TABLE IF EXISTS test.restaurants;
# Connection to PostgreSQL(127.0.0.1:5432) is closed

# %%
# create the restaurants table
reply = execute_sqL_with_fetchnone(SQL_CREATE_TABLE)
reply
# Out:
# Executing SQL statement with fetchnone-
#     CREATE TABLE IF NOT EXISTS test.restaurants (
#     id SERIAL PRIMARY KEY,
#     name VARCHAR(255),
#     cuisine VARCHAR(64),
#     longitude FLOAT,
#     latitude FLOAT,
#     location GEOMETRY(Point, 4326)
#     )
#
# Connection to PostgreSQL(127.0.0.1:5432) is closed

# %%
# create the restaurants table
reply = execute_sqL_with_fetchall(SQL_VALIDATE_COLUMNS)
reply
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# [('id',
#   'integer',
#   'postgres',
#   'pg_catalog',
#   'int4',
#   None,
#   "nextval('test.restaurants_id_seq'::regclass)",
#   'NO'),
#  ('name',
#   'character varying',
#   'postgres',
#   'pg_catalog',
#   'varchar',
#   255,
#   None,
#   'YES'),
#  ('cuisine',
#   'character varying',
#   'postgres',
#   'pg_catalog',
#   'varchar',
#   64,
#   None,
#   'YES'),
#  ('longitude',
#   'double precision',
#   'postgres',
#   'pg_catalog',
#   'float8',
#   None,
#   None,
#   'YES'),
#  ('latitude',
#   'double precision',
#   'postgres',
#   'pg_catalog',
#   'float8',
#   None,
#   None,
#   'YES'),
#  ('location',
#   'USER-DEFINED',
#   'postgres',
#   'public',
#   'geometry',
#   None,
#   None,
#   'YES')]

# %% [markdown]
# Let's check table definition

# %%
column_names = [ 'column_name', 'data_type',
                 'udt_catalog', 'udt_schema', 'udt_name',
                 'character_maximum_length', 'column_default', 'is_nullable']
df = pd.DataFrame(reply,columns=column_names)
df
# Out:
#   column_name          data_type udt_catalog  udt_schema  udt_name  \
# 0          id            integer    postgres  pg_catalog      int4
# 1        name  character varying    postgres  pg_catalog   varchar
# 2     cuisine  character varying    postgres  pg_catalog   varchar
# 3   longitude   double precision    postgres  pg_catalog    float8
# 4    latitude   double precision    postgres  pg_catalog    float8
# 5    location       USER-DEFINED    postgres      public  geometry
#
#    character_maximum_length                                column_default  \
# 0                       NaN  nextval('test.restaurants_id_seq'::regclass)
# 1                     255.0                                          None
# 2                      64.0                                          None
# 3                       NaN                                          None
# 4                       NaN                                          None
# 5                       NaN                                          None
#
#   is_nullable
# 0          NO
# 1         YES
# 2         YES
# 3         YES
# 4         YES
# 5         YES

# %%
filename="./restaurants.csv"
df_loaded = pd.read_csv(filename)
df_loaded[:10]
# Out:
#                              Name        Lon        Lat
# 0           Morris Park Bake Shop -73.856077  40.848447
# 1                         Wendy'S -73.961704  40.662942
# 2                 Riviera Caterer -73.982420  40.579505
# 3              Tov Kosher Kitchen -73.860115  40.731174
# 4         Brunos On The Boulevard -73.880383  40.764312
# 5  Dj Reynolds Pub And Restaurant -73.985136  40.767692
# 6              Wilken'S Fine Food -73.906851  40.619903
# 7                 Regina Caterers -74.005289  40.628886
# 8     Taste The Tropics Ice Cream -73.948261  40.640827
# 9                   Kosher Island -74.137729  40.611957

# %%
df_loaded['Rid'] = df_loaded.index
printdf = df_loaded[:10]
print(printdf.to_string(index=False))
# Out:
#                           Name        Lon       Lat  Rid
#          Morris Park Bake Shop -73.856077 40.848447    0
#                        Wendy'S -73.961704 40.662942    1
#                Riviera Caterer -73.982420 40.579505    2
#             Tov Kosher Kitchen -73.860115 40.731174    3
#        Brunos On The Boulevard -73.880383 40.764312    4
# Dj Reynolds Pub And Restaurant -73.985136 40.767692    5
#             Wilken'S Fine Food -73.906851 40.619903    6
#                Regina Caterers -74.005289 40.628886    7
#    Taste The Tropics Ice Cream -73.948261 40.640827    8
#                  Kosher Island -74.137729 40.611957    9

# %%
import random
def assignCuisineRandomly(df,cuisine,cname):
    for i in range(df.shape[0]):
        df.at[i,cname] = cuisine[random.randint(0,len(cuisine)-1)]

# %%
cuisine = ['italian', 'chinese', 'french', 'zambian', 'egyptian', 'canadian', 'mexican', 'vietnamese', 'cajun', 'korean', 'thai', 'brazilian','colombian','peruvian','ecuadorian', 'japanese','indian','malaysian','russian', 'indonesian']
assignCuisineRandomly(df_loaded,cuisine,'Cuisine')
df_loaded[-4:]
# Out:
#                              Name        Lon        Lat   Rid    Cuisine
# 4996  Wagner College - Hawk' Nest -74.092853  40.615121  4996   egyptian
# 4997         Ellen Deli & Grocery -74.007810  40.725708  4997  malaysian
# 4998           Crepes On Columbus -73.961831  40.801052  4998    mexican
# 4999               Capital Grille -73.974723  40.751244  4999   japanese

# %%
def formatSQL(df):
    name = df['Name'].replace("'"," ")
    sql_stmt = f"INSERT INTO test.restaurants (name, cuisine, longitude, latitude, location) VALUES ('{name}','{df['Cuisine']}',{df['Lon']},{df['Lat']},ST_GeomFromText('POINT({df['Lon']} {df['Lat']})', 4326));"

    return sql_stmt

# %%
#print(formatSQL(df_loaded[0]))
idx=4996
print(type(df_loaded.loc[idx].to_dict()))
df_loaded.loc[idx].to_dict()
print(formatSQL(df_loaded.loc[idx].to_dict()))
# Out:
# <class 'dict'>
# INSERT INTO test.restaurants (name, cuisine, longitude, latitude, location) VALUES ('Wagner College - Hawk  Nest','egyptian',-74.09285299999999,40.61512099999999,ST_GeomFromText('POINT(-74.09285299999999 40.61512099999999)', 4326));

# %% [markdown]
# Let's load the data

# %%
# Load data to test.restaurants table
# using ST_GeomFromText('POINT($longitude $latitude)', 4326)
try:
        # Connect to an existing database
        connection = psycopg2.connect(user=USER_NAME,
                                      password=USER_PWD,
                                      host=POSTGRES_HOST,
                                      port=POSTGRES_PORT,
                                      database=POSTGRES_DB)

        # Create a cursor to perform database operations
        cursor = connection.cursor()
        # Executing a SQL query
        cursor.execute("SELECT version();")
        # Fetch result
        record = cursor.fetchone()
        print("You are connected to - ", record, "\n")
        sql_stmt = ""
        for i in range(df_loaded.shape[0]):
            #addARestaurant(connection, df_loaded.loc[i].to_dict())
            sql_stmt = formatSQL(df_loaded.loc[i].to_dict())
            #print(sql_stmt)
            cursor.execute(sql_stmt)

        connection.commit()

        #Closing the connection
        connection.close()

except (Exception, Error) as error:
        print("Error: ", error)
finally:
        if (connection):
            cursor.close()
            connection.close()
        print("PostgreSQL connection is closed")
# Out:
# You are connected to -  ('PostgreSQL 17.5 on x86_64-windows, compiled by msvc-19.44.35209, 64-bit',)
#
# PostgreSQL connection is closed

# %% [markdown]
# Let's search

# %%
NNQ_LON = -74.092853
NNQ_LAT =  40.615121
NNQ_RADIUS = 2000/10000
query = f"""
SELECT name
    , cuisine
    , longitude
    , latitude
    , ST_Distance(location, ST_Point({NNQ_LON}, {NNQ_LAT},4326)) AS dist2NNQ
FROM test.restaurants
WHERE ST_DWithin(location, ST_Point({NNQ_LON}, {NNQ_LAT},4326), {NNQ_RADIUS});
"""

explain_query = "Explain "+ query

# %%
reply = execute_sqL_with_fetchall(query)
reply
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# [('Wendy S', 'egyptian', -73.961704, 40.662942, 0.13959551655408542),
#  ('Riviera Caterer',
#   'brazilian',
#   -73.98241999999999,
#   40.579505,
#   0.11603424901727748),
#  ('Dj Reynolds Pub And Restaurant',
#   'indonesian',
#   -73.98513559999999,
#   40.7676919,
#   0.18676433757431565),
#  ('Wilken S Fine Food',
#   'zambian',
#   -73.9068506,
#   40.6199034,
#   0.1860638711720318),
#  ('Regina Caterers',
#   'indonesian',
#   -74.00528899999999,
#   40.628886,
#   0.08863932152832932),
#  ('Taste The Tropics Ice Cream',
#   'zambian',
#   -73.9482609,
#   40.6408271,
#   0.14685938498993956),
#  ('Kosher Island', 'vietnamese', -74.1377286, 40.6119572, 0.04498698818324906),
#  ('C & C Catering Service',
#   'vietnamese',
#   -73.9973325,
#   40.61174889999999,
#   0.09558000302710451),
#  ('1 East 66Th Street Kitchen',
#   'zambian',
#   -73.96926909999999,
#   40.7685235,
#   0.19699062755741206),
#  ('Seuda Foods', 'zambian', -73.9653967, 40.6064339, 0.12775200239566312),
#  ('Carvel Ice Cream',
#   'chinese',
#   -73.97822040000001,
#   40.6435254,
#   0.1180992926402118),
#  ('Nordic Delicacies',
#   'japanese',
#   -74.0259567,
#   40.6353674,
#   0.06989300155703222),
#  ('The Movable Feast', 'french', -73.9829239, 40.6580753, 0.11802321345947299),
#  ('Bully S Deli', 'zambian', -73.9925306, 40.7309346, 0.15322328115113917),
#  ('Angelika Film Center', 'thai', -73.996984, 40.72589, 0.1464944931456501),
#  ('White Castle', 'french', -73.9634876, 40.6940001, 0.15151672889147322),
#  ('The Country Cafe',
#   'russian',
#   -74.0085357,
#   40.70620539999999,
#   0.12412000242768659),
#  ('Shashemene Int L Restaura',
#   'brazilian',
#   -73.9246028,
#   40.6522396,
#   0.17229602510215056),
#  ('Downtown Deli',
#   'egyptian',
#   -74.00920839999999,
#   40.7132925,
#   0.12897310774503412),
#  ('Dunkin  Donuts', 'chinese', -73.991495, 40.692273, 0.12738082770967013),
#  ('Olive S', 'canadian', -73.9998042, 40.7251256, 0.14408015547812333),
#  ('Cafe Metro', 'chinese', -73.990494, 40.7569545, 0.1749117108808058),
#  ('Lexler Deli', 'thai', -73.97534999999999, 40.7516269, 0.18011334138206436),
#  ('Bagels N Buns', 'indonesian', -74.1459332, 40.6103714, 0.05329227272503654),
#  ('Domino S Pizza', 'korean', -73.9791458, 40.744328, 0.17211558959269768),
#  ('Berkely', 'mexican', -73.975393, 40.757365, 0.18447278155869337),
#  ('Sonny S Heros', 'indonesian', -73.9075537, 40.6438684, 0.1875159822181943),
#  ('Carvel Ice Cream',
#   'cajun',
#   -74.0796436,
#   40.59878339999999,
#   0.0210096506901156),
#  ('Golden Pavillion',
#   'russian',
#   -73.92701509999999,
#   40.6620192,
#   0.172341667160483),
#  ('Domino S Pizza', 'colombian', -73.9806854, 40.7778589, 0.19764917046668884),
#  ('Kosher Bagel Hole', 'indian', -73.9615132, 40.6253268, 0.13173572566954528),
#  ('Mejlander & Mulgannon',
#   'french',
#   -74.0228449,
#   40.6281815,
#   0.07121594432331298),
#  ('Plaza Bagels & Deli',
#   'zambian',
#   -74.1178949,
#   40.5734906,
#   0.04858175542083417),
#  ('Texas Rotisserie', 'zambian', -74.0061936, 40.7092038, 0.12791178547811566),
#  ('Philadelhia Grille Express',
#   'colombian',
#   -74.03400479999999,
#   40.6127077,
#   0.058897662603295764),
#  ('Peter Luger Steakhouse',
#   'cajun',
#   -73.96252129999999,
#   40.7098035,
#   0.16109353752135142),
#  ('Palm Restaurant', 'brazilian', -73.9712, 40.751703, 0.18290460664784094),
#  ('21 Club', 'egyptian', -73.9774394, 40.7604522, 0.1855840961893093),
#  ('B & M Hot Bagel & Grocery',
#   'colombian',
#   -74.15235919999999,
#   40.5563756,
#   0.08361823879751588),
#  ('Isle Of Capri Resturant',
#   'malaysian',
#   -73.966032,
#   40.762832,
#   0.19468463103697226),
#  ('Old Town Bar & Restaurant',
#   'chinese',
#   -73.9891878,
#   40.7375638,
#   0.16043289239704098),
#  ('Polish National Home',
#   'mexican',
#   -73.94839189999999,
#   40.7224876,
#   0.17999054477603574),
#  ('Metropolitan Club',
#   'italian',
#   -73.97166039999999,
#   40.764832,
#   0.19261627609255272),
#  ('Seville Restaurant',
#   'french',
#   -74.00310999999999,
#   40.7348888,
#   0.1496600546767302),
#  ('Criminal Court Bldg Cafeteria',
#   'indian',
#   -74.0010484,
#   40.71599000000001,
#   0.13639149439082565),
#  ('Nyac Main Dining Room',
#   'japanese',
#   -73.9788694,
#   40.7665961,
#   0.18957048026782106),
#  ('7B Bar', 'peruvian', -73.98146, 40.7250067, 0.1564712993283158),
#  ('Cafe Atelier (Art Students League)',
#   'korean',
#   -73.9805679,
#   40.7659436,
#   0.1880303176425845),
#  ('Donohue S Steak House',
#   'colombian',
#   -73.965531,
#   40.765431,
#   0.19698727822882606),
#  ('Junior S', 'cajun', -73.9818918, 40.6901211, 0.1339305898794251),
#  ('Tout Va Bien',
#   'italian',
#   -73.98621899999999,
#   40.763406,
#   0.18264515099230902),
#  ('Great Kills Yacht Club',
#   'vietnamese',
#   -74.138263,
#   40.546681,
#   0.0821346559011445),
#  ('Marchis Restaurant',
#   'japanese',
#   -73.9775552,
#   40.7432016,
#   0.17233172308429162),
#  ('Towne Cafe', 'russian', -73.95443709999999, 40.5877993, 0.141086628224306),
#  ('Serendipity 3',
#   'malaysian',
#   -73.96485799999999,
#   40.761899,
#   0.1947472754854418),
#  ('Melody Lanes', 'egyptian', -74.002944, 40.652779, 0.09747693699024951),
#  ('White Horse Tavern',
#   'peruvian',
#   -74.00619499999999,
#   40.735663,
#   0.14845869030812087),
#  ('Crystal Room',
#   'canadian',
#   -74.0707363,
#   40.59321569999999,
#   0.031128613637314027),
#  ('Labetti S Post # 2159',
#   'korean',
#   -74.07444319999999,
#   40.6096914,
#   0.019193782644401754),
#  ('Shell Lanes', 'italian', -73.9727638, 40.588853, 0.12292853119045385),
#  ('Mcsorley S Old Ale House',
#   'zambian',
#   -73.9896713,
#   40.7287978,
#   0.15352158829666798),
#  ('Forlinis Restaurant',
#   'malaysian',
#   -73.99950489999999,
#   40.7169224,
#   0.13812093547168197),
#  ('South Shore Swimming Club',
#   'canadian',
#   -74.2274942,
#   40.5071996,
#   0.1725551544156181),
#  ('Corner Bistro', 'italian', -74.0037823, 40.7380122, 0.15177561278390833),
#  ('Nostrand Donut Shop',
#   'french',
#   -73.94933739999999,
#   40.6509823,
#   0.1479282267893937),
#  ('La Grenouille',
#   'french',
#   -73.97557069999999,
#   40.7596796,
#   0.18615135435245192),
#  ('Angelo Of Mulberry St.',
#   'indonesian',
#   -73.9973041,
#   40.7188698,
#   0.14104398531185866),
#  ('Panchito S', 'zambian', -74.001043, 40.729795, 0.14689861257344106),
#  ('New Corner', 'cajun', -74.0166091, 40.6284767, 0.07740482549364258),
#  ('Old Homestead', 'indian', -74.004758, 40.741207, 0.15381290069757456),
#  ('The Princeton Club',
#   'canadian',
#   -73.98126069999999,
#   40.7547107,
#   0.17871241077603228),
#  ('Le Perigord', 'brazilian', -73.9646207, 40.7550069, 0.18976719364026232),
#  ('Joe & Pat S Pizzeria',
#   'mexican',
#   -74.1220973,
#   40.6129407,
#   0.029325463177574573),
#  ('Keats Restaurant',
#   'vietnamese',
#   -73.97063700000001,
#   40.751495,
#   0.18312459838044068),
#  ('Spain Restaurant & Bar',
#   'vietnamese',
#   -73.9979214,
#   40.7371344,
#   0.1545939146865809),
#  ('Palace Cafe', 'peruvian', -73.9446421, 40.7253944, 0.18473411603267034),
#  ('Donut Pub', 'french', -73.99987229999999, 40.7386361, 0.15460074547201255),
#  ('Moran S Chelsea', 'korean', -74.0056649, 40.7452371, 0.15662683122894283),
#  ('Reben Luncheonette', 'zambian', -73.9590059, 40.7090147, 0.16349640081085),
#  ('J&V Famous Pizza',
#   'canadian',
#   -73.9896898,
#   40.6199526,
#   0.10327628088192536),
#  ('La Parisienne Diner',
#   'french',
#   -73.9799932,
#   40.7660886,
#   0.18849018729313888),
#  ('Joe Allen Restaurant',
#   'italian',
#   -73.989131,
#   40.760039,
#   0.17821189637058496),
#  ('Joyce S Tavern',
#   'chinese',
#   -74.16536339999999,
#   40.5450793,
#   0.10081467079273919),
#  ('Arturo S', 'canadian', -74.0003315, 40.7274874, 0.14555561071703996),
#  ('Barbetta Restaurant',
#   'russian',
#   -73.988948,
#   40.760337,
#   0.17856073387226484),
#  ('Gargiulo S Restaurant',
#   'egyptian',
#   -73.982241,
#   40.576366,
#   0.11720479755112785),
#  ('Il Vagabondo Restaurant',
#   'malaysian',
#   -73.96117869999999,
#   40.7619226,
#   0.19720251277063566),
#  ('Neary S Pub', 'canadian', -73.963506, 40.758273, 0.19293299747063156),
#  ('Mee Sum Coffee Shop', 'indian', -73.9983, 40.715051, 0.13757279785263146),
#  ('Hop Kee Restaurant',
#   'mexican',
#   -73.9990337,
#   40.7143954,
#   0.13659234073640825),
#  ('Nancy Whiskey Pub', 'french', -74.0049219, 40.720699, 0.13739939021411737),
#  ('Fifth Avenue Bingo',
#   'korean',
#   -73.98586209999999,
#   40.67017250000001,
#   0.12032339895075879),
#  ('Denino S Pizzeria Tavern',
#   'canadian',
#   -74.1402105,
#   40.6301893,
#   0.049696946295913404),
#  ('Michael S Restaurant',
#   'egyptian',
#   -73.942849,
#   40.6076256,
#   0.1501911483315944),
#  ('New York Pizza Suprema',
#   'cajun',
#   -73.99532099999999,
#   40.750205,
#   0.1666138592074583),
#  ('Nanni Restaurant', 'canadian', -73.9736776, 40.7535755, 0.1826812101323211),
#  ('Killarney Rose', 'french', -74.0086833, 40.7052024, 0.1232850235188761),
#  ('Blarney Castle', 'italian', -73.9250442, 40.5595462, 0.1767720332871727),
#  ('Three Star Restaurant',
#   'japanese',
#   -73.955074,
#   40.599217,
#   0.1386938717355689),
#  ('Blarney Rock', 'italian', -73.98926, 40.7509054, 0.17078908903194126),
#  ('Desmond S Tavern',
#   'chinese',
#   -73.98306099999999,
#   40.7441419,
#   0.16941273830740405),
#  ('Roll-N-Roaster',
#   'indonesian',
#   -73.9396213,
#   40.5841703,
#   0.15632626047910908),
#  ('Tio Pepe', 'chinese', -74.0016583, 40.7319679, 0.14822169661591447),
#  ('Brennan & Carr',
#   'vietnamese',
#   -73.9420751,
#   40.6002442,
#   0.15151004688354053),
#  ('Blarney Stone', 'indonesian', -74.0137007, 40.7062029, 0.12066896495329878),
#  ('The Riviera Cafe',
#   'vietnamese',
#   -74.0027865,
#   40.7340505,
#   0.14918512121689992),
#  ('Fascati S Pizzeria', 'french', -73.9927131, 40.6984887, 0.1303003184006081),
#  ('Baby Bo S Burritos',
#   'canadian',
#   -73.97598099999999,
#   40.745132,
#   0.1748196914109005),
#  ('Shun Lee Palace Restaurant',
#   'canadian',
#   -73.9690789,
#   40.7594184,
#   0.1901098826404645),
#  ('Li Greci S Staaten Restaurant',
#   'zambian',
#   -74.11223799999999,
#   40.629819,
#   0.024327133596034535),
#  ('Tamaqua', 'russian', -73.9300062, 40.5943553, 0.16416544876049244),
#  ('Richmond County Country Club',
#   'korean',
#   -74.10465599999999,
#   40.58834,
#   0.02926658111224576),
#  ('Patsy S Italian Restaurant',
#   'mexican',
#   -73.9827418,
#   40.7655827,
#   0.18644891936488014),
#  ('Dangerfield S Night Club',
#   'russian',
#   -73.960573,
#   40.760982,
#   0.19690969940813288),
#  ('El Charro Espanol',
#   'malaysian',
#   -74.00065800000002,
#   40.735114,
#   0.15132163782486063),
#  ('Da Vinci Pizza', 'egyptian', -73.9907801, 40.6188665, 0.10214159625080321),
#  ('Mitchell S Restaurant',
#   'canadian',
#   -73.9681178,
#   40.678776,
#   0.14003867017377916),
#  ('Mexico Lindo Restaurant',
#   'peruvian',
#   -73.979839,
#   40.739796,
#   0.1682736456519577),
#  ('Twins Pub', 'japanese', -73.99682299999999, 40.753182, 0.16817431617521936),
#  ('New Floridian Diner',
#   'indian',
#   -73.9270926,
#   40.6142428,
#   0.16576272633919698),
#  ('Narrows Coffee Shop', 'thai', -74.03345, 40.612598, 0.05945655504652451),
#  ('Broome Street Bar',
#   'zambian',
#   -74.0029643,
#   40.7231081,
#   0.14050335282155926),
#  ('Emerald Pub', 'cajun', -74.0084936, 40.7258072, 0.13916875812768129),
#  ('Tap Room', 'russian', -73.9788694, 40.7665961, 0.18957048026782106),
#  ('Cocktail Room (Nyac)',
#   'indonesian',
#   -73.9788694,
#   40.7665961,
#   0.18957048026782106),
#  ('Flame Restaurant Coffee House',
#   'indian',
#   -73.98557920000002,
#   40.7686093,
#   0.1872600502064631),
#  ('Jackson Hole', 'zambian', -73.9629729, 40.7638694, 0.1974713317891251),
#  ('John S Restaurant',
#   'vietnamese',
#   -73.985535,
#   40.730605,
#   0.15765058636110504),
#  ('Grassroot Tavern', 'korean', -73.988991, 40.728848, 0.15401670549976304),
#  ('Buddy S Wonder Bar',
#   'korean',
#   -74.1350211,
#   40.6369042,
#   0.047462158187861356),
#  ('Mr Broadway Kosher Restaurant',
#   'japanese',
#   -73.9870818,
#   40.7523004,
#   0.17322163413904634),
#  ('Ni-Ni S Cafe', 'ecuadorian', -74.1003379, 40.5655379, 0.05014486547613694),
#  ('La Bonne Soupe Bistro',
#   'russian',
#   -73.977035,
#   40.762307,
#   0.18728995627101946),
#  ('Mimis Restaurant & Bar',
#   'ecuadorian',
#   -73.9672945,
#   40.7561212,
#   0.1888014653605552),
#  ('Gray S Papaya',
#   'indian',
#   -73.98185529999999,
#   40.7782266,
#   0.1972914751241253),
#  ('Mcdonald S',
#   'japanese',
#   -73.95802549999999,
#   40.6487475,
#   0.1389575340113074),
#  ('El Greco Diner',
#   'japanese',
#   -73.95006049999999,
#   40.5838274,
#   0.14618135126347007),
#  ('One If By Land Two If By Sea',
#   'malaysian',
#   -74.00259299999999,
#   40.7324849,
#   0.1480579367113188),
#  ('Fiorellos', 'korean', -73.9819129, 40.77151449999999, 0.1917462714898448),
#  ('Lb Spumoni Gardens',
#   'canadian',
#   -73.9812843,
#   40.5947365,
#   0.11341561911809767),
#  ('Roadhouse Restaurant',
#   'vietnamese',
#   -74.1005771,
#   40.6134163,
#   0.00790997616304018),
#  ('Ford Foundation Cafeteria',
#   'french',
#   -73.971128,
#   40.749869,
#   0.18158744210159888),
#  ('Elephant & Castle',
#   'chinese',
#   -74.00066699999999,
#   40.736224,
#   0.1521978817362508),
#  ('Oyster Bar', 'japanese', -73.97705599999999, 40.752998, 0.1800528043047437),
#  ('Cherry Tavern',
#   'cajun',
#   -73.98431219999999,
#   40.7258174,
#   0.1550316039960948),
#  ('Red Flame Diner', 'malaysian', -73.9827221, 40.7561037, 0.1788992365386139),
#  ('Colonnade Diner',
#   'colombian',
#   -74.099018,
#   40.58116500000001,
#   0.03451111648439116),
#  ('Mill Basin Kosher Deli',
#   'indonesian',
#   -73.9181846,
#   40.6157107,
#   0.1746693954436511),
#  ('Maggies Place', 'mexican', -73.977114, 40.756295, 0.18255304543337805),
#  ('Da Silvano Restaurant',
#   'mexican',
#   -74.0062401,
#   40.7397546,
#   0.1517739394473568),
#  ('Benjamin', 'colombian', -73.9765607, 40.7443236, 0.17383098367682503),
#  ('Jimmy S Corner', 'chinese', -73.984838, 40.756594, 0.177993960442486),
#  ('Denny S Pub', 'canadian', -73.9789394, 40.6429349, 0.11726005840937792),
#  ('Maries Crisis Cafe',
#   'french',
#   -74.00340299999999,
#   40.733235,
#   0.1481628141471472),
#  ('Boots & Saddle Bar',
#   'peruvian',
#   -74.00341019999999,
#   40.7335084,
#   0.14837651751743497),
#  ('New Parkway Restaurant',
#   'french',
#   -74.0078144,
#   40.6202393,
#   0.08519249077736092),
#  ('Cafe Riazor', 'zambian', -74.000399, 40.740848, 0.15606095169836715),
#  ('The Brook', 'russian', -73.9714599, 40.759647, 0.188743342673619),
#  ('Il Cortile Restaurant',
#   'cajun',
#   -73.998254,
#   40.7179289,
#   0.13970839310295347),
#  ('Raouls', 'french', -74.002139, 40.7261357, 0.14336419850189458),
#  ('Frost Restaurant',
#   'russian',
#   -73.94347599999999,
#   40.718386,
#   0.18159611326789096),
#  ('Hatsuhana Restaurant',
#   'korean',
#   -73.97691499999999,
#   40.757028,
#   0.18324632736565882),
#  ('La Mangeoire', 'canadian', -73.9668354, 40.7568328, 0.1896382602983948),
#  ('Viand Coffee Shop',
#   'colombian',
#   -73.970169,
#   40.764834,
#   0.19355967096738197),
#  ('Palm Too', 'italian', -73.970668, 40.751453, 0.18307263162198578),
#  ('Nada-Sushi', 'french', -73.9717, 40.756457, 0.18615561851580079),
#  ('The Hytes Bar', 'korean', -73.942599, 40.67096, 0.1602942869755533),
#  ('Jody S Club', 'italian', -74.1018239, 40.630788, 0.018053585123457155),
#  ('Caffe Reggio',
#   'canadian',
#   -74.00041689999999,
#   40.7302678,
#   0.1476591281751733),
#  ('Cafe Un Deux Trois', 'indian', -73.984126, 40.7567949, 0.17858626618587048),
#  ('Dan Tempura', 'indian', -73.9818416, 40.7760336, 0.19549014238247628),
#  ('Knickerbocker Bar & Grill',
#   'ecuadorian',
#   -73.994428,
#   40.7320132,
#   0.15281121374375659),
#  ('Pergola Des Artistes',
#   'russian',
#   -73.9873049,
#   40.7592843,
#   0.17867137006386938),
#  ('Mcdonald S', 'korean', -73.9808063, 40.6895078, 0.13449111121234586),
#  ('El Pote Espanol', 'mexican', -73.9735762, 40.74754, 0.1782182554601007),
#  ('Cafe Capri',
#   'brazilian',
#   -73.94523509999999,
#   40.7177182,
#   0.1797699358854363),
#  ('The River Cafe',
#   'vietnamese',
#   -73.99472279999999,
#   40.703195,
#   0.13185812689418344),
#  ('White Horse Tavern', 'italian', -74.012376, 40.703721, 0.11969338966292262),
#  ('Mudville Saloon',
#   'egyptian',
#   -74.00893959999999,
#   40.7151413,
#   0.1305584892362493),
#  ('White Castle', 'ecuadorian', -73.9321666, 40.6632351, 0.1677351655550228),
#  ('White Castle', 'canadian', -73.993031, 40.6417669, 0.10331716058240542),
#  ('Ferdinando S Restaurant',
#   'thai',
#   -74.00184349999999,
#   40.684236,
#   0.11427866080442058),
#  ('The Cupping Room', 'canadian', -74.0030657, 40.7230087, 0.1403620855237693),
#  ('Mcdonald S', 'malaysian', -73.9308722, 40.656262, 0.16712379079485554),
#  ('Pete S Tavern', 'japanese', -73.9866918, 40.7364597, 0.16122431734428103),
#  ('Villa Mosconi Restaurant',
#   'french',
#   -74.00200099999999,
#   40.7285929,
#   0.14536147355338808),
#  ('Jim Brady S Restaurant',
#   'italian',
#   -74.0075542,
#   40.7077614,
#   0.12592906333964674),
#  ('Volare Restaurant',
#   'italian',
#   -74.00041259999999,
#   40.7315763,
#   0.14868444589213906),
#  ('Sparks Steak House',
#   'korean',
#   -73.97212999999999,
#   40.7528838,
#   0.1831737748501194),
#  ('Bamonte S Restaurant',
#   'egyptian',
#   -73.951199,
#   40.7166026,
#   0.17425375420506917),
#  ('Mcdonald S', 'egyptian', -73.9996841, 40.7543101, 0.1674934311727494),
#  ('Ear Inn', 'italian', -74.0094737, 40.7258405, 0.13860344638117608),
#  ('Greenpoint Tavern',
#   'vietnamese',
#   -73.9581492,
#   40.7177363,
#   0.16933698216435855),
#  ('Mcdonald S', 'indonesian', -74.1680654, 40.5595469, 0.09351676697025962),
#  ('Tony S Pizzeria', 'zambian', -73.922642, 40.701015, 0.19065561559262398),
#  ('Rossini S', 'zambian', -73.9788758, 40.7491708, 0.17595496867062807),
#  ('The Players Club',
#   'zambian',
#   -73.986685,
#   40.73756400000001,
#   0.16206150830164778),
#  ('Cafe Espanol', 'thai', -74.0007509, 40.7287609, 0.1462765315982709),
#  ('Smith & Wollensky', 'cajun', -73.9704988, 40.7552269, 0.18601132619399666),
#  ('Olive Tree Cafe & Comedy Cellar',
#   'mexican',
#   -74.00057799999999,
#   40.730204,
#   0.14750855064708085),
#  ('Perkins Family Restaurant & Bakery',
#   'thai',
#   -74.146976,
#   40.625178,
#   0.0550494539300694),
#  ('Burger King', 'vietnamese', -73.9195106, 40.6527642, 0.1773826320246807),
#  ('Manducatis', 'canadian', -73.9491317, 40.7445755, 0.1934277116753006),
#  ('Mama Lucia',
#   'malaysian',
#   -73.96123879999999,
#   40.635193,
#   0.1331359561712915),
#  ('Mariella Pizza',
#   'japanese',
#   -73.98621539999999,
#   40.7350907,
#   0.16051263704721977),
#  ('Coliseum Bar Restaurant',
#   'russian',
#   -73.9832993,
#   40.76754440000001,
#   0.18770963228149654),
#  ('Kosher Delight', 'chinese', -73.9633849, 40.625169, 0.12985742651697985),
#  ('West Bank Cafe',
#   'malaysian',
#   -73.99283419999999,
#   40.75885830000001,
#   0.17511188356229415),
#  ('The Four Seasons', 'colombian', -73.972235, 40.758066, 0.18703468915952748),
#  ('Dairy Luncheonette', 'russian', -73.984858, 40.631394, 0.1092141499715146),
#  ('Zafi S Luncheonette',
#   'ecuadorian',
#   -73.9828058,
#   40.7150766,
#   0.14866576000950144),
#  ('La Palina Restaurant',
#   'russian',
#   -73.9788552,
#   40.6109657,
#   0.11407350666535859),
#  ('Schaffer S Tavern',
#   'egyptian',
#   -74.1321,
#   40.61266000000001,
#   0.03932408333323334),
#  ('Ty S', 'thai', -74.00529, 40.73302899999999, 0.1468658416140293),
#  ('Mariner Inn', 'canadian', -73.9321411, 40.6094715, 0.16081116768391168),
#  ('Exclusive Catering',
#   'malaysian',
#   -74.1235473,
#   40.6215341,
#   0.03135710292899422),
#  ('Green House Cafe',
#   'japanese',
#   -74.028273,
#   40.62951959999999,
#   0.06616567147668365),
#  ('Water Front Crab House',
#   'colombian',
#   -73.958372,
#   40.7420277,
#   0.18490659768080744),
#  ('La Ripaille Restaurant',
#   'cajun',
#   -74.0060152,
#   40.7372653,
#   0.1498667192252199),
#  ('Marina Cafe', 'french', -74.1408495, 40.5441055, 0.08571385682898575),
#  ('Murals On 54/Randolphs S',
#   'thai',
#   -73.9782725,
#   40.7624022,
#   0.1866023656165404),
#  ('Veterans Of Foreign Wars Post #107 Canteen',
#   'egyptian',
#   -73.931262,
#   40.598023,
#   0.1624930548823567),
#  ('Caruso Pizza #2', 'brazilian', -73.990556, 40.749722, 0.16906243051015357),
#  ('Tropical House Baking Co.',
#   'ecuadorian',
#   -73.933605,
#   40.669476,
#   0.1682688073559736),
#  ('Chen S Chinese',
#   'brazilian',
#   -74.0986428,
#   40.5942955,
#   0.021615347193369265),
#  ('The Greek Corner',
#   'ecuadorian',
#   -73.993539,
#   40.7474898,
#   0.16548344270482154),
#  ('Racquet & Tennis Club',
#   'mexican',
#   -73.97328379999999,
#   40.7588047,
#   0.18692725653133813),
#  ('Casa Pepe', 'indian', -74.031688, 40.6374532, 0.0651143945824605),
#  ('Astro Restaurant',
#   'malaysian',
#   -73.97831029999999,
#   40.7632329,
#   0.18723558701513576),
#  ('Golden Dove Diner',
#   'zambian',
#   -74.1690735,
#   40.5589805,
#   0.09466425069950736),
#  ('Caffe Dante', 'malaysian', -74.0018619, 40.7288849, 0.14567637153094123),
#  ('Korner Pizzeria', 'egyptian', -73.9777137, 40.6433389, 0.11854665024749682),
#  ('Henry S End', 'cajun', -73.992182, 40.699702, 0.13148610497691804),
#  ('Souen Restaurant',
#   'malaysian',
#   -74.0062401,
#   40.7397546,
#   0.1517739394473568),
#  ('Villa Berulia',
#   'canadian',
#   -73.98053949999999,
#   40.7469315,
#   0.17317138964766396),
#  ('Victor S Cafe', 'colombian', -73.9840766, 40.7628868, 0.18348579467250536),
#  ('Petes Pizzeria & Restaurant',
#   'chinese',
#   -74.0282415,
#   40.6309663,
#   0.06652608108359781),
#  ('Keens Steakhouse',
#   'russian',
#   -73.98646339999999,
#   40.7507174,
#   0.17235176436904337),
#  ('Bar 515', 'thai', -73.97752600000001, 40.745973, 0.17442064910152638),
#  ('Il Mulino',
#   'brazilian',
#   -73.99914799999999,
#   40.729735,
#   0.14804389896581938),
#  ('Felidia Restaurant',
#   'italian',
#   -73.9651212,
#   40.7603438,
#   0.19340391508726343),
#  ('Mcdonald S', 'canadian', -73.9216671, 40.6447189, 0.17372578404837885),
#  ('The Malt House', 'ecuadorian', -73.9993545, 40.7286288, 0.1470577783155042),
#  ('Shun Lee', 'egyptian', -73.9812519, 40.7728753, 0.19323877636152767),
#  ('Bridgeview Diner',
#   'thai',
#   -74.0318242,
#   40.62062239999999,
#   0.061276258301238944),
#  ('Pongsri Thai Restaurant',
#   'cajun',
#   -73.9865289,
#   40.7606981,
#   0.18027064732013653),
#  ('Primavera Pizza & Pasta',
#   'canadian',
#   -73.967288,
#   40.757018,
#   0.18947645720247744),
#  ('Victoria Pizza',
#   'korean',
#   -73.9254891,
#   40.59284479999999,
#   0.168839877131129),
#  ('Molly Wee Pub', 'brazilian', -73.9949622, 40.7496446, 0.16637069357792778),
#  ('La Mediterranee Restaurant',
#   'mexican',
#   -73.96864699999999,
#   40.755183,
#   0.18720174753458863),
#  ('Kasteli Ii', 'ecuadorian', -73.995662, 40.748717, 0.16520890320137427),
#  ('El Caribe', 'zambian', -73.91535139999999, 40.6087346, 0.17761645224337996),
#  ('Omen Japanese Cuisine',
#   'italian',
#   -74.0019729,
#   40.7260047,
#   0.1433680142210952),
#  ('Mcdonald S', 'ecuadorian', -73.9917897, 40.6913932, 0.12661452957591848),
#  ('Bar Vetro', 'russian', -73.96607999999999, 40.7602774, 0.1927220122091997),
#  ('Rosie O Grady Restaurant',
#   'peruvian',
#   -73.982506,
#   40.762621,
#   0.1842083342549984),
#  ('Casa Bella', 'italian', -73.9982079, 40.7180815, 0.1398519199519994),
#  ('Raccoon Lodge',
#   'egyptian',
#   -74.0095812,
#   40.71463749999999,
#   0.1297602652875221),
#  ('Chez Napolean',
#   'brazilian',
#   -73.9883256,
#   40.76344890000001,
#   0.18145837888941221),
#  ('Turkey S Nest Tavern',
#   'japanese',
#   -73.9550857,
#   40.72063869999999,
#   0.17353332234063581),
#  ('Agra Restaurant',
#   'mexican',
#   -73.96643449999999,
#   40.7641697,
#   0.1954409171947929),
#  ('Lindy S', 'egyptian', -73.9813814, 40.76306150000001, 0.18523582036640135),
#  ('Gene S Resturant', 'korean', -73.9977952, 40.7353195, 0.1532438081721131),
#  ('Maria Ristorante', 'zambian', -73.9367236, 40.5842786, 0.15914660908145026),
#  ('Cozy Soup & Burger', 'french', -73.993406, 40.730003, 0.15194597636332047),
#  ('Villa Fiorita', 'thai', -73.9977997, 40.6118897, 0.09510820753531576),
#  ('Vegas Diner', 'cajun', -74.0065917, 40.609992, 0.08641364775711477),
#  ('Candle Bar', 'ecuadorian', -73.9801846, 40.7801316, 0.19980657264194113),
#  ('Haagen-Dazs', 'cajun', -73.990556, 40.749722, 0.16906243051015357),
#  ('King S Arms Restaurant',
#   'vietnamese',
#   -74.1069208,
#   40.6302784,
#   0.020679694668920355),
#  ('Blue Note Jazz',
#   'ecuadorian',
#   -74.00064259999999,
#   40.7309096,
#   0.14801945060741592),
#  ('The Water Club', 'indian', -73.9724015, 40.7403386, 0.17374697465570485),
#  ('Marco Polo Ristorante',
#   'russian',
#   -73.9957111,
#   40.6821943,
#   0.11804819485490557),
#  ('Manhattan Monster',
#   'colombian',
#   -74.0023353,
#   40.7333573,
#   0.1489069395662307),
#  ('Chez Jaqueline', 'mexican', -74.001763, 40.7282465, 0.14524037610200016),
#  ('Tripoli Restaurant',
#   'mexican',
#   -73.9946329,
#   40.690043,
#   0.12353337252747254),
#  ('Pj Carney S', 'chinese', -73.980002, 40.7659216, 0.18835118571795717),
#  ('Tomoe Sushi', 'korean', -74.0001023, 40.7276736, 0.14584505516901192),
#  ('Utopia Restaurant', 'cajun', -73.9811382, 40.7788729, 0.19822936536409208),
#  ('Sunset Pizzeria', 'indian', -74.2078085, 40.5427718, 0.13582773546256757),
#  ('Jackson Hole', 'zambian', -73.9774801, 40.7461444, 0.17457960190690003),
#  ('Vesuvio Restaurant & Pizza',
#   'korean',
#   -74.027017,
#   40.632575,
#   0.06811035906527443),
#  ('Johns Cafe & Resturant',
#   'cajun',
#   -73.971606,
#   40.751148,
#   0.1822201408681331),
#  ('Karavas Place', 'peruvian', -74.0014102, 40.7318195, 0.1482576324311549),
#  ('Cafe Luxembourg', 'brazilian', -73.983169, 40.7774031, 0.19587256019261584),
#  ('Red Rose', 'japanese', -73.9940325, 40.681185, 0.11886943810858226),
#  ('Mary Ann S',
#   'egyptian',
#   -74.00141959999999,
#   40.7408836,
#   0.15548729271011555),
#  ('Fiorentino Ristorante',
#   'brazilian',
#   -73.97256639999999,
#   40.59727549999999,
#   0.12160315789408567),
#  ('Il Cantinori Restauraunt',
#   'korean',
#   -73.9932049,
#   40.7321769,
#   0.15372646993417013),
#  ('Andrews Coffee Shop',
#   'indonesian',
#   -73.9896961,
#   40.7516989,
#   0.17115743859388668),
#  ('Kang Suh Korean Restaurant',
#   'cajun',
#   -73.9879627,
#   40.7478473,
#   0.1691692813302115),
#  ('Knights Of Baron Dekalb',
#   'cajun',
#   -73.93825489999999,
#   40.5834295,
#   0.15781293893678305),
#  ('Union Hall', 'brazilian', -74.1092654, 40.6379272, 0.028097858142564516),
#  ('Kosher Hut Of Brooklyn',
#   'thai',
#   -73.965305,
#   40.6064189,
#   0.12784451043518116),
#  ('Terra Blues', 'thai', -73.9992986, 40.7283881, 0.14690766386328916),
#  ('Monte S', 'chinese', -74.001094, 40.729583, 0.14670127308582226),
#  ('Gotham Bar & Grill',
#   'japanese',
#   -73.9938232,
#   40.7340887,
#   0.15479087483224555),
#  ('Delmonico S Kitchen', 'thai', -73.9901605, 40.7526176, 0.17161312469566634),
#  ('Hasaki Restaurant',
#   'malaysian',
#   -73.9888412,
#   40.7296752,
#   0.15472918043110698),
#  ('Cooper Town Diner',
#   'korean',
#   -73.980274,
#   40.73489379999999,
#   0.1643762600281409),
#  ('Restuarant Nippon',
#   'brazilian',
#   -73.9703093,
#   40.7575104,
#   0.18786085180806508),
#  ('Imperial Coffee House',
#   'thai',
#   -74.0082408,
#   40.7148452,
#   0.13078279877140195),
#  ('Mcdonald S', 'cajun', -73.98527039999999, 40.7589099, 0.17958079960277581),
#  ('Rex Manor',
#   'colombian',
#   -74.00290509999999,
#   40.6312541,
#   0.09138326777929433),
#  ('Club 101', 'russian', -73.97775159999999, 40.7510553, 0.17811924713082544),
#  ('The Bitter End', 'zambian', -73.9991763, 40.728369, 0.1469708597882257),
#  ('Arriba Arriba',
#   'malaysian',
#   -73.98819809999999,
#   40.7641429,
#   0.18209935412741932),
#  ('Geido Restaurant',
#   'brazilian',
#   -73.9726244,
#   40.6779037,
#   0.1356340063452046),
#  ('Petrossian Restauraunt',
#   'mexican',
#   -73.97919759999999,
#   40.76604930000001,
#   0.18893623710145263),
#  ('Supernova-Novotel Hotel',
#   'korean',
#   -73.9837907,
#   40.7626833,
#   0.1834917373141914),
#  ('Montero Bar & Grill',
#   'peruvian',
#   -73.9979536,
#   40.6914024,
#   0.12175692221110221),
#  ('Pete S Clam Stop', 'egyptian', -73.9820285, 40.5753606, 0.1177410684867918),
#  ('Porto Bello Restaurant',
#   'egyptian',
#   -73.9991998,
#   40.7286624,
#   0.1471821027985401),
#  ('Burrito Loco', 'indonesian', -74.0015608, 40.7319387, 0.14825869557679208),
#  ('Fit Cafeteria (Building A)',
#   'mexican',
#   -73.9939366,
#   40.7468282,
#   0.16471563593296698),
#  ('Riverhead Gentlemen S Club',
#   'thai',
#   -73.9524969,
#   40.748421,
#   0.19356839826586122),
#  ('Smiling Pizza', 'chinese', -73.9812553, 40.6670051, 0.12306911260791831),
#  ('Gandhi', 'russian', -73.9864626, 40.7266739, 0.15415241389797266),
#  ('Nina S Restaurant Pizzeria',
#   'zambian',
#   -73.94130600000001,
#   40.722332,
#   0.1856359117466175),
#  ('Village Yokocho',
#   'peruvian',
#   -73.98927979999999,
#   40.72983199999999,
#   0.15455103131082482),
#  ('Clark S Restaurant',
#   'korean',
#   -73.9932232,
#   40.6974104,
#   0.12921935768452253),
#  ('Pietros', 'indonesian', -73.9723721, 40.7506241, 0.18131943462966474),
#  ('Miss Lily S 7A', 'vietnamese', -73.9837551, 40.726019, 0.1555658001888966),
#  ('Noho Star Restaurant',
#   'japanese',
#   -73.9950747,
#   40.7257659,
#   0.14765801653448973),
#  ('Rosa Mexicano',
#   'french',
#   -73.9627039,
#   40.75896580000001,
#   0.1939848311540261),
#  ('Duffy S', 'egyptian', -74.1107786, 40.6295647, 0.02302059089271955),
#  ('O Hara S',
#   'indonesian',
#   -74.01268830000001,
#   40.7095273,
#   0.12385042836332372),
#  ('Latourette Golf Course',
#   'mexican',
#   -74.1468129,
#   40.5760984,
#   0.066591546901763),
#  ('Dyker Beach Golf (Grill Room)',
#   'indonesian',
#   -74.0177228,
#   40.615199,
#   0.07513024048970275),
#  ('Glenda S Restaurant',
#   'colombian',
#   -73.94994129999999,
#   40.67140699999999,
#   0.15359644459717225),
#  ('My Father S Place',
#   'indonesian',
#   -74.0054509,
#   40.6018789,
#   0.08839954918901431),
#  ('Santa Fe Grill & Bar',
#   'peruvian',
#   -73.974896,
#   40.675678,
#   0.13259337878642527),
#  ('Sidewalk Bar & Restaurant',
#   'korean',
#   -73.983622,
#   40.72548,
#   0.15527562668365183),
#  ('Mcdonald S', 'malaysian', -74.0054378, 40.653762, 0.0955748087732407),
#  ('Caffe Vivaldi', 'thai', -74.00298049999999, 40.7317316, 0.1472246524486052),
#  ('Regency Hotel', 'mexican', -73.9692185, 40.7645497, 0.19394438886944507),
#  ('Parnell S Pub',
#   'indonesian',
#   -73.96522089999999,
#   40.7558205,
#   0.18996394987118628),
#  ('La Fe Restaurant',
#   'colombian',
#   -74.0042129,
#   40.654029,
#   0.09680340795659555),
#  ('Ocean Dragon Restaurant',
#   'brazilian',
#   -73.98866199999999,
#   40.769442,
#   0.18620079355900107),
#  ('Cha Cha S Backyard Garden Bar & Cafe',
#   'japanese',
#   -73.99849569999999,
#   40.7176369,
#   0.13932985974335318),
#  ('O Sullivan S Pub',
#   'canadian',
#   -74.0321699,
#   40.6213165,
#   0.060998547899606986),
#  ('Spring St. Natural Restaurant',
#   'korean',
#   -73.997387,
#   40.722304,
#   0.14353380314406836),
#  ('Pizza Wagon', 'japanese', -74.0263399, 40.6213638, 0.06680542660181962),
#  ('Russian Turkish Baths',
#   'japanese',
#   -73.98357949999999,
#   40.7281865,
#   0.15724027821300327),
#  ('Tortilla Flats', 'korean', -74.0079669, 40.737446, 0.14889276543274388),
#  ('Cornelia Street Cafe',
#   'russian',
#   -74.0024972,
#   40.7314926,
#   0.14733132687993516),
#  ('Le Bernardin', 'peruvian', -73.9817017, 40.7614715, 0.1837745367071831),
#  ('The Grotto', 'french', -74.0122263, 40.7058609, 0.12138531297031319),
#  ('Tony S Pizzeria', 'japanese', -73.9314602, 40.6704278, 0.17060620744298885),
#  ('Canlon S Restaurant',
#   'brazilian',
#   -74.1268188,
#   40.5651822,
#   0.060395027238004335),
#  ('Real Madrid Restaurant',
#   'italian',
#   -74.158427,
#   40.626607,
#   0.0665723491548833),
#  ('Cousin John S Cafe And Bakery',
#   'malaysian',
#   -73.975144,
#   40.675441,
#   0.13226454960041573),
#  ('Russian Samovar', 'vietnamese', -73.984752, 40.763105, 0.18326235417292158),
#  ('Flash Dancers',
#   'russian',
#   -73.982872,
#   40.76280939999999,
#   0.18414039170034585),
#  ('Pizza D Oro',
#   'canadian',
#   -74.16303719999999,
#   40.60731,
#   0.07061751659919834),
#  ('Josie S Restaurant',
#   'chinese',
#   -73.9809789,
#   40.7802374,
#   0.19944733590542219),
#  ('La Mela Restaurant',
#   'brazilian',
#   -73.99735199999999,
#   40.719931,
#   0.1417941363421019),
#  ('Pj Morans', 'french', -73.97746699999999, 40.757261, 0.18307842198359378),
#  ('Frankie & Johnnies Steakhouse',
#   'ecuadorian',
#   -73.9880305,
#   40.7591348,
#   0.1781227978016608),
#  ('Friend Of A Farmer',
#   'brazilian',
#   -73.9868393,
#   40.73691240000001,
#   0.16146841704077214),
#  ('Sancho S Restaurant',
#   'cajun',
#   -74.02778909999999,
#   40.6318755,
#   0.06718648936699669),
#  ('India Passage Restaurant',
#   'vietnamese',
#   -74.0272951,
#   40.6318285,
#   0.06765337248548717),
#  ('Irene S Place',
#   'french',
#   -73.95097100000001,
#   40.723595,
#   0.17859762204463678),
#  ('Veselka Restaurant',
#   'ecuadorian',
#   -73.9871139,
#   40.7290155,
#   0.1554114358696356),
#  ('J & R Pizza', 'italian', -73.9541457, 40.6102692, 0.13879212887095593),
#  ('Chez Josephine', 'russian', -73.9935579, 40.7585089, 0.17441217489160943),
#  ('Mishima Restaurant',
#   'malaysian',
#   -73.9816053,
#   40.7441474,
#   0.17036391241178908),
#  ('Rocco S Calamari', 'japanese', -74.009029, 40.631093, 0.0853321027515501),
#  ('Grand Canyon', 'russian', -73.993645, 40.694843, 0.1272706743440937),
#  ('Cappuccino Cafe',
#   'ecuadorian',
#   -74.0283135,
#   40.6294318,
#   0.06610708023268849),
#  ('Carol S Cafe', 'chinese', -74.1013145, 40.5912425, 0.025333372150190128),
#  ('Pangea Restaurant', 'italian', -73.985889, 40.730473, 0.1573130039125863),
#  ('Cafe Edison', 'french', -73.98635039999999, 40.7596825, 0.179557319786778),
#  ('Automatic Slims',
#   'egyptian',
#   -74.00834669999999,
#   40.7362217,
#   0.1476708985554786),
#  ('De Robertis Pastry Shop',
#   'egyptian',
#   -73.98384999999999,
#   40.7290629,
#   0.15768452867866734),
#  ('Cloister Cafe',
#   'italian',
#   -73.98789909999999,
#   40.7292983,
#   0.1550863532374881),
#  ('Dairy Palace', 'indian', -74.1369752, 40.6118922, 0.044240181761370546),
#  ('200 Fifth Avenue Restaurant & Sports Bar',
#   'colombian',
#   -73.9804898,
#   40.6768216,
#   0.12818912884718545),
#  ('Jimbo S Hamburger Place',
#   'peruvian',
#   -73.964379,
#   40.7567359,
#   0.19120760596276767),
#  ('Lattanzi', 'indonesian', -73.98997, 40.760897, 0.17842520524018052),
#  ('Sushiden', 'canadian', -73.9763347, 40.7575454, 0.18401419496944013),
#  ('Salumeria Beillese/ Biricchino Rest',
#   'chinese',
#   -73.99556,
#   40.748852,
#   0.16537807657002418),
#  ('Academy Restauraunt',
#   'thai',
#   -73.97574639999999,
#   40.687295,
#   0.13756104840965258),
#  ('Trattoria Alba', 'french', -73.9765199, 40.7452545, 0.1745511901359059),
#  ('Park Plaza Restaurant',
#   'peruvian',
#   -73.9917184,
#   40.6979881,
#   0.1307484744827718),
#  ('Sam S Place', 'peruvian', -73.9772263, 40.7493346, 0.17715198045139208),
#  ('Ray S Pizza',
#   'vietnamese',
#   -73.98164460000001,
#   40.7632783,
#   0.18525089412429108),
#  ('Hunter S Steak & Ale House',
#   'thai',
#   -74.031194,
#   40.616655,
#   0.06167807906380294),
#  ('Dakota Diner', 'ecuadorian', -74.1485484, 40.6248044, 0.056530927966193384),
#  ('Primola Restaurant',
#   'cajun',
#   -73.96160050000002,
#   40.7639308,
#   0.19842271879068032),
#  ('Country Donuts',
#   'vietnamese',
#   -74.1603346,
#   40.5454655,
#   0.09698275629620753),
#  ('Sally & George S Place',
#   'peruvian',
#   -74.02853089999999,
#   40.6289779,
#   0.06579776763706818),
#  ('Winnie S Bar', 'indian', -73.99976319999999, 40.7162194, 0.137428517224783),
#  ('Pizza Plus', 'korean', -73.9821078, 40.6658524, 0.12181204484369375),
#  ('Niles Restaurant', 'mexican', -73.9916396, 40.7487243, 0.16761263111845262),
#  ('Arirang Hibachi Steak House',
#   'malaysian',
#   -74.1504413,
#   40.5493122,
#   0.08744833019748845),
#  ('Tina S Restaurant',
#   'vietnamese',
#   -73.9310977,
#   40.70359879999999,
#   0.18437217298424047),
#  ('Karavas Pizza N Pita',
#   'japanese',
#   -74.00318299999999,
#   40.733443,
#   0.14846145824422585),
#  ('China Grill', 'egyptian', -73.9787406, 40.7611474, 0.18532498301826822),
#  ('New York University - Law School',
#   'french',
#   -73.9999854,
#   40.7300989,
#   0.14779820235094496),
#  ('Westside Restaurant',
#   'korean',
#   -73.981751,
#   40.7763588,
#   0.19580930149724485),
#  ('Club Metropolitan', 'cajun', -73.9792691, 40.7649292, 0.18799946576107776),
#  ('Rocco S Pizzeria',
#   'peruvian',
#   -74.0239115,
#   40.6269162,
#   0.06994324245623021),
#  ('Periyali', 'peruvian', -73.992869, 40.740758, 0.16056604879301428),
#  ('El Azteca Mexican Restaurant',
#   'japanese',
#   -73.988231,
#   40.76503200000001,
#   0.18280883678040385),
#  ('Lupe S East L.A. Kitchen',
#   'cajun',
#   -74.0045136,
#   40.7236625,
#   0.13994679994416426),
#  ('Arno Ristorante',
#   'canadian',
#   -73.9879785,
#   40.75331250000001,
#   0.17348069466803237),
#  ('T & G Whitney S', 'french', -73.967893, 40.75682, 0.18892752102591914),
#  ('Pellegrino S',
#   'peruvian',
#   -73.99741519999999,
#   40.7186078,
#   0.14077603291427954),
#  ('Da Umberto Restaurant',
#   'thai',
#   -73.99582699999999,
#   40.739672,
#   0.15788285618458348),
#  ('Teddy S Bar And Grill',
#   'thai',
#   -73.9585056,
#   40.7193481,
#   0.17003679678578923),
#  ('Live Bait Bar & Restaurant',
#   'ecuadorian',
#   -73.9883909,
#   40.740735,
#   0.16337443904237595),
#  ('Jimmy Max Restaurant',
#   'indonesian',
#   -74.1386716,
#   40.6160213,
#   0.04582744424522345),
#  ('T.G.I. Friday S', 'brazilian', -73.9932633, 40.752437, 0.1696283944453037),
#  ('Tal Bagels Deli', 'italian', -73.9641006, 40.7566992, 0.1913676232307913),
#  ('Peculiar Pub',
#   'mexican',
#   -73.99905799999999,
#   40.72837800000001,
#   0.14705322190963815),
#  ('Nostrand Island Eatery',
#   'zambian',
#   -73.9497152,
#   40.653664,
#   0.14823627301656386),
#  ('Areo Restaurant',
#   'indian',
#   -73.98010790000001,
#   40.6862191,
#   0.13329065007576332),
#  ('Giando', 'peruvian', -73.9685372, 40.7103536, 0.15660033918354213),
#  ('Trattoria Della Arte',
#   'chinese',
#   -73.9805746,
#   40.7652002,
#   0.1874305348101049),
#  ('Rosebank Tavern', 'chinese', -74.065258, 40.612447, 0.027724254742017472),
#  ('Green Pavilion Restaurant & Sports Lounge',
#   'ecuadorian',
#   -73.976152,
#   40.63089799999999,
#   0.1177626304478674),
#  ('Tre Giovani Pizza & Pasta',
#   'cajun',
#   -73.9983829,
#   40.7290603,
#   0.1480093371328357),
#  ('Westway Diner', 'brazilian', -73.9916209, 40.7593916, 0.17624399023731416),
#  ('Rocking Horse Cafe',
#   'thai',
#   -73.9998818,
#   40.74289419999999,
#   0.15801783022076296),
#  ('Luigi S Pizza',
#   'french',
#   -73.94838039999999,
#   40.6325077,
#   0.1455150490074963),
#  ('Sob S', 'vietnamese', -74.0051398, 40.7281648, 0.14308216580930608),
#  ('Walker S Restaurant',
#   'chinese',
#   -74.007032,
#   40.7196857,
#   0.13527387230020127),
#  ('Holland Bar', 'korean', -73.993494, 40.756672, 0.17294188758655693),
#  ('Amnon Kosher Pizza',
#   'colombian',
#   -73.992091,
#   40.6354339,
#   0.10278907797237334),
#  ('T.G.I. Friday S',
#   'malaysian',
#   -73.97817599999999,
#   40.757775,
#   0.1830327239730738),
#  ('Angelica Kitchen', 'russian', -73.985568, 40.7307496, 0.15773409385088935),
#  ('Cowgirl Hall Of Fame',
#   'malaysian',
#   -74.00660599999999,
#   40.733932,
#   0.14681484506003709),
#  ('Yip S', 'malaysian', -73.9788903, 40.7605367, 0.18475178699482367),
#  ('Lee S Villa Chinese Restaurant',
#   'indian',
#   -73.986446,
#   40.6915505,
#   0.13101113738629377),
#  ('Puttin On A Bagel', 'thai', -74.1064605, 40.634613, 0.023771876666552172),
#  ('Champ S Deli', 'thai', -74.01229450000001, 40.7074764, 0.12255281241737516),
#  ('Bennys Burritos',
#   'peruvian',
#   -74.00148399999999,
#   40.7371583,
#   0.15245129304893246),
#  ('Brooklyn Botanic Catering Hall',
#   'french',
#   -73.9619036,
#   40.6675708,
#   0.14106284727170829),
#  ('The Cornell Center Of New York',
#   'japanese',
#   -73.97937,
#   40.754292,
#   0.17957438160829012),
#  ('Queen Bee S Tavern',
#   'egyptian',
#   -73.94875979999999,
#   40.6509995,
#   0.1484928181714317),
#  ('White Castle', 'zambian', -73.9431862, 40.7146566, 0.1797428348769454),
#  ('T.G.I. Friday S', 'french', -73.9786446, 40.7527136, 0.1788163365168899),
#  ('Yama Japanese Restaurant ',
#   'mexican',
#   -73.9876443,
#   40.7358217,
#   0.1601172368490704),
#  ('Chadwick S',
#   'vietnamese',
#   -74.03208579999999,
#   40.6215814,
#   0.06110965033447462),
#  ('2A', 'brazilian', -73.9860427, 40.7229989, 0.15180935904779064),
#  ('Teresa S Resturant',
#   'colombian',
#   -73.99624560000001,
#   40.6951645,
#   0.1254589639165273),
#  ('La Rivista Restaurant',
#   'colombian',
#   -73.988568,
#   40.760303,
#   0.17875450861167233),
#  ('Pax Wholesome Foods',
#   'cajun',
#   -73.9848522,
#   40.7533144,
#   0.17538981898673445),
#  ('Dallas Bbq',
#   'chinese',
#   -73.9874091,
#   40.72863479999999,
#   0.15493159405895612),
#  ('Sakebar Decibel',
#   'chinese',
#   -73.98779019999999,
#   40.7292837,
#   0.15514932811692442),
#  ('El Castillo De Jagua Rest',
#   'russian',
#   -73.987875,
#   40.719752,
#   0.14821614839483613),
#  ('Benny S Burritos', 'chinese', -73.9842265, 40.7253886, 0.15478585242847615),
#  ('Guayoyo', 'thai', -73.987292, 40.725414, 0.15266849894461376),
#  ('Sacco Pizza',
#   'malaysian',
#   -73.98724899999999,
#   40.766272,
#   0.18438771547205232),
#  ('Rivoli Pizza Restaurant',
#   'vietnamese',
#   -74.0017238,
#   40.7359904,
#   0.15137352129418574),
#  ('Campeon', 'zambian', -73.991669, 40.737153, 0.15852448038079178),
#  ('Townhouse Of Ny', 'cajun', -73.9657113, 40.7601715, 0.19288509384901023),
#  ('Lucky Strike', 'colombian', -74.0034907, 40.722135, 0.1394188540237322),
#  ('Ah! Chihuahua',
#   'ecuadorian',
#   -73.9660459,
#   40.75609439999999,
#   0.18961418754399145),
#  ('Champ Gourmet',
#   'cajun',
#   -74.01153459999999,
#   40.7061121,
#   0.12203303838621651),
#  ('Classic Coffee Shop',
#   'french',
#   -73.9907994,
#   40.7156752,
#   0.1432692723880475),
#  ('Da Tommasso',
#   'russian',
#   -73.98482229999999,
#   40.7645702,
#   0.18440633265463796),
#  ('Queen', 'russian', -73.9918113, 40.6913309, 0.1265597645260978),
#  ('Pomodoro Ristorante',
#   'japanese',
#   -73.99638569999999,
#   40.72209369999999,
#   0.14404547377331856),
#  ('Haveli', 'indonesian', -73.988342, 40.727111, 0.1531806424487121),
#  ('Barfly', 'chinese', -73.9847137, 40.7371804, 0.1630723929205998),
#  ('Kum Kau Kitchen', 'cajun', -73.9667463, 40.6935651, 0.1485138936588152),
#  ('Taste Of India Ii Restaurant',
#   'korean',
#   -74.1126424,
#   40.5722235,
#   0.04724209837221387),
#  ('Stage Door Deli',
#   'colombian',
#   -74.0097128,
#   40.7121042,
#   0.12774206017706075),
#  ('Han Bat Restaurant',
#   'peruvian',
#   -73.9862347,
#   40.75015459999999,
#   0.17205096635546063),
#  ('Dennis  Place', 'egyptian', -73.9105112, 40.6699158, 0.1903969593619624),
#  ('O Flanagan S',
#   'chinese',
#   -73.9592335,
#   40.76383930000001,
#   0.19992824596625688),
#  ('Danny Blaine', 'french', -74.0631248, 40.6097835, 0.030203555775612147),
#  ('The Edge Bar', 'mexican', -73.9877595, 40.7248378, 0.15192899639138088),
#  ('Cafe Luna', 'korean', -74.085013, 40.5966165, 0.02009681865992679),
#  ('Killarney S Pub', 'colombian', -74.020889, 40.633037, 0.07416063883220794),
#  ('Daniel S Bagel', 'russian', -73.9761439, 40.7478596, 0.17674996450571342),
#  ('Scotty S Diner',
#   'french',
#   -73.977572,
#   40.74978100000001,
#   0.17726540711883207),
#  ('A & S Pizzeria', 'italian', -74.0775165, 40.643984, 0.032684568243288456),
#  ('Solera Restaurant',
#   'egyptian',
#   -73.96875399999999,
#   40.757204,
#   0.18864819291475776),
#  ('Little Pie Company',
#   'korean',
#   -73.99331699999999,
#   40.7594404,
#   0.17531544288043505),
#  ('Malachy S', 'russian', -73.97894699999999, 40.777789, 0.19858362233578605),
#  ('Lazzaras Pizza Cafe', 'cajun', -73.989497, 40.754057, 0.17316372262111182),
#  ('Bello Restaurant', 'cajun', -73.986521, 40.767623, 0.18591222183600897),
#  ('Pronto Pizza', 'malaysian', -73.979771, 40.757729, 0.18200159446554318),
#  ('Grotto Azzura Pizzeria',
#   'egyptian',
#   -73.9953713,
#   40.6036019,
#   0.09815992817693282),
#  ('The Palace Theater', 'thai', -73.9852422, 40.7589981, 0.17966831713201406),
#  ('Bay Ridge Manor Catering',
#   'mexican',
#   -74.02357789999999,
#   40.6288524,
#   0.0706228774971094),
#  ('The Beekman', 'malaysian', -74.0063787, 40.7108898, 0.1290328160350306),
#  ('Szechuan Delight Restaurant',
#   'japanese',
#   -73.9771312,
#   40.67257840000001,
#   0.12920095901347617),
#  ('Tea And Sympathy', 'cajun', -74.0019453, 40.7382932, 0.1530869059460352),
#  ('Collado Restaurant',
#   'ecuadorian',
#   -73.92396529999999,
#   40.6903438,
#   0.18488246225949695),
#  ('Taka Hashi Restaurant',
#   'indonesian',
#   -73.98443,
#   40.725358,
#   0.1546212892780291),
#  ('Bar Association Of The City Of Ny Kitchen',
#   'russian',
#   -73.9821691,
#   40.7554761,
#   0.17874697148545732),
#  ('Bel Paese Italian Deli',
#   'canadian',
#   -73.9743584,
#   40.7534139,
#   0.18211506368109753),
#  ('Mcdonald S', 'malaysian', -73.9890844, 40.7483602, 0.16888045109663083),
#  ('Tokya', 'korean', -73.9715774, 40.7626541, 0.19098111621563552),
#  ('Orso', 'chinese', -73.989025, 40.759994, 0.1782370323838472),
#  ('Lily S Bar @ Roger Smith Hotel',
#   'japanese',
#   -73.9733955,
#   40.75470989999999,
#   0.18372576114812622),
#  ('Hillside Swimming Club',
#   'russian',
#   -74.16906999999999,
#   40.60375,
#   0.07706056533660967),
#  ('The Nippon Club',
#   'thai',
#   -73.97866499999999,
#   40.765296,
#   0.18865691073746044),
#  ('La Strada Restaurant',
#   'mexican',
#   -74.11556999999999,
#   40.573835,
#   0.04712319901067113),
#  ('Walter S Bar', 'italian', -73.995856, 40.7493849, 0.16563578373108417),
#  ('Salvatore And Lloyd S Pizza',
#   'malaysian',
#   -74.1651864,
#   40.5438954,
#   0.10151456472309497),
#  ('Novecento', 'thai', -74.0033499, 40.72255, 0.13982773312404623),
#  ('Sutton Cafe Restaurant',
#   'egyptian',
#   -73.9630363,
#   40.7577488,
#   0.19286022122701077),
#  ('Fay Da Bakery',
#   'brazilian',
#   -73.99978949999999,
#   40.7186898,
#   0.13923832577883188),
#  ('Cambridge Caterers',
#   'korean',
#   -73.9890601,
#   40.7538643,
#   0.17327050927754228),
#  ('Cafe Bella Vita',
#   'malaysian',
#   -74.0969897,
#   40.5830445,
#   0.032342141845277644),
#  ('Charle S Corner Restaurant & Deli',
#   'italian',
#   -73.9549067,
#   40.6971322,
#   0.1604837020046965),
#  ('Tartine',
#   'peruvian',
#   -74.00345709999999,
#   40.73635100000001,
#   0.15062649115217147),
#  ('Ipanema Bar', 'brazilian', -74.0022315, 40.7393829, 0.15379621599331447),
#  ('Henrietta Hudson',
#   'ecuadorian',
#   -74.0064209,
#   40.7310687,
#   0.14461803845199148),
#  ('Lucys', 'colombian', -73.9830854, 40.7270359, 0.15676055260100208),
#  ('Sal S Pizzeria',
#   'ecuadorian',
#   -73.9492258,
#   40.7131675,
#   0.17390195151893037),
#  ('Gabriel S Bar & Grill',
#   'japanese',
#   -73.9828696,
#   40.7693649,
#   0.1894400405478476),
#  ('Jaiya Thai Oriental Restaurant',
#   'korean',
#   -73.9809909,
#   40.7422324,
#   0.16932346980372076),
#  ('Dojo Restaurant', 'canadian', -73.9948902, 40.7286803, 0.14997474720875717),
#  ('Bergen Beach Cafe',
#   'colombian',
#   -73.906922,
#   40.619872,
#   0.18599169003480767),
#  ('El Cantinero', 'french', -73.9932394, 40.7336411, 0.15482210245624453),
#  ('Molly S', 'french', -73.9832361, 40.7382721, 0.1648698219712195),
#  ('Azuri Cafe',
#   'mexican',
#   -73.99076149999999,
#   40.7653444,
#   0.18163079111156039),
#  ('Amelia S Restaurant',
#   'canadian',
#   -74.00577439999999,
#   40.72448929999999,
#   0.13980024185547393),
#  ('National Restaurant & Catering',
#   'russian',
#   -73.9649155,
#   40.5771957,
#   0.13344036977744317),
#  ('Patrick Conways',
#   'cajun',
#   -73.9784822,
#   40.75316000000001,
#   0.17926361988323916),
#  ('Metrostar Cafe',
#   'chinese',
#   -73.98694499999999,
#   40.692606,
#   0.1312266348307471),
#  ('Scalinatella Ristaurant',
#   'colombian',
#   -73.9652191,
#   40.7627652,
#   0.19516460289419835),
#  ('Amsterdam Billiards',
#   'italian',
#   -73.9899313,
#   40.731505,
#   0.15536444827209114),
#  ('Yen Yen Restaurant',
#   'peruvian',
#   -73.97635439999999,
#   40.6438997,
#   0.12000057239718939),
#  ('Buddy S Burrito & Taco Bar',
#   'french',
#   -73.9947256,
#   40.6852794,
#   0.1206283039809542),
#  ('V & S Pizzeria Of Sheapshead Bay',
#   'thai',
#   -73.9510102,
#   40.5836641,
#   0.14528907897516558),
#  ('Court Square Diner', 'cajun', -73.945866, 40.746087, 0.19686866516793156),
#  ('Davis Polk Dining Room',
#   'brazilian',
#   -73.97490839999999,
#   40.7532711,
#   0.18164905394516337),
#  ('White Castle', 'peruvian', -73.9605993, 40.6805698, 0.14756214482424557),
#  ('Mcdonald S', 'french', -73.9972555, 40.7476408, 0.16340250731947578),
#  ('Bella Napoli', 'indian', -73.984758, 40.7457939, 0.16958754618017025),
#  ('Cody S Ale House Grill',
#   'brazilian',
#   -73.9931261,
#   40.6887559,
#   0.12396593516616046),
#  ('Down The Hatch',
#   'vietnamese',
#   -74.0015476,
#   40.7323956,
#   0.14862707651811163),
#  ('J.J. Bubbles', 'french', -74.029397, 40.628295, 0.06480909050434405),
#  ('Faros Restaurant',
#   'vietnamese',
#   -73.97977759999999,
#   40.6428602,
#   0.11642812934082158),
#  ('Fitzgerald S Pub',
#   'french',
#   -73.98257989999999,
#   40.7400916,
#   0.16666675567722747),
#  ('Pasta Lovers Trattoria',
#   'vietnamese',
#   -73.982976,
#   40.7599775,
#   0.18181408284632783),
#  ('Don Giovanni Restaurant',
#   'indian',
#   -74.0042175,
#   40.7473469,
#   0.15918523955147423),
#  ('Tribeca Grill', 'mexican', -74.0099723, 40.7196029, 0.13336295535155127),
#  ('Shabu Tatsu',
#   'ecuadorian',
#   -73.98588629999999,
#   40.7292211,
#   0.1563991935046406),
#  ('Indo Chine', 'brazilian', -73.992465, 40.729258, 0.1520033069146911),
#  ('San Pietro', 'indian', -73.97443109999999, 40.7604984, 0.1875055594652435),
#  ('Muldoons Bar', 'brazilian', -73.9739876, 40.7518635, 0.18118359369272416),
#  ('Tony S Pizza Ii',
#   'french',
#   -73.92329939999999,
#   40.6648509,
# ...
#  ('Womens Natl. Republican Club',
#   'thai',
#   -73.97731999999999,
#   40.759653,
#   0.18503343782409318),
#  ('The Century Association',
#   'mexican',
#   -73.9810658,
#   40.7546367,
#   0.17877642078957495),
#  ('Regency Whist Club', 'indian', -73.9681307, 40.7690148, 0.1980882474952265),
#  ('Harvard Club', 'cajun', -73.982706, 40.755661, 0.17856050293668824),
#  ('The River Club', 'colombian', -73.9632744, 40.7544774, 0.19029140758037313),
#  ('Friars National Assoc.',
#   'ecuadorian',
#   -73.972492,
#   40.760894,
#   0.1890411009542638),
#  ('Knickerbocker Club',
#   'korean',
#   -73.9714139,
#   40.7659585,
#   0.19364763467458437),
#  ('Anglers Club Of New York',
#   'indonesian',
#   -74.0112941,
#   40.7032931,
#   0.12010900627189025),
#  ('Down Town Association',
#   'vietnamese',
#   -74.0081545,
#   40.7067097,
#   0.12474905157931857),
#  ('The Union League Club',
#   'japanese',
#   -73.9806258,
#   40.7492531,
#   0.17488957850669712),
#  ('Lotos Club Grill Room',
#   'indian',
#   -73.96894800000001,
#   40.768529,
#   0.19719650982965709),
#  ('Madison Square', 'thai', -73.9860597, 40.7431194, 0.16669852827019896),
#  ('Yale Club', 'ecuadorian', -73.9774365, 40.7539873, 0.1805680418787919),
#  ('The Webster Apartments',
#   'italian',
#   -73.9971942,
#   40.7540962,
#   0.1687148844426036),
#  ('Island Chateau',
#   'vietnamese',
#   -74.08587059999999,
#   40.6011805,
#   0.015591390252645316),
#  ('The University Club',
#   'russian',
#   -73.9755498,
#   40.76125469999999,
#   0.18739023188503717),
#  ('The University Club',
#   'japanese',
#   -73.9755498,
#   40.76125469999999,
#   0.18739023188503717),
#  ('Harmonie Club',
#   'russian',
#   -73.97198209999999,
#   40.764464,
#   0.19212783795122407),
#  ('Columbus Citizens Foundation',
#   'chinese',
#   -73.96784099999999,
#   40.76997100000001,
#   0.19901387550622268),
#  ('Glen Terrace', 'french', -73.923354, 40.6193776, 0.16955243921737195),
#  ('The Tap Room',
#   'italian',
#   -73.9755498,
#   40.76125469999999,
#   0.18739023188503717),
#  ('The University Club',
#   'canadian',
#   -73.9755498,
#   40.76125469999999,
#   0.18739023188503717),
#  ('Simpson Thacher And Bartlet Cafe',
#   'french',
#   -73.9749375,
#   40.7522452,
#   0.1808510751029446),
#  ('Cleary Gottlieb', 'peruvian', -74.0109533, 40.7096139, 0.1250458676266477),
#  ('Black Rock Cafe', 'italian', -73.9787406, 40.7611474, 0.18532498301826822),
#  ('Princess Manor', 'russian', -73.9501963, 40.7237308, 0.179295908238114),
#  ('Bank Of New York Cafe',
#   'chinese',
#   -74.0116385,
#   40.707491,
#   0.12299598330941298),
#  ('Cafe 101 16Th Floor Cafeteria',
#   'chinese',
#   -74.01231039999999,
#   40.7143002,
#   0.12776393907281278),
#  ('Cbs Employee Cafeteria',
#   'brazilian',
#   -73.989637,
#   40.769262,
#   0.18550738674510872),
#  ('P.S. Gourmet (Cafe On 8)',
#   'vietnamese',
#   -73.97395569999999,
#   40.7635384,
#   0.19016911571034179),
#  ('Credit Agricole',
#   'ecuadorian',
#   -73.9801263,
#   40.7616971,
#   0.1849104161049385),
#  ('Good Shepherd Services',
#   'vietnamese',
#   -73.9818651,
#   40.7337096,
#   0.162424043775457),
#  ('Ing Forman Selz', 'korean', -73.9758568, 40.7544956, 0.18197084914787764),
#  ('Cravath Cafe', 'cajun', -73.9866514, 40.7620624, 0.18130238519258363),
#  ('Patterson Employee Cafeteria',
#   'french',
#   -73.9836468,
#   40.7559068,
#   0.1781758558281102),
#  ('Morgan Stanley Cafeteria',
#   'italian',
#   -73.9837606,
#   40.7608268,
#   0.1820201414442927),
#  ('Mutual Of America', 'cajun', -73.9741793, 40.7575374, 0.18538036050415113),
#  ('Culinart Cafe', 'indian', -73.9793564, 40.7589426, 0.18321061879192424),
#  ('Holtermann S Bakery',
#   'mexican',
#   -74.15565029999999,
#   40.5644155,
#   0.0807127537477078),
#  ('Lords Bakery',
#   'indian',
#   -73.94741479999999,
#   40.6333318,
#   0.1465738832667142),
#  ('La Delice Pastry Shop',
#   'indian',
#   -73.98171889999999,
#   40.7413831,
#   0.16820495260016252),
#  ('Buono Bakery',
#   'peruvian',
#   -74.07979739999999,
#   40.5987581,
#   0.0209330644620071),
#  ('The Penn Club',
#   'ecuadorian',
#   -73.98174999999999,
#   40.7552949,
#   0.1788647501611576),
#  ('Lazard Freres', 'egyptian', -73.9793564, 40.7589426, 0.18321061879192424),
#  ('Aliotta Bake Shop',
#   'mexican',
#   -73.9309557,
#   40.6185564,
#   0.16193374484786116),
#  ('Allan S Bakery', 'mexican', -73.9503455, 40.6606412, 0.14960105669510523),
#  ('Zaro S Bakery',
#   'ecuadorian',
#   -73.97729919999999,
#   40.7524958,
#   0.1795118836441823),
#  ('Circo Pastry Shop',
#   'indonesian',
#   -73.9234069,
#   40.7014034,
#   0.1901489767392128),
#  ('Alfonso S Pastry Shoppe',
#   'mexican',
#   -74.127349,
#   40.612969,
#   0.03456306004970229),
#  ('Lung Moon Bakery', 'chinese', -73.9991491, 40.7165692, 0.13810198462893858),
#  ('Angel Flakes Patties',
#   'indonesian',
#   -73.9477753,
#   40.63385239999999,
#   0.14628193457583868),
#  ('Highway Bagels', 'indonesian', -73.9539362, 40.6107492, 0.1389855746380938),
#  ('Renato S Pastry Shop',
#   'thai',
#   -74.1434262,
#   40.6246952,
#   0.05147148593035485),
#  ('The Cake Chef', 'chinese', -74.1305762, 40.6129841, 0.03778367583823865),
#  ('Manna House',
#   'french',
#   -73.9971473,
#   40.71819740000001,
#   0.14065676396623553),
#  ('Manna One Bakery',
#   'ecuadorian',
#   -73.9968312,
#   40.7126429,
#   0.13686017336993936),
#  ('Amy S Bread', 'chinese', -73.990218, 40.7612, 0.17853015842148748),
#  ('Manna House Bakery', 'thai', -73.9938095, 40.7135376, 0.13962607939712246),
#  ('Bagel Bazaar', 'chinese', -73.993678, 40.601558, 0.10009812982269259),
#  ('Vito S Bakery',
#   'russian',
#   -73.95202499999999,
#   40.59904299999999,
#   0.14174282228036877),
#  ('Vittoria Bakery', 'egyptian', -73.9574808, 40.7183584, 0.1702456850895234),
#  ('Shubert Theater', 'italian', -73.9871606, 40.7580922, 0.17779664633283004),
#  ('Majestic Theater', 'french', -73.9882148, 40.7584004, 0.177420797438185),
#  ('Bernard B Jacobs Theater',
#   'ecuadorian',
#   -73.98772579999999,
#   40.7587254,
#   0.17797177270343437),
#  ('Booth Theater',
#   'mexican',
#   -73.98671209999999,
#   40.7584367,
#   0.17834035022759595),
#  ('Broadhurst Theater',
#   'colombian',
#   -73.9872318,
#   40.7581077,
#   0.17776679742384055),
#  ('Winter Garden Theater',
#   'colombian',
#   -73.983583,
#   40.76174839999999,
#   0.18286477881417684),
#  ('Imperial Theatre', 'japanese', -73.9872966, 40.7588493, 0.1783254827607437),
#  ('Broadway Theatre',
#   'colombian',
#   -73.98322139999999,
#   40.76321120000001,
#   0.18425470158073265),
#  ('Schoenfield', 'russian', -73.9873168, 40.7584637, 0.17800286276835575),
#  ('Lincoln Plaza Cinemas',
#   'cajun',
#   -73.9827363,
#   40.7719905,
#   0.1916604488389325),
#  ('Hidden Cottage', 'indian', -74.1128499, 40.5719006, 0.04762225305222389),
#  ('Gershwin Theatre',
#   'cajun',
#   -73.9849698,
#   40.76249730000001,
#   0.182643255128494),
#  ('The Joyce Theater',
#   'indonesian',
#   -74.0006087,
#   40.742755,
#   0.15747840753097211),
#  ('Minskoff Theater', 'zambian', -73.9860017, 40.7578273, 0.17827587714377016),
#  ('Walter Reade Theater',
#   'zambian',
#   -73.98435289999999,
#   40.7727501,
#   0.19136145083799813),
#  ('Nederlander Theater Ba',
#   'zambian',
#   -73.9883119,
#   40.755487,
#   0.17501844344300196),
#  ('Richard Rogers Theatre',
#   'cajun',
#   -73.9866977,
#   40.759012,
#   0.17881154213051087),
#  ('Marquis Theater',
#   'ecuadorian',
#   -73.9862536,
#   40.7585799,
#   0.17872853177254955),
#  ('Lunt Fontanne Theater',
#   'ecuadorian',
#   -73.98607919999999,
#   40.7591861,
#   0.17931926110837207),
#  ('Brooks Atkinson Theater',
#   'malaysian',
#   -73.9869032,
#   40.7599244,
#   0.17942515088916938),
#  ('Cafe Madison', 'egyptian', -73.9860597, 40.7431194, 0.16669852827019896),
#  ('Don Pepis Delicatessen',
#   'colombian',
#   -73.9991637,
#   40.75368539999999,
#   0.1672655908483499),
#  ('Randazzo Pizza Restaurant',
#   'peruvian',
#   -73.9756349,
#   40.6355631,
#   0.11898723637441293),
#  ('Devon & Blakely',
#   'colombian',
#   -73.9761482,
#   40.75499569999999,
#   0.18216734625922362),
#  ('The Muffins Shop',
#   'thai',
#   -73.979699,
#   40.77623639999999,
#   0.19688067409768117),
#  ('Woodrow Diner',
#   'korean',
#   -74.20658449999999,
#   40.54289199999999,
#   0.1347289224081038),
#  ('Dunkin  Donuts/Subway',
#   'mexican',
#   -73.9941624,
#   40.6683183,
#   0.11211506257257506),
#  ('Tajin Restaurant', 'zambian', -74.0134539, 40.7076612, 0.1219340219005737),
#  ('Cafe Asean', 'peruvian', -73.999501, 40.7348987, 0.15185945252532662),
#  ('The Ginger Man', 'russian', -73.9826114, 40.7494539, 0.17377726661727405),
#  ('Silver Spurs/Molcajate Taqueria',
#   'peruvian',
#   -73.99881990000002,
#   40.7285861,
#   0.14736537182668774),
#  ('The Central Bar', 'egyptian', -73.9899306, 40.7304421, 0.15457029639284295),
#  ('Little Sal S Italiano',
#   'indian',
#   -73.99203609999999,
#   40.7367938,
#   0.15801366265438005),
#  ('Trevi Deli', 'russian', -73.9888977, 40.7363885, 0.15972636274059693),
#  ('El Castillo De Madison',
#   'colombian',
#   -73.989578,
#   40.7129199,
#   0.14223343652676174),
#  ('Vincent S Pizzeria',
#   'vietnamese',
#   -73.99536239999999,
#   40.6454641,
#   0.10210348087098997),
#  ('Cibar - Lady Mendl S Tea Salon',
#   'vietnamese',
#   -73.9869973,
#   40.7359131,
#   0.16061183220703357),
#  ('Restivo Ristorante',
#   'vietnamese',
#   -73.99582199999999,
#   40.743407,
#   0.1608487263145154),
#  ('I Trulli Restaurant',
#   'canadian',
#   -73.98368099999999,
#   40.742097,
#   0.1674557558282279),
#  ('Kitty Kiernans', 'brazilian', -74.034098, 40.61513, 0.058755000689308036),
#  ('Rainbow Falafel', 'french', -73.9910292, 40.7372614, 0.15901686564198436),
#  ('Notaro Restaurant',
#   'ecuadorian',
#   -73.9758564,
#   40.74532689999999,
#   0.17504793859502607),
#  ('Alfonso S Pastry Shoppe',
#   'malaysian',
#   -74.1606584,
#   40.5452578,
#   0.0973572749382382),
#  ('Brooklyn Pizza',
#   'colombian',
#   -73.958012,
#   40.65065500000001,
#   0.13944447080111397),
#  ('Cafe Ole Usa', 'canadian', -73.9895227, 40.7671312, 0.18380492866659467),
#  ('Starbucks Coffee',
#   'japanese',
#   -74.0066803,
#   40.7115866,
#   0.12934970509688073),
#  ('Barracuda Bar', 'egyptian', -73.998305, 40.744594, 0.1603202483562195),
#  ('China Chalet',
#   'peruvian',
#   -74.01303759999999,
#   40.70661,
#   0.12141142943793083),
#  ('Blue Ribbon Sushi',
#   'egyptian',
#   -74.00237299999999,
#   40.726056,
#   0.14315447818703397),
#  ('Mcdonald S',
#   'russian',
#   -73.9232263,
#   40.65249710000001,
#   0.17369568274457442),
#  ('Chelsea Trattoria', 'italian', -74.0015999, 40.740631, 0.1551769582109733),
#  ('Zaro S Bread Basket',
#   'cajun',
#   -73.97729919999999,
#   40.7524958,
#   0.1795118836441823),
#  ('Bais Rochel', 'mexican', -73.9562358, 40.7017358, 0.1617602637079974),
#  ('Connolly S Pub', 'zambian', -73.9778118, 40.7561728, 0.18201672445322598),
#  ('Los Angeles Bakery',
#   'indian',
#   -73.9434833,
#   40.70067239999999,
#   0.1721346836638393),
#  ('El Continental Restaurant',
#   'italian',
#   -73.9928879,
#   40.662118,
#   0.11046148300204423),
#  ('Aqua Grill', 'cajun', -74.0038433, 40.7253089, 0.14164780266739366),
#  ('Blue Mountain Restaurant & Jerk Center',
#   'french',
#   -73.9275013,
#   40.6246788,
#   0.16562770370240196),
#  ('Mcgees Pub', 'italian', -73.9830473, 40.764891, 0.18571037841890017),
#  ('Ace Bar', 'colombian', -73.9828471, 40.7244201, 0.15507285802364396),
#  ('Burger King', 'thai', -74.131142, 40.613148, 0.03833979981689224),
#  ('Paddy Maguire S Ale House',
#   'italian',
#   -73.984409,
#   40.736611,
#   0.16284938205594024),
#  ('B66 Club', 'thai', -73.9980027, 40.6227135, 0.09515369391852778),
#  ('Vatan', 'peruvian', -73.98021000000001, 40.7423, 0.16989097530474534),
#  ('Arte Cafe',
#   'brazilian',
#   -73.97884599999999,
#   40.778065,
#   0.19886765243498533),
#  ('Piaxtla Es Mexico Deli',
#   'indonesian',
#   -74.01073319999999,
#   40.64446179999999,
#   0.08720403715815946),
#  ('Skylight Diner',
#   'malaysian',
#   -73.99679189999999,
#   40.7533794,
#   0.16835415083618277),
#  ('Soho Grand Hotel', 'russian', -74.0043037, 40.7220205, 0.13881095645063962),
#  ('Anopoli Family Restaurant',
#   'russian',
#   -74.026513,
#   40.635301,
#   0.06934138735272971),
#  ('Creative Edge Caterers',
#   'malaysian',
#   -74.008558,
#   40.732037,
#   0.14413534639706205),
#  ('St. Marks Ale House',
#   'french',
#   -73.98979109999999,
#   40.7293427,
#   0.1538452208633785),
#  ('Tony S Pizza',
#   'canadian',
#   -73.94472499999999,
#   40.7150421,
#   0.17867884768268838),
#  ('Freddie & Pepper S Pizza',
#   'vietnamese',
#   -73.9803328,
#   40.7800281,
#   0.199637539151462),
#  ('Blue Water Grill', 'cajun', -73.9908292, 40.7366592, 0.15868330039951128),
#  ('Anyway Cafe', 'ecuadorian', -73.9905823, 40.7250089, 0.1501154443916428),
#  ('Starbucks Coffee', 'canadian', -73.9977705, 40.7224755, 0.1434073585158747),
#  ('Atlantis Diner', 'canadian', -73.9140573, 40.6431943, 0.1809862218827251),
#  ('The Bubble Lounge', 'french', -74.0063581, 40.7194557, 0.13552526461918443),
#  ('Azusa Of Japan', 'brazilian', -73.9791599, 40.7547039, 0.18002640628536015),
#  ('Campus Center Cafeteria',
#   'indonesian',
#   -74.15198199999999,
#   40.6009948,
#   0.06079299439440496),
#  ('Food For Thought Library Cafe',
#   'egyptian',
#   -74.15198199999999,
#   40.6009948,
#   0.06079299439440496),
#  ('Il Palazzo', 'peruvian', -73.9975707, 40.7190497, 0.14099606865789194),
#  ('Starbucks Coffee',
#   'egyptian',
#   -73.97940419999999,
#   40.7533284,
#   0.17880692278601246),
#  ('Madras Mahal',
#   'russian',
#   -73.98302199999999,
#   40.742313,
#   0.16804955645583625),
#  ('Topaze Restaurant & Jerk Chicken',
#   'italian',
#   -73.92766979999999,
#   40.6264459,
#   0.16557096038332048),
#  ('Nick And Toni S Cafe',
#   'malaysian',
#   -73.98157710000001,
#   40.7743109,
#   0.1942260285925122),
#  ('Mcdonald S', 'cajun', -74.1158584, 40.6293085, 0.027028384809481547),
#  ('Dunkin  Donuts Baskin Robbins',
#   'mexican',
#   -73.9243706,
#   40.69104799999999,
#   0.1848005098444226),
#  ('Au Bon Pain', 'cajun', -73.990494, 40.7569545, 0.1749117108808058),
#  ('Starbucks Coffee',
#   'thai',
#   -74.01405249999999,
#   40.7025595,
#   0.11770730683564967),
#  ('Mcquaids Public House',
#   'indonesian',
#   -73.997602,
#   40.762363,
#   0.1753652176601747),
#  ('Mcdonald S', 'zambian', -73.9498035, 40.6505357, 0.14736811197250516),
#  ('Starbucks Coffee', 'cajun', -73.9870818, 40.7523004, 0.17322163413904634),
#  ('Starbucks Coffee',
#   'peruvian',
#   -73.9835976,
#   40.7621614,
#   0.18318739493022004),
#  ('Starbucks Coffee', 'cajun', -73.9840858, 40.7669118, 0.18673711671888035),
#  ('The Bras & Pail Bar',
#   'canadian',
#   -73.9476059,
#   40.5888866,
#   0.1475973028268868),
#  ('Amy S Bread', 'cajun', -74.00489689999999, 40.7419343, 0.15433045254939523),
#  ('Club Macanudo (Cigar Bar)',
#   'vietnamese',
#   -73.96936149999999,
#   40.7658603,
#   0.19486530511289818),
#  ('Deb S', 'italian', -74.0051398, 40.7281648, 0.14308216580930608),
#  ('Island Burgers And Shakes',
#   'japanese',
#   -73.988011,
#   40.76420299999999,
#   0.18225610466592548),
#  ('Pit Stop Bar', 'malaysian', -73.9502129, 40.7277307, 0.18173371360895707),
#  ('Tribeca Pizzeria', 'cajun', -74.010465, 40.7198789, 0.13327415412003385),
#  ('Grand Plaza', 'zambian', -74.1504413, 40.5493122, 0.08744833019748845),
#  ('Bobby Van S', 'indian', -73.9758568, 40.7544956, 0.18197084914787764),
#  ('Via Italia Ristorante',
#   'peruvian',
#   -73.980701,
#   40.756994,
#   0.18084805565170198),
#  ('Swift', 'colombian', -73.9923517, 40.7272403, 0.15056974707483614),
#  ('Perkins Family Restaurant & Bakery',
#   'thai',
#   -74.1608071,
#   40.5444791,
#   0.09802059856183286),
#  ('Your Bakery',
#   'vietnamese',
#   -74.02590599999999,
#   40.6209702,
#   0.06720203828487471),
#  ('Cafe Bravo',
#   'zambian',
#   -74.00947049999999,
#   40.7045563,
#   0.12227556662040813),
#  ('Wendy S', 'malaysian', -73.9815467, 40.7584118, 0.18144240349028354),
#  ('Mona S', 'indian', -73.97852100000001, 40.729192, 0.16150541559030393),
#  ('Corner Gourmet Ii', 'italian', -74.010069, 40.7147337, 0.12952173816502585),
#  ('The Room', 'italian', -74.01641599999999, 40.680196, 0.10038610757471363),
#  ('Starbucks Coffee',
#   'egyptian',
#   -74.0011779,
#   40.7411261,
#   0.15582557295264704),
#  ('Odessa', 'malaysian', -73.98350889999999, 40.7264835, 0.15606965948275484),
#  ('La Cucina', 'vietnamese', -74.002764, 40.6067589, 0.09047625455008118),
#  ('Circo Restaurant',
#   'vietnamese',
#   -73.9793577,
#   40.7630705,
#   0.18646779258719512),
#  ('Crown Gourmet Deli',
#   'malaysian',
#   -73.982872,
#   40.76280939999999,
#   0.18414039170034585),
#  ('Raj Mahal Indian Restaurant',
#   'colombian',
#   -73.9874971,
#   40.7267605,
#   0.1535032365295935),
#  ('Brooklyn Moon Cafe',
#   'italian',
#   -73.97490189999999,
#   40.6865219,
#   0.1378787529390341),
#  ...]

# %%
column_names = [ 'name', 'cuisine','longitude', 'latitude', 'dist2NNQ']
df = pd.DataFrame(reply,columns=column_names)
df
# Out:
#                                 name     cuisine  longitude   latitude  \
# 0                            Wendy S    egyptian -73.961704  40.662942
# 1                    Riviera Caterer   brazilian -73.982420  40.579505
# 2     Dj Reynolds Pub And Restaurant  indonesian -73.985136  40.767692
# 3                 Wilken S Fine Food     zambian -73.906851  40.619903
# 4                    Regina Caterers  indonesian -74.005289  40.628886
# ...                              ...         ...        ...        ...
# 3103                   Cafe Exchange        thai -74.013321  40.706824
# 3104                        1 Darbar    egyptian -73.973526  40.753517
# 3105     Wagner College - Hawk  Nest    egyptian -74.092853  40.615121
# 3106            Ellen Deli & Grocery   malaysian -74.007810  40.725708
# 3107                  Capital Grille    japanese -73.974723  40.751244
#
#           dist2NNQ
# 0     1.395955e-01
# 1     1.160342e-01
# 2     1.867643e-01
# 3     1.860639e-01
# 4     8.863932e-02
# ...            ...
# 3103  1.213863e-01
# 3104  1.827355e-01
# 3105  2.009718e-14
# 3106  1.395055e-01
# 3107  1.802337e-01
#
# [3108 rows x 5 columns]

# %% [markdown]
# Let's check the query plan

# %%
reply = execute_sqL_with_fetchall(explain_query)
reply
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# [('Seq Scan on restaurants  (cost=0.00..62630.50 rows=1 width=49)',),
#  ("  Filter: st_dwithin(location, '0101000020E61000007995B54DF18552C09A0AF148BC4E4440'::geometry, '0.2'::double precision)",)]

# %% [markdown]
# It scans the whole table.
