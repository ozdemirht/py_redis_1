# %% [markdown]
# ## PostgreSQL and PostGIS for Nearest Neighbour Query / Proximity Search

# %% [markdown]
# Objective is to leverage PostGIS for NNQ.

# %%
# %pip install --user psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\timuc\appdata\roaming\python\python313\site-packages (2.9.11)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# To enable PostGIS extension, run the following command on database
# CREATE EXTENSION postgis;

# %%
import psycopg2
from psycopg2 import Error
import pandas as pd

# %%
def getConfigOrDefault(config_filename, config,label,default=None):
    if config.get(label) is not None:
        return config.get(label)
    if default is not None:
        return default
    print(f"{config_filename} file does not have {label} parameter!")
    return None

# %%
from dotenv import dotenv_values
config_filename = './postgresql.cfg'
config = dotenv_values(config_filename)

USER_NAME = getConfigOrDefault(config_filename, config, 'POSTGRES_UNAME')
USER_PWD  = getConfigOrDefault(config_filename, config, 'POSTGRES_UPWD')
POSTGRES_HOST = getConfigOrDefault(config_filename, config, 'POSTGRES_HOST', 'localhost')
POSTGRES_PORT = getConfigOrDefault(config_filename, config, 'POSTGRES_PORT', '5432')
POSTGRES_DB = getConfigOrDefault(config_filename, config, 'POSTGRES_DBNAME', 'test')

if USER_PWD is None or USER_PWD is None:
    print(f"{config_filename} file does not have parameters: POSTGRES_UNAME and/or POSTGRES_UPWD!")

# %%
try:
    # Connect to an existing database
    connection = psycopg2.connect(user=USER_NAME,
                                  password=USER_PWD,
                                  host=POSTGRES_HOST,
                                  port=POSTGRES_PORT,
                                  database=POSTGRES_DB)

    # Create a cursor to perform database operations
    cursor = connection.cursor()
    # Print PostgreSQL details
    print("PostgreSQL server information")
    print(connection.get_dsn_parameters(), "\n")
    # Executing a SQL query
    cursor.execute("SELECT version();")
    # Fetch result
    record = cursor.fetchone()
    print("You are connected to - ", record, "\n")

    #Closing the connection
    connection.close()

except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if (connection):
       cursor.close()
       connection.close()
       print("PostgreSQL connection is closed")
# Out:
# PostgreSQL server information
# {'user': 'test_user', 'channel_binding': 'prefer', 'dbname': 'postgres', 'host': '127.0.0.1', 'port': '5432', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'sslcertmode': 'allow', 'sslsni': '1', 'ssl_min_protocol_version': 'TLSv1.2', 'gssencmode': 'disable', 'krbsrvname': 'postgres', 'gssdelegation': '0', 'target_session_attrs': 'any', 'load_balance_hosts': 'disable'}
#
# You are connected to -  ('PostgreSQL 17.5 on x86_64-windows, compiled by msvc-19.44.35209, 64-bit',)
#
# PostgreSQL connection is closed

# %%
try:
    # Connect to an existing database
    connection = psycopg2.connect(user=USER_NAME,
                                  password=USER_PWD,
                                  host=POSTGRES_HOST,
                                  port=POSTGRES_PORT,
                                  database=POSTGRES_DB)

    # Create a cursor to perform database operations
    cursor = connection.cursor()
    # Executing a SQL query
    cursor.execute("SELECT version();")
    # Fetch result
    record = cursor.fetchone()
    print("You are connected to - ", record, "\n")

    cursor.execute(f"DROP TABLE IF EXISTS test.restaurants;")

    sql_stmt=f"""
    CREATE TABLE IF NOT EXISTS test.restaurants (
    id SERIAL PRIMARY KEY,
    name VARCHAR(255),
    longitude FLOAT,
    latitude FLOAT,
    location GEOMETRY(Point, 4326)
    )
    """
    cursor.execute(sql_stmt)

    #record = cursor.fetchone()
    #print("Result - ", record, "\n")

    connection.commit()

    sql_stmt="""
     select column_name
        , data_type
        , udt_catalog
        , udt_schema
        , udt_name
        , character_maximum_length
        , column_default
        , is_nullable
    from INFORMATION_SCHEMA.COLUMNS
    where table_name = 'restaurants';
    """
    cursor.execute(sql_stmt)

    record = cursor.fetchall()
    print(record)

    #Closing the connection
    connection.close()

except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if (connection):
       cursor.close()
       connection.close()
       print("PostgreSQL connection is closed")
# Out:
# You are connected to -  ('PostgreSQL 17.5 on x86_64-windows, compiled by msvc-19.44.35209, 64-bit',)
#
# [('id', 'integer', 'postgres', 'pg_catalog', 'int4', None, "nextval('test.restaurants_id_seq'::regclass)", 'NO'), ('name', 'character varying', 'postgres', 'pg_catalog', 'varchar', 255, None, 'YES'), ('longitude', 'double precision', 'postgres', 'pg_catalog', 'float8', None, None, 'YES'), ('latitude', 'double precision', 'postgres', 'pg_catalog', 'float8', None, None, 'YES'), ('location', 'USER-DEFINED', 'postgres', 'public', 'geometry', None, None, 'YES')]
# PostgreSQL connection is closed

# %%
df_raw=record
df_raw

# %%
column_names = [ 'column_name', 'data_type',
                 'udt_catalog', 'udt_schema', 'udt_name',
                 'character_maximum_length', 'column_default', 'is_nullable']
df = pd.DataFrame(df_raw,columns=column_names)
df
# Out:
#   column_name          data_type udt_catalog  udt_schema  udt_name  \
# 0          id            integer    postgres  pg_catalog      int4
# 1        name  character varying    postgres  pg_catalog   varchar
# 2   longitude   double precision    postgres  pg_catalog    float8
# 3    latitude   double precision    postgres  pg_catalog    float8
# 4    location       USER-DEFINED    postgres      public  geometry
#
#    character_maximum_length                                column_default  \
# 0                       NaN  nextval('test.restaurants_id_seq'::regclass)
# 1                     255.0                                          None
# 2                       NaN                                          None
# 3                       NaN                                          None
# 4                       NaN                                          None
#
#   is_nullable
# 0          NO
# 1         YES
# 2         YES
# 3         YES
# 4         YES

# %%
filename="./restaurants.csv"
df_loaded = pd.read_csv(filename)
df_loaded[:10]
# Out:
#                              Name        Lon        Lat
# 0           Morris Park Bake Shop -73.856077  40.848447
# 1                         Wendy'S -73.961704  40.662942
# 2                 Riviera Caterer -73.982420  40.579505
# 3              Tov Kosher Kitchen -73.860115  40.731174
# 4         Brunos On The Boulevard -73.880383  40.764312
# 5  Dj Reynolds Pub And Restaurant -73.985136  40.767692
# 6              Wilken'S Fine Food -73.906851  40.619903
# 7                 Regina Caterers -74.005289  40.628886
# 8     Taste The Tropics Ice Cream -73.948261  40.640827
# 9                   Kosher Island -74.137729  40.611957

# %%
df_loaded['Rid'] = df_loaded.index
printdf = df_loaded[:10]
print(printdf.to_string(index=False))
# Out:
#                           Name        Lon       Lat  Rid    Cuisine
#          Morris Park Bake Shop -73.856077 40.848447    0 indonesian
#                        Wendy'S -73.961704 40.662942    1 vietnamese
#                Riviera Caterer -73.982420 40.579505    2 vietnamese
#             Tov Kosher Kitchen -73.860115 40.731174    3      cajun
#        Brunos On The Boulevard -73.880383 40.764312    4      cajun
# Dj Reynolds Pub And Restaurant -73.985136 40.767692    5    chinese
#             Wilken'S Fine Food -73.906851 40.619903    6    mexican
#                Regina Caterers -74.005289 40.628886    7    mexican
#    Taste The Tropics Ice Cream -73.948261 40.640827    8  colombian
#                  Kosher Island -74.137729 40.611957    9    zambian

# %%
import random
def assignCuisineRandomly(df,cuisine,cname):
    for i in range(df.shape[0]):
        df.at[i,cname] = cuisine[random.randint(0,len(cuisine)-1)]

# %%
cuisine = ['italian', 'chinese', 'french', 'zambian', 'egyptian', 'canadian', 'mexican', 'vietnamese', 'cajun', 'korean', 'thai', 'brazilian','colombian','peruvian','ecuadorian', 'japanese','indian','malaysian','russian', 'indonesian']
assignCuisineRandomly(df_loaded,cuisine,'Cuisine')
df_loaded[-4:]
# Out:
#                              Name        Lon        Lat   Rid  Cuisine
# 4996  Wagner College - Hawk' Nest -74.092853  40.615121  4996  italian
# 4997         Ellen Deli & Grocery -74.007810  40.725708  4997  chinese
# 4998           Crepes On Columbus -73.961831  40.801052  4998   french
# 4999               Capital Grille -73.974723  40.751244  4999  chinese

# %%
def formatSQL(df):
    name = df['Name'].replace("'"," ")
    sql_stmt = f"INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('{name}',{df['Lon']},{df['Lat']},ST_GeomFromText('POINT({df['Lon']} {df['Lat']})', 4326));"

    return sql_stmt

# %%
#print(formatSQL(df_loaded[0]))
idx=4996
print(type(df_loaded.loc[idx].to_dict()))
df_loaded.loc[idx].to_dict()
print(formatSQL(df_loaded.loc[idx].to_dict()))
# Out:
# <class 'dict'>
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Wagner College - Hawk  Nest',-74.09285299999999,40.61512099999999,ST_GeomFromText('POINT(-74.09285299999999 40.61512099999999)', 4326));

# %%
# Load data to test.restaurants table
# using ST_GeomFromText('POINT($longitude $latitude)', 4326)
try:
        # Connect to an existing database
        connection = psycopg2.connect(user=USER_NAME,
                                      password=USER_PWD,
                                      host=POSTGRES_HOST,
                                      port=POSTGRES_PORT,
                                      database=POSTGRES_DB)

        # Create a cursor to perform database operations
        cursor = connection.cursor()
        # Executing a SQL query
        cursor.execute("SELECT version();")
        # Fetch result
        record = cursor.fetchone()
        print("You are connected to - ", record, "\n")
        sql_stmt = ""
        for i in range(df_loaded.shape[0]):
            #addARestaurant(connection, df_loaded.loc[i].to_dict())
            sql_stmt = formatSQL(df_loaded.loc[i].to_dict())
            print(sql_stmt)
            cursor.execute(sql_stmt)

        connection.commit()

        #Closing the connection
        connection.close()

except (Exception, Error) as error:
        print("Error: ", error)
finally:
        if (connection):
            cursor.close()
            connection.close()
        print("PostgreSQL connection is closed")
# Out:
# You are connected to -  ('PostgreSQL 17.5 on x86_64-windows, compiled by msvc-19.44.35209, 64-bit',)
#
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Morris Park Bake Shop',-73.856077,40.848447,ST_GeomFromText('POINT(-73.856077 40.848447)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Wendy S',-73.961704,40.662942,ST_GeomFromText('POINT(-73.961704 40.662942)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Riviera Caterer',-73.98241999999999,40.579505,ST_GeomFromText('POINT(-73.98241999999999 40.579505)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Tov Kosher Kitchen',-73.8601152,40.7311739,ST_GeomFromText('POINT(-73.8601152 40.7311739)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Brunos On The Boulevard',-73.8803827,40.7643124,ST_GeomFromText('POINT(-73.8803827 40.7643124)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Dj Reynolds Pub And Restaurant',-73.98513559999999,40.7676919,ST_GeomFromText('POINT(-73.98513559999999 40.7676919)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Wilken S Fine Food',-73.9068506,40.6199034,ST_GeomFromText('POINT(-73.9068506 40.6199034)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Regina Caterers',-74.00528899999999,40.628886,ST_GeomFromText('POINT(-74.00528899999999 40.628886)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Taste The Tropics Ice Cream',-73.9482609,40.6408271,ST_GeomFromText('POINT(-73.9482609 40.6408271)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Kosher Island',-74.1377286,40.6119572,ST_GeomFromText('POINT(-74.1377286 40.6119572)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Wild Asia',-73.8786113,40.8502883,ST_GeomFromText('POINT(-73.8786113 40.8502883)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('C & C Catering Service',-73.9973325,40.61174889999999,ST_GeomFromText('POINT(-73.9973325 40.61174889999999)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('1 East 66Th Street Kitchen',-73.96926909999999,40.7685235,ST_GeomFromText('POINT(-73.96926909999999 40.7685235)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('May May Kitchen',-73.871194,40.6730975,ST_GeomFromText('POINT(-73.871194 40.6730975)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Seuda Foods',-73.9653967,40.6064339,ST_GeomFromText('POINT(-73.9653967 40.6064339)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Carvel Ice Cream',-73.97822040000001,40.6435254,ST_GeomFromText('POINT(-73.97822040000001 40.6435254)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Carvel Ice Cream',-73.7032601,40.7386417,ST_GeomFromText('POINT(-73.7032601 40.7386417)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Nordic Delicacies',-74.0259567,40.6353674,ST_GeomFromText('POINT(-74.0259567 40.6353674)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('The Movable Feast',-73.9829239,40.6580753,ST_GeomFromText('POINT(-73.9829239 40.6580753)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Sal S Deli',-73.839297,40.78147,ST_GeomFromText('POINT(-73.839297 40.78147)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Glorious Food',-73.95171,40.767461,ST_GeomFromText('POINT(-73.95171 40.767461)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Bully S Deli',-73.9925306,40.7309346,ST_GeomFromText('POINT(-73.9925306 40.7309346)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Harriet S Kitchen',-73.976112,40.786714,ST_GeomFromText('POINT(-73.976112 40.786714)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Steve Chu S Deli & Grocery',-73.94024739999999,40.7623288,ST_GeomFromText('POINT(-73.94024739999999 40.7623288)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('P & S Deli Grocery',-73.96805719999999,40.7925587,ST_GeomFromText('POINT(-73.96805719999999 40.7925587)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Angelika Film Center',-73.996984,40.72589,ST_GeomFromText('POINT(-73.996984 40.72589)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('White Castle',-73.9634876,40.6940001,ST_GeomFromText('POINT(-73.9634876 40.6940001)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Ho Mei Restaurant',-73.8642349,40.75356,ST_GeomFromText('POINT(-73.8642349 40.75356)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('The Country Cafe',-74.0085357,40.70620539999999,ST_GeomFromText('POINT(-74.0085357 40.70620539999999)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Shashemene Int L Restaura',-73.9246028,40.6522396,ST_GeomFromText('POINT(-73.9246028 40.6522396)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Downtown Deli',-74.00920839999999,40.7132925,ST_GeomFromText('POINT(-74.00920839999999 40.7132925)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Carvel Ice Cream',-73.84856870000002,40.8903781,ST_GeomFromText('POINT(-73.84856870000002 40.8903781)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Dunkin  Donuts',-73.991495,40.692273,ST_GeomFromText('POINT(-73.991495 40.692273)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Olive S',-73.9998042,40.7251256,ST_GeomFromText('POINT(-73.9998042 40.7251256)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Happy Garden',-73.8893654,40.81376179999999,ST_GeomFromText('POINT(-73.8893654 40.81376179999999)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Cafe Metro',-73.990494,40.7569545,ST_GeomFromText('POINT(-73.990494 40.7569545)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Tony S Deli',-73.902463,40.694924,ST_GeomFromText('POINT(-73.902463 40.694924)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Lexler Deli',-73.97534999999999,40.7516269,ST_GeomFromText('POINT(-73.97534999999999 40.7516269)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Bagels N Buns',-74.1459332,40.6103714,ST_GeomFromText('POINT(-74.1459332 40.6103714)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Hot Bagels',-73.8740217,40.7135015,ST_GeomFromText('POINT(-73.8740217 40.7135015)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Snack Time Grill',-73.8309503,40.7001121,ST_GeomFromText('POINT(-73.8309503 40.7001121)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Domino S Pizza',-73.9791458,40.744328,ST_GeomFromText('POINT(-73.9791458 40.744328)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Lorenzo & Maria S',-73.95685019999999,40.7753401,ST_GeomFromText('POINT(-73.95685019999999 40.7753401)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Berkely',-73.975393,40.757365,ST_GeomFromText('POINT(-73.975393 40.757365)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Sonny S Heros',-73.9075537,40.6438684,ST_GeomFromText('POINT(-73.9075537 40.6438684)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Carvel Ice Cream',-74.0796436,40.59878339999999,ST_GeomFromText('POINT(-74.0796436 40.59878339999999)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Golden Pavillion',-73.92701509999999,40.6620192,ST_GeomFromText('POINT(-73.92701509999999 40.6620192)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Domino S Pizza',-73.9806854,40.7778589,ST_GeomFromText('POINT(-73.9806854 40.7778589)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Kosher Bagel Hole',-73.9615132,40.6253268,ST_GeomFromText('POINT(-73.9615132 40.6253268)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Spoon Bread Catering',-73.96084119999999,40.8014307,ST_GeomFromText('POINT(-73.96084119999999 40.8014307)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Terminal Cafe/Yankee Clipper',-84.2040813,9.9986585,ST_GeomFromText('POINT(-84.2040813 9.9986585)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mejlander & Mulgannon',-74.0228449,40.6281815,ST_GeomFromText('POINT(-74.0228449 40.6281815)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Plaza Bagels & Deli',-74.1178949,40.5734906,ST_GeomFromText('POINT(-74.1178949 40.5734906)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Texas Rotisserie',-74.0061936,40.7092038,ST_GeomFromText('POINT(-74.0061936 40.7092038)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Philadelhia Grille Express',-74.03400479999999,40.6127077,ST_GeomFromText('POINT(-74.03400479999999 40.6127077)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Peter Luger Steakhouse',-73.96252129999999,40.7098035,ST_GeomFromText('POINT(-73.96252129999999 40.7098035)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Palm Restaurant',-73.9712,40.751703,ST_GeomFromText('POINT(-73.9712 40.751703)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Happy Garden',-73.8941893,40.8634684,ST_GeomFromText('POINT(-73.8941893 40.8634684)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('21 Club',-73.9774394,40.7604522,ST_GeomFromText('POINT(-73.9774394 40.7604522)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Manhem Club',-73.81363999999999,40.82941100000001,ST_GeomFromText('POINT(-73.81363999999999 40.82941100000001)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('B & M Hot Bagel & Grocery',-74.15235919999999,40.5563756,ST_GeomFromText('POINT(-74.15235919999999 40.5563756)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Isle Of Capri Resturant',-73.966032,40.762832,ST_GeomFromText('POINT(-73.966032 40.762832)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Old Town Bar & Restaurant',-73.9891878,40.7375638,ST_GeomFromText('POINT(-73.9891878 40.7375638)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Polish National Home',-73.94839189999999,40.7224876,ST_GeomFromText('POINT(-73.94839189999999 40.7224876)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Metropolitan Club',-73.97166039999999,40.764832,ST_GeomFromText('POINT(-73.97166039999999 40.764832)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Seville Restaurant',-74.00310999999999,40.7348888,ST_GeomFromText('POINT(-74.00310999999999 40.7348888)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Criminal Court Bldg Cafeteria',-74.0010484,40.71599000000001,ST_GeomFromText('POINT(-74.0010484 40.71599000000001)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Gottscheer Hall',-73.9056678,40.7066898,ST_GeomFromText('POINT(-73.9056678 40.7066898)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Nyac Main Dining Room',-73.9788694,40.7665961,ST_GeomFromText('POINT(-73.9788694 40.7665961)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('7B Bar',-73.98146,40.7250067,ST_GeomFromText('POINT(-73.98146 40.7250067)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Ben-Best Deli & Restaurant',-73.86137149999999,40.7293762,ST_GeomFromText('POINT(-73.86137149999999 40.7293762)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Cafe Atelier (Art Students League)',-73.9805679,40.7659436,ST_GeomFromText('POINT(-73.9805679 40.7659436)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Donohue S Steak House',-73.965531,40.765431,ST_GeomFromText('POINT(-73.965531 40.765431)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Junior S',-73.9818918,40.6901211,ST_GeomFromText('POINT(-73.9818918 40.6901211)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Tout Va Bien',-73.98621899999999,40.763406,ST_GeomFromText('POINT(-73.98621899999999 40.763406)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Great Kills Yacht Club',-74.138263,40.546681,ST_GeomFromText('POINT(-74.138263 40.546681)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Marchis Restaurant',-73.9775552,40.7432016,ST_GeomFromText('POINT(-73.9775552 40.7432016)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Towne Cafe',-73.95443709999999,40.5877993,ST_GeomFromText('POINT(-73.95443709999999 40.5877993)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('New Park Pizzeria & Restaurant',-73.840437,40.6627235,ST_GeomFromText('POINT(-73.840437 40.6627235)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Serendipity 3',-73.96485799999999,40.761899,ST_GeomFromText('POINT(-73.96485799999999 40.761899)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Douglaston Club',-73.7522366,40.7766941,ST_GeomFromText('POINT(-73.7522366 40.7766941)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Rizzo S Fine Pizza',-73.9151096,40.763377,ST_GeomFromText('POINT(-73.9151096 40.763377)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Melody Lanes',-74.002944,40.652779,ST_GeomFromText('POINT(-74.002944 40.652779)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('The New Starling Athletic Club Of The Bronx',-73.84971759999999,40.8304811,ST_GeomFromText('POINT(-73.84971759999999 40.8304811)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('White Horse Tavern',-74.00619499999999,40.735663,ST_GeomFromText('POINT(-74.00619499999999 40.735663)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Crystal Room',-74.0707363,40.59321569999999,ST_GeomFromText('POINT(-74.0707363 40.59321569999999)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Labetti S Post # 2159',-74.07444319999999,40.6096914,ST_GeomFromText('POINT(-74.07444319999999 40.6096914)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Shell Lanes',-73.9727638,40.588853,ST_GeomFromText('POINT(-73.9727638 40.588853)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mcsorley S Old Ale House',-73.9896713,40.7287978,ST_GeomFromText('POINT(-73.9896713 40.7287978)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Forlinis Restaurant',-73.99950489999999,40.7169224,ST_GeomFromText('POINT(-73.99950489999999 40.7169224)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('South Shore Swimming Club',-74.2274942,40.5071996,ST_GeomFromText('POINT(-74.2274942 40.5071996)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Corner Bistro',-74.0037823,40.7380122,ST_GeomFromText('POINT(-74.0037823 40.7380122)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Nostrand Donut Shop',-73.94933739999999,40.6509823,ST_GeomFromText('POINT(-73.94933739999999 40.6509823)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('La Grenouille',-73.97557069999999,40.7596796,ST_GeomFromText('POINT(-73.97557069999999 40.7596796)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Dorrian S Red Hand Restaurant',-73.952449,40.776325,ST_GeomFromText('POINT(-73.952449 40.776325)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Como Pizza',-73.9395182,40.8422945,ST_GeomFromText('POINT(-73.9395182 40.8422945)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Angelo Of Mulberry St.',-73.9973041,40.7188698,ST_GeomFromText('POINT(-73.9973041 40.7188698)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Panchito S',-74.001043,40.729795,ST_GeomFromText('POINT(-74.001043 40.729795)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('New Corner',-74.0166091,40.6284767,ST_GeomFromText('POINT(-74.0166091 40.6284767)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Old Homestead',-74.004758,40.741207,ST_GeomFromText('POINT(-74.004758 40.741207)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Dining Room',-48.9424,-16.3550032,ST_GeomFromText('POINT(-48.9424 -16.3550032)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('The Princeton Club',-73.98126069999999,40.7547107,ST_GeomFromText('POINT(-73.98126069999999 40.7547107)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Le Perigord',-73.9646207,40.7550069,ST_GeomFromText('POINT(-73.9646207 40.7550069)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Joe & Pat S Pizzeria',-74.1220973,40.6129407,ST_GeomFromText('POINT(-74.1220973 40.6129407)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Reynold S Bar',-73.9365108,40.8497077,ST_GeomFromText('POINT(-73.9365108 40.8497077)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Keats Restaurant',-73.97063700000001,40.751495,ST_GeomFromText('POINT(-73.97063700000001 40.751495)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Spain Restaurant & Bar',-73.9979214,40.7371344,ST_GeomFromText('POINT(-73.9979214 40.7371344)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Palace Cafe',-73.9446421,40.7253944,ST_GeomFromText('POINT(-73.9446421 40.7253944)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Yankee Tavern',-73.92506,40.8275556,ST_GeomFromText('POINT(-73.92506 40.8275556)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Donut Pub',-73.99987229999999,40.7386361,ST_GeomFromText('POINT(-73.99987229999999 40.7386361)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Moran S Chelsea',-74.0056649,40.7452371,ST_GeomFromText('POINT(-74.0056649 40.7452371)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('V & T Restaurant',-73.96392089999999,40.8033908,ST_GeomFromText('POINT(-73.96392089999999 40.8033908)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Reben Luncheonette',-73.9590059,40.7090147,ST_GeomFromText('POINT(-73.9590059 40.7090147)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('King Yum Restaurant',-73.7867565,40.7271312,ST_GeomFromText('POINT(-73.7867565 40.7271312)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('J&V Famous Pizza',-73.9896898,40.6199526,ST_GeomFromText('POINT(-73.9896898 40.6199526)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Jahn S Restaurant',-73.8850023,40.7494272,ST_GeomFromText('POINT(-73.8850023 40.7494272)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('La Parisienne Diner',-73.9799932,40.7660886,ST_GeomFromText('POINT(-73.9799932 40.7660886)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Joe Allen Restaurant',-73.989131,40.760039,ST_GeomFromText('POINT(-73.989131 40.760039)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Joyce S Tavern',-74.16536339999999,40.5450793,ST_GeomFromText('POINT(-74.16536339999999 40.5450793)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Arturo S',-74.0003315,40.7274874,ST_GeomFromText('POINT(-74.0003315 40.7274874)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Barbetta Restaurant',-73.988948,40.760337,ST_GeomFromText('POINT(-73.988948 40.760337)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Gargiulo S Restaurant',-73.982241,40.576366,ST_GeomFromText('POINT(-73.982241 40.576366)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Il Vagabondo Restaurant',-73.96117869999999,40.7619226,ST_GeomFromText('POINT(-73.96117869999999 40.7619226)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Parkside Restaurant',-73.856132,40.743841,ST_GeomFromText('POINT(-73.856132 40.743841)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Lavelle S Admiral S Club',-73.91427200000001,40.7569379,ST_GeomFromText('POINT(-73.91427200000001 40.7569379)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Neary S Pub',-73.963506,40.758273,ST_GeomFromText('POINT(-73.963506 40.758273)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mcdwyers Pub',-73.87786539999999,40.8724377,ST_GeomFromText('POINT(-73.87786539999999 40.8724377)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mee Sum Coffee Shop',-73.9983,40.715051,ST_GeomFromText('POINT(-73.9983 40.715051)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Nancy S Fire Side',-73.70902579999999,40.7276012,ST_GeomFromText('POINT(-73.70902579999999 40.7276012)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Hop Kee Restaurant',-73.9990337,40.7143954,ST_GeomFromText('POINT(-73.9990337 40.7143954)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Nancy Whiskey Pub',-74.0049219,40.720699,ST_GeomFromText('POINT(-74.0049219 40.720699)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Blarney Bar',-73.808593,40.702028,ST_GeomFromText('POINT(-73.808593 40.702028)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Margherita Pizza',-73.78999089999999,40.7118632,ST_GeomFromText('POINT(-73.78999089999999 40.7118632)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Healy S Pub',-73.8299395,40.5812137,ST_GeomFromText('POINT(-73.8299395 40.5812137)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Fifth Avenue Bingo',-73.98586209999999,40.67017250000001,ST_GeomFromText('POINT(-73.98586209999999 40.67017250000001)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Denino S Pizzeria Tavern',-74.1402105,40.6301893,ST_GeomFromText('POINT(-74.1402105 40.6301893)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Michael S Restaurant',-73.942849,40.6076256,ST_GeomFromText('POINT(-73.942849 40.6076256)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('New York Pizza Suprema',-73.99532099999999,40.750205,ST_GeomFromText('POINT(-73.99532099999999 40.750205)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Nanni Restaurant',-73.9736776,40.7535755,ST_GeomFromText('POINT(-73.9736776 40.7535755)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Lenihan S Saloon',-73.82770529999999,40.6944628,ST_GeomFromText('POINT(-73.82770529999999 40.6944628)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Emilio Iii Bar',-73.8682701,40.745683,ST_GeomFromText('POINT(-73.8682701 40.745683)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Killarney Rose',-74.0086833,40.7052024,ST_GeomFromText('POINT(-74.0086833 40.7052024)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Don Peppe',-73.8216767,40.6689548,ST_GeomFromText('POINT(-73.8216767 40.6689548)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Blarney Castle',-73.9250442,40.5595462,ST_GeomFromText('POINT(-73.9250442 40.5595462)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Three Star Restaurant',-73.955074,40.599217,ST_GeomFromText('POINT(-73.955074 40.599217)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Blarney Rock',-73.98926,40.7509054,ST_GeomFromText('POINT(-73.98926 40.7509054)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Desmond S Tavern',-73.98306099999999,40.7441419,ST_GeomFromText('POINT(-73.98306099999999 40.7441419)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Naomi Kosher Pizza',-73.8204154,40.7242443,ST_GeomFromText('POINT(-73.8204154 40.7242443)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Roll-N-Roaster',-73.9396213,40.5841703,ST_GeomFromText('POINT(-73.9396213 40.5841703)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Tio Pepe',-74.0016583,40.7319679,ST_GeomFromText('POINT(-74.0016583 40.7319679)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Brennan & Carr',-73.9420751,40.6002442,ST_GeomFromText('POINT(-73.9420751 40.6002442)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('The Punch Bowl',-73.9002615,40.885186,ST_GeomFromText('POINT(-73.9002615 40.885186)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Jardin De China Rest',-73.8700163,40.7504734,ST_GeomFromText('POINT(-73.8700163 40.7504734)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Irish Cottage',-73.8236419,40.7261682,ST_GeomFromText('POINT(-73.8236419 40.7261682)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Blarney Stone',-74.0137007,40.7062029,ST_GeomFromText('POINT(-74.0137007 40.7062029)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Shimons Kosher Pizza',-73.8221418,40.7272376,ST_GeomFromText('POINT(-73.8221418 40.7272376)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('The Riviera Cafe',-74.0027865,40.7340505,ST_GeomFromText('POINT(-74.0027865 40.7340505)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Fascati S Pizzeria',-73.9927131,40.6984887,ST_GeomFromText('POINT(-73.9927131 40.6984887)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Baby Bo S Burritos',-73.97598099999999,40.745132,ST_GeomFromText('POINT(-73.97598099999999 40.745132)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Shun Lee Palace Restaurant',-73.9690789,40.7594184,ST_GeomFromText('POINT(-73.9690789 40.7594184)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Li Greci S Staaten Restaurant',-74.11223799999999,40.629819,ST_GeomFromText('POINT(-74.11223799999999 40.629819)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Tamaqua',-73.9300062,40.5943553,ST_GeomFromText('POINT(-73.9300062 40.5943553)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Munchtime',-73.9168424,40.8401362,ST_GeomFromText('POINT(-73.9168424 40.8401362)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Cara Mia',-73.74292179999999,40.7305714,ST_GeomFromText('POINT(-73.74292179999999 40.7305714)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Ihop',-73.8194559,40.8899176,ST_GeomFromText('POINT(-73.8194559 40.8899176)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Maloney S Bar',-73.809167,40.705421,ST_GeomFromText('POINT(-73.809167 40.705421)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Richmond County Country Club',-74.10465599999999,40.58834,ST_GeomFromText('POINT(-74.10465599999999 40.58834)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('La Fusta Restaurant',-73.8845166,40.744772,ST_GeomFromText('POINT(-73.8845166 40.744772)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Patsy S Italian Restaurant',-73.9827418,40.7655827,ST_GeomFromText('POINT(-73.9827418 40.7655827)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Lulu S Coffee Shop',-73.8513114,40.8316981,ST_GeomFromText('POINT(-73.8513114 40.8316981)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Dangerfield S Night Club',-73.960573,40.760982,ST_GeomFromText('POINT(-73.960573 40.760982)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('El Charro Espanol',-74.00065800000002,40.735114,ST_GeomFromText('POINT(-74.00065800000002 40.735114)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Finnegan S Wake',-73.9556394,40.768679,ST_GeomFromText('POINT(-73.9556394 40.768679)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Da Vinci Pizza',-73.9907801,40.6188665,ST_GeomFromText('POINT(-73.9907801 40.6188665)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mitchell S Restaurant',-73.9681178,40.678776,ST_GeomFromText('POINT(-73.9681178 40.678776)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mexico Lindo Restaurant',-73.979839,40.739796,ST_GeomFromText('POINT(-73.979839 40.739796)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Marina Delray',-73.815175,40.8137649,ST_GeomFromText('POINT(-73.815175 40.8137649)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Twins Pub',-73.99682299999999,40.753182,ST_GeomFromText('POINT(-73.99682299999999 40.753182)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('New Floridian Diner',-73.9270926,40.6142428,ST_GeomFromText('POINT(-73.9270926 40.6142428)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Narrows Coffee Shop',-74.03345,40.612598,ST_GeomFromText('POINT(-74.03345 40.612598)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Broome Street Bar',-74.0029643,40.7231081,ST_GeomFromText('POINT(-74.0029643 40.7231081)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('O Hanlon S Pub',-73.9121201,40.7749286,ST_GeomFromText('POINT(-73.9121201 40.7749286)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Charlies Sports Bar',-73.90364869999999,40.74133339999999,ST_GeomFromText('POINT(-73.90364869999999 40.74133339999999)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Jg Melon Restaurant',-73.9593019,40.77105400000001,ST_GeomFromText('POINT(-73.9593019 40.77105400000001)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Jack S Pizza & Pasta',-73.7775242,40.778475,ST_GeomFromText('POINT(-73.7775242 40.778475)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Emerald Pub',-74.0084936,40.7258072,ST_GeomFromText('POINT(-74.0084936 40.7258072)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Tap Room',-73.9788694,40.7665961,ST_GeomFromText('POINT(-73.9788694 40.7665961)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Cocktail Room (Nyac)',-73.9788694,40.7665961,ST_GeomFromText('POINT(-73.9788694 40.7665961)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Flame Restaurant Coffee House',-73.98557920000002,40.7686093,ST_GeomFromText('POINT(-73.98557920000002 40.7686093)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Jackson Hole',-73.9629729,40.7638694,ST_GeomFromText('POINT(-73.9629729 40.7638694)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Zum Stammtisch',-73.8811834,40.7017759,ST_GeomFromText('POINT(-73.8811834 40.7017759)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('John S Restaurant',-73.985535,40.730605,ST_GeomFromText('POINT(-73.985535 40.730605)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Grassroot Tavern',-73.988991,40.728848,ST_GeomFromText('POINT(-73.988991 40.728848)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Buddy S Wonder Bar',-74.1350211,40.6369042,ST_GeomFromText('POINT(-74.1350211 40.6369042)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('The Assembly Bar',-73.876876,40.703885,ST_GeomFromText('POINT(-73.876876 40.703885)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mr Broadway Kosher Restaurant',-73.9870818,40.7523004,ST_GeomFromText('POINT(-73.9870818 40.7523004)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Piccola Venezia',-73.911784,40.764766,ST_GeomFromText('POINT(-73.911784 40.764766)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Ni-Ni S Cafe',-74.1003379,40.5655379,ST_GeomFromText('POINT(-74.1003379 40.5655379)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Capitol Restaurant',-73.9215284,40.8678204,ST_GeomFromText('POINT(-73.9215284 40.8678204)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Malaga Restaurant',-73.9550129,40.768019,ST_GeomFromText('POINT(-73.9550129 40.768019)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('La Bonne Soupe Bistro',-73.977035,40.762307,ST_GeomFromText('POINT(-73.977035 40.762307)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mimis Restaurant & Bar',-73.9672945,40.7561212,ST_GeomFromText('POINT(-73.9672945 40.7561212)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Lenny S Clam Bar',-73.83856999999999,40.655669,ST_GeomFromText('POINT(-73.83856999999999 40.655669)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Griffis Faculty Club',-73.9542568,40.7641379,ST_GeomFromText('POINT(-73.9542568 40.7641379)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Little Brown Jug',-73.82629709999999,40.700598,ST_GeomFromText('POINT(-73.82629709999999 40.700598)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Dani Pizza And Restaurant',-73.8305269,40.7089494,ST_GeomFromText('POINT(-73.8305269 40.7089494)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Gray S Papaya',-73.98185529999999,40.7782266,ST_GeomFromText('POINT(-73.98185529999999 40.7782266)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mcdonald S',-73.95802549999999,40.6487475,ST_GeomFromText('POINT(-73.95802549999999 40.6487475)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('El Greco Diner',-73.95006049999999,40.5838274,ST_GeomFromText('POINT(-73.95006049999999 40.5838274)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('One If By Land Two If By Sea',-74.00259299999999,40.7324849,ST_GeomFromText('POINT(-74.00259299999999 40.7324849)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mcdonald S',-73.8618426,40.6797488,ST_GeomFromText('POINT(-73.8618426 40.6797488)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Fiorellos',-73.9819129,40.77151449999999,ST_GeomFromText('POINT(-73.9819129 40.77151449999999)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Lb Spumoni Gardens',-73.9812843,40.5947365,ST_GeomFromText('POINT(-73.9812843 40.5947365)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Amore Pizzeria & Restaurant',-73.8344778,40.7692995,ST_GeomFromText('POINT(-73.8344778 40.7692995)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('The Lark S Nest',-73.86697,40.89794699999999,ST_GeomFromText('POINT(-73.86697 40.89794699999999)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Terrace Cafe',-73.8786113,40.8502883,ST_GeomFromText('POINT(-73.8786113 40.8502883)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('African Terrace',-73.8786113,40.8502883,ST_GeomFromText('POINT(-73.8786113 40.8502883)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Cool Zone',-73.8786113,40.8502883,ST_GeomFromText('POINT(-73.8786113 40.8502883)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('African Market (Baboon Cafe)',-73.8786113,40.8502883,ST_GeomFromText('POINT(-73.8786113 40.8502883)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Beaver Pond',-73.8786113,40.8502883,ST_GeomFromText('POINT(-73.8786113 40.8502883)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Roadhouse Restaurant',-74.1005771,40.6134163,ST_GeomFromText('POINT(-74.1005771 40.6134163)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Ford Foundation Cafeteria',-73.971128,40.749869,ST_GeomFromText('POINT(-73.971128 40.749869)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Elephant & Castle',-74.00066699999999,40.736224,ST_GeomFromText('POINT(-74.00066699999999 40.736224)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Oyster Bar',-73.97705599999999,40.752998,ST_GeomFromText('POINT(-73.97705599999999 40.752998)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Cherry Tavern',-73.98431219999999,40.7258174,ST_GeomFromText('POINT(-73.98431219999999 40.7258174)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Red Flame Diner',-73.9827221,40.7561037,ST_GeomFromText('POINT(-73.9827221 40.7561037)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Colonnade Diner',-74.099018,40.58116500000001,ST_GeomFromText('POINT(-74.099018 40.58116500000001)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Brady S Bar',-73.9537859,40.775493,ST_GeomFromText('POINT(-73.9537859 40.775493)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mill Basin Kosher Deli',-73.9181846,40.6157107,ST_GeomFromText('POINT(-73.9181846 40.6157107)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Maggies Place',-73.977114,40.756295,ST_GeomFromText('POINT(-73.977114 40.756295)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Da Silvano Restaurant',-74.0062401,40.7397546,ST_GeomFromText('POINT(-74.0062401 40.7397546)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Benjamin',-73.9765607,40.7443236,ST_GeomFromText('POINT(-73.9765607 40.7443236)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Jimmy S Corner',-73.984838,40.756594,ST_GeomFromText('POINT(-73.984838 40.756594)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Denny S Pub',-73.9789394,40.6429349,ST_GeomFromText('POINT(-73.9789394 40.6429349)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Maries Crisis Cafe',-74.00340299999999,40.733235,ST_GeomFromText('POINT(-74.00340299999999 40.733235)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Boots & Saddle Bar',-74.00341019999999,40.7335084,ST_GeomFromText('POINT(-74.00341019999999 40.7335084)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('New Parkway Restaurant',-74.0078144,40.6202393,ST_GeomFromText('POINT(-74.0078144 40.6202393)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Sammy S Steakhouse',153.1628795,-28.0168595,ST_GeomFromText('POINT(153.1628795 -28.0168595)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Cafe Riazor',-74.000399,40.740848,ST_GeomFromText('POINT(-74.000399 40.740848)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('The Brook',-73.9714599,40.759647,ST_GeomFromText('POINT(-73.9714599 40.759647)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Il Cortile Restaurant',-73.998254,40.7179289,ST_GeomFromText('POINT(-73.998254 40.7179289)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Raouls',-74.002139,40.7261357,ST_GeomFromText('POINT(-74.002139 40.7261357)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Frost Restaurant',-73.94347599999999,40.718386,ST_GeomFromText('POINT(-73.94347599999999 40.718386)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Hatsuhana Restaurant',-73.97691499999999,40.757028,ST_GeomFromText('POINT(-73.97691499999999 40.757028)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('La Mangeoire',-73.9668354,40.7568328,ST_GeomFromText('POINT(-73.9668354 40.7568328)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Valentino S Pizza',-73.814835,40.7288261,ST_GeomFromText('POINT(-73.814835 40.7288261)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Viand Coffee Shop',-73.970169,40.764834,ST_GeomFromText('POINT(-73.970169 40.764834)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Palm Too',-73.970668,40.751453,ST_GeomFromText('POINT(-73.970668 40.751453)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Steve S Coffee Shop',-91.5971285,41.6823902,ST_GeomFromText('POINT(-91.5971285 41.6823902)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Blue Bay Restaurant',-73.9100082,40.8863835,ST_GeomFromText('POINT(-73.9100082 40.8863835)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Nada-Sushi',-73.9717,40.756457,ST_GeomFromText('POINT(-73.9717 40.756457)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('The Hytes Bar',-73.942599,40.67096,ST_GeomFromText('POINT(-73.942599 40.67096)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('P.J.  S',-73.7796156,40.7298006,ST_GeomFromText('POINT(-73.7796156 40.7298006)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Reif S Tavern',-73.9486257,40.7813724,ST_GeomFromText('POINT(-73.9486257 40.7813724)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Jody S Club',-74.1018239,40.630788,ST_GeomFromText('POINT(-74.1018239 40.630788)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Whitestone Lanes',-73.8335566,40.7703224,ST_GeomFromText('POINT(-73.8335566 40.7703224)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('John S Pizzeria',-73.8818014,40.7347681,ST_GeomFromText('POINT(-73.8818014 40.7347681)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Seashore Restaurant',-73.790804,40.8541848,ST_GeomFromText('POINT(-73.790804 40.8541848)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Marbella Restaurant',-73.76078199999999,40.761876,ST_GeomFromText('POINT(-73.76078199999999 40.761876)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Caffe Reggio',-74.00041689999999,40.7302678,ST_GeomFromText('POINT(-74.00041689999999 40.7302678)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Cafe Un Deux Trois',-73.984126,40.7567949,ST_GeomFromText('POINT(-73.984126 40.7567949)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Armando S Pizza',-73.88228649999999,40.6481972,ST_GeomFromText('POINT(-73.88228649999999 40.6481972)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Dan Tempura',-73.9818416,40.7760336,ST_GeomFromText('POINT(-73.9818416 40.7760336)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Knickerbocker Bar & Grill',-73.994428,40.7320132,ST_GeomFromText('POINT(-73.994428 40.7320132)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Pergola Des Artistes',-73.9873049,40.7592843,ST_GeomFromText('POINT(-73.9873049 40.7592843)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mcdonald S',-73.9808063,40.6895078,ST_GeomFromText('POINT(-73.9808063 40.6895078)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('El Pote Espanol',-73.9735762,40.74754,ST_GeomFromText('POINT(-73.9735762 40.74754)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Cafe Capri',-73.94523509999999,40.7177182,ST_GeomFromText('POINT(-73.94523509999999 40.7177182)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('The River Cafe',-73.99472279999999,40.703195,ST_GeomFromText('POINT(-73.99472279999999 40.703195)', 4326));
# ...
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Villaggio Pizzeria Restaurant',-74.24660039999999,40.5092869,ST_GeomFromText('POINT(-74.24660039999999 40.5092869)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Petite Abeille',-73.9793904,40.7349974,ST_GeomFromText('POINT(-73.9793904 40.7349974)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Trinidad Ali S Roti Shop #2',-73.960243,40.65913,ST_GeomFromText('POINT(-73.960243 40.65913)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Xes Lounge',-73.9944821,40.74467629999999,ST_GeomFromText('POINT(-73.9944821 40.74467629999999)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Paramount Bar & Grill',-73.986987,40.759642,ST_GeomFromText('POINT(-73.986987 40.759642)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Famous Famiglia Pizza',-73.95729759999999,40.7656818,ST_GeomFromText('POINT(-73.95729759999999 40.7656818)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Leone S Pizzeria & Restaurant',-73.8651089,40.710613,ST_GeomFromText('POINT(-73.8651089 40.710613)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Sunny S',-74.0168872,40.6756643,ST_GeomFromText('POINT(-74.0168872 40.6756643)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('El Nuevo Yoly Restaurant',-73.91965429999999,40.8459646,ST_GeomFromText('POINT(-73.91965429999999 40.8459646)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Tu Casa Restaurant',-73.83146099999999,40.70628300000001,ST_GeomFromText('POINT(-73.83146099999999 40.70628300000001)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Ukrainian Restaurant',-73.98668649999999,40.7299351,ST_GeomFromText('POINT(-73.98668649999999 40.7299351)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Akdeniz',-73.979916,40.756666,ST_GeomFromText('POINT(-73.979916 40.756666)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('The Mansfield Bar',-73.9811299,40.755025,ST_GeomFromText('POINT(-73.9811299 40.755025)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Domand S Italian Gourmet Deli & Caterers',-73.83444899999999,40.7692443,ST_GeomFromText('POINT(-73.83444899999999 40.7692443)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Subway',-73.8781558,40.872868,ST_GeomFromText('POINT(-73.8781558 40.872868)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mendy S',-73.976451,40.7518315,ST_GeomFromText('POINT(-73.976451 40.7518315)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('La Terraza Restaurant',-73.9426319,40.8373749,ST_GeomFromText('POINT(-73.9426319 40.8373749)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Liberty Pizza',-73.9660238,40.6932746,ST_GeomFromText('POINT(-73.9660238 40.6932746)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Midtown Buffet',-73.987977,40.75519500000001,ST_GeomFromText('POINT(-73.987977 40.75519500000001)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Abitino S Pizza',-73.987034,40.754712,ST_GeomFromText('POINT(-73.987034 40.754712)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Dunkin  Donuts, Baskin Robbins',-73.92259659999999,40.7434474,ST_GeomFromText('POINT(-73.92259659999999 40.7434474)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Ali Baba Restaurant',-73.9775028,40.7451605,ST_GeomFromText('POINT(-73.9775028 40.7451605)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Sip Sak',-73.968502,40.754336,ST_GeomFromText('POINT(-73.968502 40.754336)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Aegea Gyros And Pizza',-73.7395327,40.7666584,ST_GeomFromText('POINT(-73.7395327 40.7666584)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Paradise Venus Restaurant',-73.9531695,40.6550579,ST_GeomFromText('POINT(-73.9531695 40.6550579)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Silver Leaf Tavern',-73.9797524,40.7498316,ST_GeomFromText('POINT(-73.9797524 40.7498316)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Crown Fried Chicken',-73.7393994,40.70659759999999,ST_GeomFromText('POINT(-73.7393994 40.70659759999999)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Starbucks Coffee',-73.9768727,40.6845666,ST_GeomFromText('POINT(-73.9768727 40.6845666)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Starbucks Coffee',-73.9742229,40.7584214,ST_GeomFromText('POINT(-73.9742229 40.7584214)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Barnes & Noble Booksellers',-73.790688,40.7257013,ST_GeomFromText('POINT(-73.790688 40.7257013)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Falafel Off The Korner',-73.9716827,40.6086369,ST_GeomFromText('POINT(-73.9716827 40.6086369)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Emack & Bolio S',-73.9995648,40.7265272,ST_GeomFromText('POINT(-73.9995648 40.7265272)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('New York University - Law School Cafe',-73.99892400000002,40.730124,ST_GeomFromText('POINT(-73.99892400000002 40.730124)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('El Rinconcito De Nagua',-73.8647956,40.6915025,ST_GeomFromText('POINT(-73.8647956 40.6915025)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Fanelli Cafe',-73.99883899999999,40.7245064,ST_GeomFromText('POINT(-73.99883899999999 40.7245064)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('The Grill House',-73.8646818,40.8497364,ST_GeomFromText('POINT(-73.8646818 40.8497364)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mcdonald S',-73.9768727,40.6845666,ST_GeomFromText('POINT(-73.9768727 40.6845666)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('25Th Deli',-73.9046315,40.7647951,ST_GeomFromText('POINT(-73.9046315 40.7647951)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Dishes',-73.9789103,40.7548711,ST_GeomFromText('POINT(-73.9789103 40.7548711)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Rogue',-92.7264662,41.7461691,ST_GeomFromText('POINT(-92.7264662 41.7461691)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('The Dugout',-73.92516189999999,40.8284252,ST_GeomFromText('POINT(-73.92516189999999 40.8284252)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Bingo Bingo Bingo',-73.946698,40.627623,ST_GeomFromText('POINT(-73.946698 40.627623)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Bagelsmith',-73.9578707,40.7175673,ST_GeomFromText('POINT(-73.9578707 40.7175673)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Andrew S Pizzeria',-73.8792543,40.72472,ST_GeomFromText('POINT(-73.8792543 40.72472)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Tia Pol',-74.004801,40.7473,ST_GeomFromText('POINT(-74.004801 40.7473)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Canaan Cake House',-73.8279022,40.7626274,ST_GeomFromText('POINT(-73.8279022 40.7626274)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Pates Plus Bakery',-73.73499799999999,40.716748,ST_GeomFromText('POINT(-73.73499799999999 40.716748)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mama S Bar',-73.9809983,40.7253563,ST_GeomFromText('POINT(-73.9809983 40.7253563)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Sunrise Of Mill Basin',-73.91629999999999,40.607952,ST_GeomFromText('POINT(-73.91629999999999 40.607952)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('El Dorado Restaurant',-73.8146146,40.702732,ST_GeomFromText('POINT(-73.8146146 40.702732)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Village East Cinemas',-73.98615699999999,40.7309294,ST_GeomFromText('POINT(-73.98615699999999 40.7309294)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Cinema 1, 2, & 3',-73.9660305,40.7618383,ST_GeomFromText('POINT(-73.9660305 40.7618383)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Boardwalk Bagel',-73.829696,40.5814329,ST_GeomFromText('POINT(-73.829696 40.5814329)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Canaan Bakery',-73.826331,40.7595468,ST_GeomFromText('POINT(-73.826331 40.7595468)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Il Piccolo Bufalo',-73.9978127,40.718834,ST_GeomFromText('POINT(-73.9978127 40.718834)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Hing Wong',-73.9164158,40.8485293,ST_GeomFromText('POINT(-73.9164158 40.8485293)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Breadsoul Cafe/ Lincoln Cafe',-73.9817091,40.7710093,ST_GeomFromText('POINT(-73.9817091 40.7710093)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Special Attention',-73.982767,40.72081499999999,ST_GeomFromText('POINT(-73.982767 40.72081499999999)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Gerrittsen Beach Property Owners Association',-73.9240788,40.5860339,ST_GeomFromText('POINT(-73.9240788 40.5860339)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('The Michelangelo',-73.982444,40.761422,ST_GeomFromText('POINT(-73.982444 40.761422)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Lili S 57',-73.9804462,40.7655657,ST_GeomFromText('POINT(-73.9804462 40.7655657)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Hummus Place',-73.983875,40.727229,ST_GeomFromText('POINT(-73.983875 40.727229)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Mamas Empanadas',-73.92251259999999,40.7406462,ST_GeomFromText('POINT(-73.92251259999999 40.7406462)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Grand China',-73.8637495,40.7372662,ST_GeomFromText('POINT(-73.8637495 40.7372662)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Applebee S Neighborhood Grill & Bar',-73.90905649999999,40.8738244,ST_GeomFromText('POINT(-73.90905649999999 40.8738244)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Dunkin  Donuts',-73.9047859,40.8125519,ST_GeomFromText('POINT(-73.9047859 40.8125519)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Dunkin  Donuts',-73.9848403,40.73994640000001,ST_GeomFromText('POINT(-73.9848403 40.73994640000001)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Turkish Grill Restaurant & Bar',-73.9221448,40.74387,ST_GeomFromText('POINT(-73.9221448 40.74387)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('El Dorado Restaurant',-73.9177799,40.703107,ST_GeomFromText('POINT(-73.9177799 40.703107)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Dunkin  Donuts',-73.94005299999999,40.593596,ST_GeomFromText('POINT(-73.94005299999999 40.593596)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Cool Ice',-74.126328,40.612596,ST_GeomFromText('POINT(-74.126328 40.612596)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Great Dragon Restaurant',-73.9253161,40.744353,ST_GeomFromText('POINT(-73.9253161 40.744353)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Awash Ethiopian Restaurant',-73.9868924,40.7264833,ST_GeomFromText('POINT(-73.9868924 40.7264833)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Momofuku Ko',-73.98467300000002,40.729006,ST_GeomFromText('POINT(-73.98467300000002 40.729006)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Larry And Lawrence',-73.9573216,40.7130584,ST_GeomFromText('POINT(-73.9573216 40.7130584)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Pretzel Maker',-73.8706606,40.7342757,ST_GeomFromText('POINT(-73.8706606 40.7342757)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Golden Krust Caribbean Bakery & Grill',-73.94310449999999,40.8108763,ST_GeomFromText('POINT(-73.94310449999999 40.8108763)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Winners Bar',-73.880501,40.741805,ST_GeomFromText('POINT(-73.880501 40.741805)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Chuck E Cheese S',-73.9768727,40.6845666,ST_GeomFromText('POINT(-73.9768727 40.6845666)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Brooklyn Exposure',-73.9532215,40.6751474,ST_GeomFromText('POINT(-73.9532215 40.6751474)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Lily Thai Restaurant',-73.94759669999999,40.7114747,ST_GeomFromText('POINT(-73.94759669999999 40.7114747)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Freemans',-73.992272,40.721989,ST_GeomFromText('POINT(-73.992272 40.721989)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Fresh Salt',-74.00243739999999,40.7070522,ST_GeomFromText('POINT(-74.00243739999999 40.7070522)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Cafe Exchange',-74.0133214,40.7068236,ST_GeomFromText('POINT(-74.0133214 40.7068236)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('1 Darbar',-73.97352649999999,40.753517,ST_GeomFromText('POINT(-73.97352649999999 40.753517)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Wagner College - Hawk  Nest',-74.09285299999999,40.61512099999999,ST_GeomFromText('POINT(-74.09285299999999 40.61512099999999)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Ellen Deli & Grocery',-74.00780999999999,40.725708,ST_GeomFromText('POINT(-74.00780999999999 40.725708)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Crepes On Columbus',-73.9618311,40.8010518,ST_GeomFromText('POINT(-73.9618311 40.8010518)', 4326));
# INSERT INTO test.restaurants (name, longitude, latitude, location) VALUES ('Capital Grille',-73.9747229,40.751244,ST_GeomFromText('POINT(-73.9747229 40.751244)', 4326));
# PostgreSQL connection is closed

# %%
try:
    # Connect to an existing database
    connection = psycopg2.connect(user="test_user",
                                  password="tester",
                                  host="127.0.0.1",
                                  port="5432",
                                  database="test")

    # Create a cursor to perform database operations
    cursor = connection.cursor()
    # Print PostgreSQL details
    print("PostgreSQL server information")
    print(connection.get_dsn_parameters(), "\n")
    # Executing a SQL query
    cursor.execute("SELECT version();")
    # Fetch result
    record = cursor.fetchone()
    print("You are connected to - ", record, "\n")

    #Closing the connection
    connection.close()

except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if (connection):
       cursor.close()
       connection.close()
       print("PostgreSQL connection is closed")
# Out:
# PostgreSQL server information
# {'user': 'test_user', 'channel_binding': 'prefer', 'dbname': 'test', 'host': '127.0.0.1', 'port': '5432', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'sslcertmode': 'allow', 'sslsni': '1', 'ssl_min_protocol_version': 'TLSv1.2', 'gssencmode': 'disable', 'krbsrvname': 'postgres', 'gssdelegation': '0', 'target_session_attrs': 'any', 'load_balance_hosts': 'disable'}
#
# You are connected to -  ('PostgreSQL 17.5 on x86_64-windows, compiled by msvc-19.44.35209, 64-bit',)
#
# PostgreSQL connection is closed
