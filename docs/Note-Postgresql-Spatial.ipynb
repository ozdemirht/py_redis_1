# %% [markdown]
# ## PostgreSQL and PostGIS for Nearest Neighbour Query / Proximity Search

# %% [markdown]
# Objective is to leverage PostGIS for NNQ.
#
# This notebook demonstrates NNQ by using PostGIS extension of PostgreSQL.
#
# Query:  *find the list of restaurants that serve $cuisine and is within Xkm from a location (Lat, Lon)*

# %% [markdown]
#  1. It creates the following test.restaurants table
# ```bash
# CREATE TABLE IF NOT EXISTS test.restaurants (
#   id SERIAL PRIMARY KEY,
#   name VARCHAR(255),
#   cuisine VARCHAR(64),
#   longitude FLOAT,
#   latitude FLOAT,
#   location GEOMETRY(Point, 4326)
# )
# ```
#  1. tested query:  *find the list of restaurants that is within Xkm from a location (Lat, Lon)* with a) no index, b) GIST index on location column, and c) SPGIST index on location column.
#  1. tested query:  *find the list of restaurants that serve $cuisine and is within Xkm from a location (Lat, Lon)* with a) no index, b) GIST index on location column, c) SPGIST index on location column, d) B-Tree index on cuisine column.
#
# After validating query plans, we can conclude that a client can use a single query to retrieve answers and paginate.

# %%
# %pip install --user psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\timuc\appdata\roaming\python\python313\site-packages (2.9.11)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# To enable PostGIS extension, run the following command on database
#
# CREATE EXTENSION postgis;

# %%
import psycopg2
from psycopg2 import Error
import pandas as pd

# %% [markdown]
# Parsing configuration parameters.

# %%
def getConfigOrDefault(config_filename, config,label,default=None):
    if config.get(label) is not None:
        return config.get(label)
    if default is not None:
        return default
    print(f"{config_filename} file does not have {label} parameter!")
    return None

# %%
from dotenv import dotenv_values
config_filename = './postgresql.cfg'
config = dotenv_values(config_filename)

USER_NAME = getConfigOrDefault(config_filename, config, 'POSTGRES_UNAME')
USER_PWD  = getConfigOrDefault(config_filename, config, 'POSTGRES_UPWD')
POSTGRES_HOST = getConfigOrDefault(config_filename, config, 'POSTGRES_HOST', 'localhost')
POSTGRES_PORT = getConfigOrDefault(config_filename, config, 'POSTGRES_PORT', '5432')
POSTGRES_DB = getConfigOrDefault(config_filename, config, 'POSTGRES_DBNAME', 'test')

if USER_PWD is None or USER_PWD is None:
    print(f"{config_filename} file does not have parameters: POSTGRES_UNAME and/or POSTGRES_UPWD!")

# %%
try:
    # Connect to an existing database
    connection = psycopg2.connect(user=USER_NAME,
                                  password=USER_PWD,
                                  host=POSTGRES_HOST,
                                  port=POSTGRES_PORT,
                                  database=POSTGRES_DB)

    # Create a cursor to perform database operations
    cursor = connection.cursor()
    # Print PostgreSQL details
    print("PostgreSQL server information")
    print(connection.get_dsn_parameters(), "\n")
    # Executing a SQL query
    cursor.execute("SELECT version();")
    # Fetch result
    record = cursor.fetchone()
    print("You are connected to - ", record, "\n")

    #Closing the connection
    connection.close()

except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if (connection):
       cursor.close()
       connection.close()
       print("PostgreSQL connection is closed")
# Out:
# PostgreSQL server information
# {'user': 'test_user', 'channel_binding': 'prefer', 'dbname': 'postgres', 'host': '127.0.0.1', 'port': '5432', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'sslcertmode': 'allow', 'sslsni': '1', 'ssl_min_protocol_version': 'TLSv1.2', 'gssencmode': 'disable', 'krbsrvname': 'postgres', 'gssdelegation': '0', 'target_session_attrs': 'any', 'load_balance_hosts': 'disable'}
#
# You are connected to -  ('PostgreSQL 17.5 on x86_64-windows, compiled by msvc-19.44.35209, 64-bit',)
#
# PostgreSQL connection is closed

# %% [markdown]
# ## Helpers

# %%
def execute_sqL_with_fetchnone(sql_stmt):
    """ Executes SQL statement with fetchnone
        Not worried about performance
    """
    print(f"Executing SQL statement with fetchnone-{sql_stmt}")
    try:
        # Connect to an existing database
        connection = psycopg2.connect(user=USER_NAME,
                                  password=USER_PWD,
                                  host=POSTGRES_HOST,
                                  port=POSTGRES_PORT,
                                  database=POSTGRES_DB)

        # Create a cursor to perform database operations
        cursor = connection.cursor()
        # Executing given SQL query
        cursor.execute(sql_stmt)
        connection.commit()
        cursor.close()
        connection.close()

    except (Exception, Error) as error:
        print(f"Error : {error}")
    finally:
        if (connection):
            cursor.close()
            connection.close()
            print(f"Connection to PostgreSQL({POSTGRES_HOST}:{POSTGRES_PORT}) is closed")

# %%
def execute_sqL_with_fetchone(sql_stmt):
    """ Executes SQL statement with fetchone
        Not worried about performance
    """
    response = None
    print(f"Executing SQL statement with fetchone-{sql_stmt}")
    try:
        # Connect to an existing database
        connection = psycopg2.connect(user=USER_NAME,
                                  password=USER_PWD,
                                  host=POSTGRES_HOST,
                                  port=POSTGRES_PORT,
                                  database=POSTGRES_DB)

        # Create a cursor to perform database operations
        cursor = connection.cursor()
        # Executing given SQL query
        cursor.execute(sql_stmt)
        # Fetch result so that it can return
        response = cursor.fetchone()

        connection.commit()
        cursor.close()
        connection.close()

    except (Exception, Error) as error:
        print(f"Error : {error}")
    finally:
        if (connection):
            cursor.close()
            connection.close()
            print(f"Connection to PostgreSQL({POSTGRES_HOST}:{POSTGRES_PORT}) is closed")
    return response

# %%
def execute_sqL_with_fetchall(sql_stmt):
    """ Executes SQL statement with fetchone
        Not worried about performance
    """
    response = None
    try:
        # Connect to an existing database
        connection = psycopg2.connect(user=USER_NAME,
                                  password=USER_PWD,
                                  host=POSTGRES_HOST,
                                  port=POSTGRES_PORT,
                                  database=POSTGRES_DB)

        # Create a cursor to perform database operations
        cursor = connection.cursor()
        # Executing given SQL query
        cursor.execute(sql_stmt)
        # Fetch result so that it can return
        response = cursor.fetchall()

        connection.commit()
        cursor.close()
        connection.close()

    except (Exception, Error) as error:
        print(f"Error : {error}")
    finally:
        if (connection):
            cursor.close()
            connection.close()
            print(f"Connection to PostgreSQL({POSTGRES_HOST}:{POSTGRES_PORT}) is closed")
    return response

# %% [markdown]
# This notebook utilize following helper queries

# %%
# Queries
SQL_DROP_TABLE = f"DROP TABLE IF EXISTS test.restaurants;"
SQL_CREATE_TABLE = f"""
    CREATE TABLE IF NOT EXISTS test.restaurants (
    id SERIAL PRIMARY KEY,
    name VARCHAR(255),
    cuisine VARCHAR(64),
    longitude FLOAT,
    latitude FLOAT,
    location GEOMETRY(Point, 4326)
    )
    """
SQL_VALIDATE_COLUMNS="""
     select column_name
        , data_type
        , udt_catalog
        , udt_schema
        , udt_name
        , character_maximum_length
        , column_default
        , is_nullable
    from INFORMATION_SCHEMA.COLUMNS
    where table_name = 'restaurants';
    """

# %%
# Drops the restaurants table
reply = execute_sqL_with_fetchnone(SQL_DROP_TABLE)
reply
# Out:
# Executing SQL statement with fetchnone-DROP TABLE IF EXISTS test.restaurants;
# Connection to PostgreSQL(127.0.0.1:5432) is closed

# %%
# create the restaurants table
reply = execute_sqL_with_fetchnone(SQL_CREATE_TABLE)
reply
# Out:
# Executing SQL statement with fetchnone-
#     CREATE TABLE IF NOT EXISTS test.restaurants (
#     id SERIAL PRIMARY KEY,
#     name VARCHAR(255),
#     cuisine VARCHAR(64),
#     longitude FLOAT,
#     latitude FLOAT,
#     location GEOMETRY(Point, 4326)
#     )
#
# Connection to PostgreSQL(127.0.0.1:5432) is closed

# %%
# create the restaurants table
reply = execute_sqL_with_fetchall(SQL_VALIDATE_COLUMNS)
reply
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# [('id',
#   'integer',
#   'postgres',
#   'pg_catalog',
#   'int4',
#   None,
#   "nextval('test.restaurants_id_seq'::regclass)",
#   'NO'),
#  ('name',
#   'character varying',
#   'postgres',
#   'pg_catalog',
#   'varchar',
#   255,
#   None,
#   'YES'),
#  ('cuisine',
#   'character varying',
#   'postgres',
#   'pg_catalog',
#   'varchar',
#   64,
#   None,
#   'YES'),
#  ('longitude',
#   'double precision',
#   'postgres',
#   'pg_catalog',
#   'float8',
#   None,
#   None,
#   'YES'),
#  ('latitude',
#   'double precision',
#   'postgres',
#   'pg_catalog',
#   'float8',
#   None,
#   None,
#   'YES'),
#  ('location',
#   'USER-DEFINED',
#   'postgres',
#   'public',
#   'geometry',
#   None,
#   None,
#   'YES')]

# %% [markdown]
# Let's check table definition

# %%
column_names = [ 'column_name', 'data_type',
                 'udt_catalog', 'udt_schema', 'udt_name',
                 'character_maximum_length', 'column_default', 'is_nullable']
df = pd.DataFrame(reply,columns=column_names)
df
# Out:
#   column_name          data_type udt_catalog  udt_schema  udt_name  \
# 0          id            integer    postgres  pg_catalog      int4
# 1        name  character varying    postgres  pg_catalog   varchar
# 2     cuisine  character varying    postgres  pg_catalog   varchar
# 3   longitude   double precision    postgres  pg_catalog    float8
# 4    latitude   double precision    postgres  pg_catalog    float8
# 5    location       USER-DEFINED    postgres      public  geometry
#
#    character_maximum_length                                column_default  \
# 0                       NaN  nextval('test.restaurants_id_seq'::regclass)
# 1                     255.0                                          None
# 2                      64.0                                          None
# 3                       NaN                                          None
# 4                       NaN                                          None
# 5                       NaN                                          None
#
#   is_nullable
# 0          NO
# 1         YES
# 2         YES
# 3         YES
# 4         YES
# 5         YES

# %%
filename="./restaurants.csv"
df_loaded = pd.read_csv(filename)
df_loaded[:10]
# Out:
#                              Name        Lon        Lat
# 0           Morris Park Bake Shop -73.856077  40.848447
# 1                         Wendy'S -73.961704  40.662942
# 2                 Riviera Caterer -73.982420  40.579505
# 3              Tov Kosher Kitchen -73.860115  40.731174
# 4         Brunos On The Boulevard -73.880383  40.764312
# 5  Dj Reynolds Pub And Restaurant -73.985136  40.767692
# 6              Wilken'S Fine Food -73.906851  40.619903
# 7                 Regina Caterers -74.005289  40.628886
# 8     Taste The Tropics Ice Cream -73.948261  40.640827
# 9                   Kosher Island -74.137729  40.611957

# %%
df_loaded['Rid'] = df_loaded.index
printdf = df_loaded[:10]
print(printdf.to_string(index=False))
# Out:
#                           Name        Lon       Lat  Rid
#          Morris Park Bake Shop -73.856077 40.848447    0
#                        Wendy'S -73.961704 40.662942    1
#                Riviera Caterer -73.982420 40.579505    2
#             Tov Kosher Kitchen -73.860115 40.731174    3
#        Brunos On The Boulevard -73.880383 40.764312    4
# Dj Reynolds Pub And Restaurant -73.985136 40.767692    5
#             Wilken'S Fine Food -73.906851 40.619903    6
#                Regina Caterers -74.005289 40.628886    7
#    Taste The Tropics Ice Cream -73.948261 40.640827    8
#                  Kosher Island -74.137729 40.611957    9

# %%
import random
def assignCuisineRandomly(df,cuisine,cname):
    for i in range(df.shape[0]):
        df.at[i,cname] = cuisine[random.randint(0,len(cuisine)-1)]

# %%
cuisine = ['italian', 'chinese', 'french', 'zambian', 'egyptian', 'canadian', 'mexican', 'vietnamese', 'cajun', 'korean', 'thai', 'brazilian','colombian','peruvian','ecuadorian', 'japanese','indian','malaysian','russian', 'indonesian']
assignCuisineRandomly(df_loaded,cuisine,'Cuisine')
df_loaded[-4:]
# Out:
#                              Name        Lon        Lat   Rid    Cuisine
# 4996  Wagner College - Hawk' Nest -74.092853  40.615121  4996   egyptian
# 4997         Ellen Deli & Grocery -74.007810  40.725708  4997  malaysian
# 4998           Crepes On Columbus -73.961831  40.801052  4998    mexican
# 4999               Capital Grille -73.974723  40.751244  4999   japanese

# %%
def formatSQL(df):
    name = df['Name'].replace("'"," ")
    sql_stmt = f"INSERT INTO test.restaurants (name, cuisine, longitude, latitude, location) VALUES ('{name}','{df['Cuisine']}',{df['Lon']},{df['Lat']},ST_GeomFromText('POINT({df['Lon']} {df['Lat']})', 4326));"

    return sql_stmt

# %%
#print(formatSQL(df_loaded[0]))
idx=4996
print(type(df_loaded.loc[idx].to_dict()))
df_loaded.loc[idx].to_dict()
print(formatSQL(df_loaded.loc[idx].to_dict()))
# Out:
# <class 'dict'>
# INSERT INTO test.restaurants (name, cuisine, longitude, latitude, location) VALUES ('Wagner College - Hawk  Nest','egyptian',-74.09285299999999,40.61512099999999,ST_GeomFromText('POINT(-74.09285299999999 40.61512099999999)', 4326));

# %% [markdown]
# Let's load the data

# %%
# Load data to test.restaurants table
# using ST_GeomFromText('POINT($longitude $latitude)', 4326)
try:
        # Connect to an existing database
        connection = psycopg2.connect(user=USER_NAME,
                                      password=USER_PWD,
                                      host=POSTGRES_HOST,
                                      port=POSTGRES_PORT,
                                      database=POSTGRES_DB)

        # Create a cursor to perform database operations
        cursor = connection.cursor()
        # Executing a SQL query
        cursor.execute("SELECT version();")
        # Fetch result
        record = cursor.fetchone()
        print("You are connected to - ", record, "\n")
        sql_stmt = ""
        for i in range(df_loaded.shape[0]):
            #addARestaurant(connection, df_loaded.loc[i].to_dict())
            sql_stmt = formatSQL(df_loaded.loc[i].to_dict())
            #print(sql_stmt)
            cursor.execute(sql_stmt)

        connection.commit()

        #Closing the connection
        connection.close()

except (Exception, Error) as error:
        print("Error: ", error)
finally:
        if (connection):
            cursor.close()
            connection.close()
        print("PostgreSQL connection is closed")
# Out:
# You are connected to -  ('PostgreSQL 17.5 on x86_64-windows, compiled by msvc-19.44.35209, 64-bit',)
#
# PostgreSQL connection is closed

# %% [markdown]
# Let's search

# %%
NNQ_LON = -74.092853
NNQ_LAT =  40.615121
NNQ_RADIUS = 2000/10000
query = f"""
SELECT name
    , cuisine
    , longitude
    , latitude
    , ST_Distance(location, ST_Point({NNQ_LON}, {NNQ_LAT},4326)) AS dist2NNQ
FROM test.restaurants
WHERE ST_DWithin(location, ST_Point({NNQ_LON}, {NNQ_LAT},4326), {NNQ_RADIUS});
"""

explain_query = "Explain "+ query

# %%
reply = execute_sqL_with_fetchall(query)
print(type(reply))
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# <class 'list'>

# %%
column_names = [ 'name', 'cuisine','longitude', 'latitude', 'dist2NNQ']
df = pd.DataFrame(reply,columns=column_names)
df
# Out:
#                                 name     cuisine  longitude   latitude  \
# 0                            Wendy S    egyptian -73.961704  40.662942
# 1                    Riviera Caterer   brazilian -73.982420  40.579505
# 2     Dj Reynolds Pub And Restaurant  indonesian -73.985136  40.767692
# 3                 Wilken S Fine Food     zambian -73.906851  40.619903
# 4                    Regina Caterers  indonesian -74.005289  40.628886
# ...                              ...         ...        ...        ...
# 3103                   Cafe Exchange        thai -74.013321  40.706824
# 3104                        1 Darbar    egyptian -73.973526  40.753517
# 3105     Wagner College - Hawk  Nest    egyptian -74.092853  40.615121
# 3106            Ellen Deli & Grocery   malaysian -74.007810  40.725708
# 3107                  Capital Grille    japanese -73.974723  40.751244
#
#           dist2NNQ
# 0     1.395955e-01
# 1     1.160342e-01
# 2     1.867643e-01
# 3     1.860639e-01
# 4     8.863932e-02
# ...            ...
# 3103  1.213863e-01
# 3104  1.827355e-01
# 3105  2.009718e-14
# 3106  1.395055e-01
# 3107  1.802337e-01
#
# [3108 rows x 5 columns]

# %% [markdown]
# Let's check the query plan

# %%
reply = execute_sqL_with_fetchall(explain_query)
reply
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# [('Seq Scan on restaurants  (cost=0.00..62630.50 rows=1 width=49)',),
#  ("  Filter: st_dwithin(location, '0101000020E61000007995B54DF18552C09A0AF148BC4E4440'::geometry, '0.2'::double precision)",)]

# %% [markdown]
# It scans the whole table.

# %%
create_index_sql = f"""
CREATE INDEX restaurants_geom_idx
  ON test.restaurants
  USING GIST (location);
"""
drop_index_sql = "DROP INDEX IF EXISTS test.restaurants_geom_idx;"

create_spgist_index_sql = f"""
CREATE INDEX restaurants_spgist_geom_idx
  ON test.restaurants
  USING SPGIST (location);
"""
drop_spgist_index_sql = "DROP INDEX IF EXISTS test.restaurants_spgist_geom_idx;"

check_indices_sql = """
SELECT
    tablename,
    indexname,
    indexdef
FROM
    pg_indexes
WHERE
    schemaname = 'test' and tablename = 'restaurants'
ORDER BY
    tablename,
    indexname;
"""

# %%
Add a GIST index by using location column.

# %%
reply_idx = execute_sqL_with_fetchnone(create_index_sql)
# Out:
# Executing SQL statement with fetchnone-
# CREATE INDEX restaurants_geom_idx
#   ON test.restaurants
#   USING GIST (location);
#
# Connection to PostgreSQL(127.0.0.1:5432) is closed

# %%
Execute NNQ

# %%
# %%time
reply = execute_sqL_with_fetchall(query)
print(type(reply))
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# <class 'list'>
# CPU times: total: 15.6 ms
# Wall time: 76.7 ms

# %% [markdown]
# Let's check the query plan to validate that GIST index is utilized.

# %%
reply = execute_sqL_with_fetchall(explain_query)
reply
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# [('Index Scan using restaurants_geom_idx on restaurants  (cost=0.27..44218.09 rows=1 width=49)',),
#  ("  Index Cond: (location && st_expand('0101000020E61000007995B54DF18552C09A0AF148BC4E4440'::geometry, '0.2'::double precision))",),
#  ("  Filter: st_dwithin(location, '0101000020E61000007995B54DF18552C09A0AF148BC4E4440'::geometry, '0.2'::double precision)",)]

# %% [markdown]
# Query planner is using GIST index. Let's drop GIST index to validate any change.

# %%
reply_idx = execute_sqL_with_fetchnone(drop_index_sql)
# Out:
# Executing SQL statement with fetchnone-DROP INDEX IF EXISTS test.restaurants_geom_idx;
# Connection to PostgreSQL(127.0.0.1:5432) is closed

# %%
# %%time
reply = execute_sqL_with_fetchall(query)
print(type(reply))
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# <class 'list'>
# CPU times: total: 0 ns
# Wall time: 58.5 ms

# %%
reply = execute_sqL_with_fetchall(explain_query)
reply
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# [('Seq Scan on restaurants  (cost=0.00..62630.50 rows=1 width=49)',),
#  ("  Filter: st_dwithin(location, '0101000020E61000007995B54DF18552C09A0AF148BC4E4440'::geometry, '0.2'::double precision)",)]

# %% [markdown]
# It is back to the scanning the table for NNQ. Let's check indices on test.restaurants table by using INFORMATION_SCHEMA.

# %%
column_names2 = [ 'tablename', 'indexname','indexdef']
df2 = pd.DataFrame(execute_sqL_with_fetchall(check_indices_sql),columns=column_names2)
df2
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
#      tablename         indexname  \
# 0  restaurants  restaurants_pkey
#
#                                             indexdef
# 0  CREATE UNIQUE INDEX restaurants_pkey ON test.r...

# %% [markdown]
# Let's add SPGIST index by using location column.

# %%
reply_idx = execute_sqL_with_fetchnone(create_spgist_index_sql)
# Out:
# Executing SQL statement with fetchnone-
# CREATE INDEX restaurants_spgist_geom_idx
#   ON test.restaurants
#   USING SPGIST (location);
#
# Connection to PostgreSQL(127.0.0.1:5432) is closed

# %%
# %%time
reply = execute_sqL_with_fetchall(query)
print(type(reply))
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# <class 'list'>
# CPU times: total: 0 ns
# Wall time: 64.9 ms

# %% [markdown]
# Let's check query plan.

# %%
reply = execute_sqL_with_fetchall(explain_query)
reply
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# [('Index Scan using restaurants_spgist_geom_idx on restaurants  (cost=0.27..44238.09 rows=1 width=49)',),
#  ("  Index Cond: (location && st_expand('0101000020E61000007995B54DF18552C09A0AF148BC4E4440'::geometry, '0.2'::double precision))",),
#  ("  Filter: st_dwithin(location, '0101000020E61000007995B54DF18552C09A0AF148BC4E4440'::geometry, '0.2'::double precision)",)]

# %% [markdown]
# Query plan utilizes restaurants_spgist_geom_idx.

# %%
reply_idx = execute_sqL_with_fetchnone(drop_spgist_index_sql)
# Out:
# Executing SQL statement with fetchnone-DROP INDEX IF EXISTS test.restaurants_spgist_geom_idx;
# Connection to PostgreSQL(127.0.0.1:5432) is closed

# %%
# %%time
reply = execute_sqL_with_fetchall(query)
print(type(reply))
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# <class 'list'>
# CPU times: total: 15.6 ms
# Wall time: 171 ms

# %%
reply = execute_sqL_with_fetchall(explain_query)
reply
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# [('Seq Scan on restaurants  (cost=0.00..62630.50 rows=1 width=49)',),
#  ("  Filter: st_dwithin(location, '0101000020E61000007995B54DF18552C09A0AF148BC4E4440'::geometry, '0.2'::double precision)",)]

# %%
column_names2 = [ 'tablename', 'indexname','indexdef']
df2 = pd.DataFrame(execute_sqL_with_fetchall(check_indices_sql),columns=column_names2)
df2
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
#      tablename         indexname  \
# 0  restaurants  restaurants_pkey
#
#                                             indexdef
# 0  CREATE UNIQUE INDEX restaurants_pkey ON test.r...

# %% [markdown]
# Now let's test the original query:

# %%
qcuisine = 'italian'
query_v1 = f"""
SELECT name
    , cuisine
    , longitude
    , latitude
    , ST_Distance(location, ST_Point({NNQ_LON}, {NNQ_LAT},4326)) AS dist2NNQ
FROM test.restaurants
WHERE ST_DWithin(location, ST_Point({NNQ_LON}, {NNQ_LAT},4326), {NNQ_RADIUS}) AND cuisine = '{qcuisine}';
"""

explain_query_v1 = "Explain "+ query_v1

explain_debug_query_v1 = "Explain (DEBUG) "+ query_v1

# %%
# %%time
reply = execute_sqL_with_fetchall(query_v1)
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# CPU times: total: 0 ns
# Wall time: 78.9 ms

# %% [markdown]
# Let's check the query plan.

# %%
exp_reply = execute_sqL_with_fetchall(explain_query_v1)
exp_reply
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# [('Seq Scan on restaurants  (cost=0.00..62643.00 rows=1 width=49)',),
#  ("  Filter: (((cuisine)::text = 'italian'::text) AND st_dwithin(location, '0101000020E61000007995B54DF18552C09A0AF148BC4E4440'::geometry, '0.2'::double precision))",)]

# %% [markdown]
# It is scanning test.restaurants table by using both predicates. Planner executes comparison predicate before st_dwithin().
# <br> Let's add GIST index on location column.

# %%
reply_idx = execute_sqL_with_fetchnone(create_index_sql)
# Out:
# Executing SQL statement with fetchnone-
# CREATE INDEX restaurants_geom_idx
#   ON test.restaurants
#   USING GIST (location);
#
# Connection to PostgreSQL(127.0.0.1:5432) is closed

# %%
# %%time
reply = execute_sqL_with_fetchall(query_v1)
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# CPU times: total: 0 ns
# Wall time: 69.7 ms

# %% [markdown]
# Let's check the query plan after adding a GIST index on location column.

# %%
exp_reply = execute_sqL_with_fetchall(explain_query_v1)
exp_reply
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# [('Index Scan using restaurants_geom_idx on restaurants  (cost=0.27..44226.85 rows=1 width=49)',),
#  ("  Index Cond: (location && st_expand('0101000020E61000007995B54DF18552C09A0AF148BC4E4440'::geometry, '0.2'::double precision))",),
#  ("  Filter: (((cuisine)::text = 'italian'::text) AND st_dwithin(location, '0101000020E61000007995B54DF18552C09A0AF148BC4E4440'::geometry, '0.2'::double precision))",)]

# %% [markdown]
# Planner scans restaurants_geom_idx first, then filter by cuisine.
# <br> Let's add B-Tree index on cuisine column.

# %%
create_index_cuisine = f"""
CREATE INDEX restaurants_cuisine_idx
  ON test.restaurants
  USING BTREE (cuisine);
"""
drop_index_cuisine = "DROP INDEX IF EXISTS test.restaurants_cuisine_idx;"

# %%
reply_idx = execute_sqL_with_fetchnone(create_index_cuisine)
# Out:
# Executing SQL statement with fetchnone-
# CREATE INDEX restaurants_cuisine_idx
#   ON test.restaurants
#   USING BTREE (cuisine);
#
# Connection to PostgreSQL(127.0.0.1:5432) is closed

# %% [markdown]
# Let's check how the query planner utilizes these indexes.

# %%
exp_reply = execute_sqL_with_fetchall(explain_query_v1)
exp_reply
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# [('Bitmap Heap Scan on restaurants  (cost=105.10..2550.47 rows=1 width=49)',),
#  ("  Recheck Cond: ((cuisine)::text = 'italian'::text)",),
#  ("  Filter: st_dwithin(location, '0101000020E61000007995B54DF18552C09A0AF148BC4E4440'::geometry, '0.2'::double precision)",),
#  ('  ->  BitmapAnd  (cost=105.10..105.10 rows=189 width=0)',),
#  ('        ->  Bitmap Index Scan on restaurants_cuisine_idx  (cost=0.00..6.30 rows=269 width=0)',),
#  ("              Index Cond: ((cuisine)::text = 'italian'::text)",),
#  ('        ->  Bitmap Index Scan on restaurants_geom_idx  (cost=0.00..98.55 rows=3504 width=0)',),
#  ("              Index Cond: (location && st_expand('0101000020E61000007995B54DF18552C09A0AF148BC4E4440'::geometry, '0.2'::double precision))",)]

# %% [markdown]
# Query plan is utilizing both indices.

# %%
# %%time
reply = execute_sqL_with_fetchall(query_v1)
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# CPU times: total: 0 ns
# Wall time: 62.8 ms

# %%
reply_idx = execute_sqL_with_fetchnone(drop_index_cuisine)
# Out:
# Executing SQL statement with fetchnone-DROP INDEX IF EXISTS test.restaurants_cuisine_idx;
# Connection to PostgreSQL(127.0.0.1:5432) is closed

# %%
exp_reply = execute_sqL_with_fetchall(explain_query_v1)
exp_reply
# Out:
# Connection to PostgreSQL(127.0.0.1:5432) is closed
# [('Index Scan using restaurants_geom_idx on restaurants  (cost=0.27..44226.85 rows=1 width=49)',),
#  ("  Index Cond: (location && st_expand('0101000020E61000007995B54DF18552C09A0AF148BC4E4440'::geometry, '0.2'::double precision))",),
#  ("  Filter: (((cuisine)::text = 'italian'::text) AND st_dwithin(location, '0101000020E61000007995B54DF18552C09A0AF148BC4E4440'::geometry, '0.2'::double precision))",)]

# %% [markdown]
# The usage statistics will impact the query planner's decisions. But, query planner utilizes available indices.
# <br> This notebook used a small data sey (5000 entries). The whole table could be cached to memory.
# <br> In this use case, the frequency of updates to test.restaurants table expected to be very low, hence this is Read (query) heavy workload.

# %% [markdown]
# # Summary
